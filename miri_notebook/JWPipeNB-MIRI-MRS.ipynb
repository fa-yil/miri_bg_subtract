# %% [markdown]
# <img style="float: center;" src='https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_header.png' alt="stsci_logo" width="900px"/>

# %% [markdown]
# <a id="title_ID"></a>
# # MIRI MRS Pipeline Notebook #

# %% [markdown]
# **Authors**: David Law, Kirsten Larson; MIRI branch<br>
# **Last Updated**: May 5, 2025<br>
# **Pipeline Version**: 1.18.0 (Build 11.3)

# %% [markdown]
# **Purpose**:<BR>
# This notebook provides a framework for processing generic Mid-Infrared
# Instrument (MIRI) Medium Resolution Spectroscopy | (MRS) data through all
# three James Webb Space Telescope (JWST) pipeline stages.  Data is assumed
# to be located in two observation folders (science and background)
# according to paths set up below.  It should not be necessary to edit any
# cells other than in the [Configuration](#1.-Configuration) section
# unless modifying the standard pipeline processing options.
#
# **Data**:<BR>
# This example is set up to use observations of the LMC planetary nebula
# SMP LMC 058 obtained by Proposal ID (PID) 1523 Observation 3. This is a
# point source that uses a standard 4-point dither in all three grating
# settings.  It incorporates a dedicated background in observation 4.
# Example input data to use will be downloaded automatically unless
# disabled (i.e., to use local files instead).
#
# **JWST pipeline version and CRDS context**:<BR>
# This notebook was written for the
# calibration pipeline version given above.  If you use it with a different pipeline
# version or specify a non-default reference file context please see the relevant
# release notes
# ([here for pipeline](https://github.com/spacetelescope/jwst),
# [here for CRDS](https://jwst-crds.stsci.edu/)) for possibly relevant
# changes.<BR>
#
# **Updates**:<BR>
# This notebook is regularly updated as improvements are made to the
# pipeline. Find the most up to date version of this notebook at:
# https://github.com/spacetelescope/jwst-pipeline-notebooks/
#
# **Recent Changes**:<br>
# Jan 31 2024: Update to 1.13.4 pipeline, enabling spectral leak
# correction<br>
# Jul 1 2024: Migrate from MRS_FlightNB1 notebook, adapt to .call()
# format, add post-hook example, add demo mode capability.<br>
# Oct 11 2024: Update to Build 11.0 (jwst 1.15.1); move pixel_replacement to spec3 and enable by default, add option for bad pixel self-calibration in spec2.<br>
# Jan 16 2025: Update to Build 11.2 (jwst 1.17.1); no significant changes.<br>
# May 5 2025: Update to Build 11.3 (jwst 1.18.0); add optional command to remove residual showers, plot spectra from updated x1d.fits data model with rf-corrected columns.

# %%
from crds import client
import jwst # -> Imports the pipeline stages
import stcal # -> "support package for calibration pipeline software" (https://github.com/spacetelescope/stcal)

# CRDS is the Calibration Reference Data System

import os

print("Server URL:", client.get_crds_server())
print("Latest context:", client.get_default_context("jwst"))
print('# JWST pipe version = {0:s}'.format(jwst.__version__))
print('# STCAL version = {0:s}'.format(stcal.__version__))
# Out:
# CRDS - INFO -  Calibration SW Found: jwst 1.19.2 (/home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst-1.19.2.dist-info)
# Server URL: https://jwst-crds.stsci.edu
# Latest context: jwst_1413.pmap
# # JWST pipe version = 1.19.2
# # STCAL version = 1.14.1

# %% [markdown]
# This code is as mentioned above, written for Pipeline 1.18.0. My pipeline version is 1.19.2. I will downgrade if necessity arises in the future. (26/10/2025)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## Table of Contents
#
# 1. [Configuration](#1.-Configuration)
# 2. [Package Imports](#2.-Package-Imports)
# 3. [Demo Mode Setup](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data))
# 4. [Directory Setup](#4.-Directory-Setup)
# 5. [Detector1 Pipeline](#5.-Detector1-Pipeline)
# 6. [Spec2 Pipeline](#6.-Spec2-Pipeline)
# 7. [Spec3 Pipeline](#7.-Spec3-Pipeline)
# 8. [Plot the spectra](#8.-Plot-the-spectra)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 1.<font color='white'>-</font>Configuration<a class="anchor" id="intro"></a>
# ------------------
# Set basic parameters to use with notebook. These will affect
# what data is used, where data is located (if already in disk),
# pipeline modules run in this data, and type of background
# subtraction (if any). The list of parameters are:
#
# * demo_mode
# * channel
# * band
# * directories with data
# * pipeline modules
# * Backgroud subtraction method

# %%
# Basic import necessary for configuration
import os

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Note that <code>demo_mode</code> must be set appropriately below.
# </div>
#
# Set <code>demo_mode = True </code> to run in demonstration mode. In this mode this
# notebook will download example data from the
# Barbara A. Mikulski Archive for Space Telescopes (MAST) and process it through the pipeline.
# This will all happen in a local directory unless modified
# in [Section 3](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data)) below.
#
# Set <code>demo_mode = False</code> if you want to process your own data that has already
# been downloaded and provide the location of the data.<br>

# %% [markdown]
# Explanation of uncal file naming, example `jw01355017001_02101_00001_mirifulong_uncal.fits`:
# - `jw`    = JWST
# - `01355` = TEMPLATES program ID number
# - `017`   = Observation number
# - `001`   = Visit number
# - `02101` = The `02` exposures are on-source, the `04` exposures are backgrounds.
# - `00001` = Exposure number, 1 to 4 for each dither position at both on- and off-source
# - `mirifulong` = Long- (or short-) wavelength MRS detector. Note this is not the same as the SHORT/MEDIUM/LONG grating specifications (it's confusing!). Channels 1 and 2 are always on the short detector, 3 and 4 always on the long detector, regardless of the grating setting.
# - `uncal` = We are starting on the raw uncalibrated exposures
# - `fits`  = This file is in the "Flexible Image Transport System" format

# %% [markdown]
# The following is the observation information regarding our object/area of interest. We are interested in the MIRI MRS data of Target **J1127+4228** and its background. This means that observation number of our target is <u>**3**</u> and for our background it is <u>**7**</u>
#
# Visit Status Report for JWST 3722
# Mon Nov 24 01:01:20 EST 2025
# |Observation|	Visit|	Status|	Target(s) |	Templates |	Hours |
# |:---:|:---:|:---:|:---|:---|:---:|
# |17 |	1|	Archived|	J1609+6045-BACKGROUND | MIRI Medium Resolution Spectroscopy |  1.11|
# |18 |	1|	Archived|	J1609+6045 | MIRI Medium Resolution Spectroscopy | 3.51	|
# |9 |	1|	Archived|	J1127+4228 | NIRSpec IFU Spectroscopy | 1.52	|
# |10 |	1|	Archived|	J1127+4228-BACKGROUND | NIRSpec IFU Spectroscopy | 0.66	|
# |<font color="#0033ffff">3 </font>|	<font color="#0033ffff">1 </font>|	<font color="#0033ffff">Archived </font>|	<font color="#0033ffff">J1127+4228 </font> | <font color="#0033ffff">MIRI Medium Resolution Spectroscopy </font> | <font color="#0033ffff">3.73 </font>	|
# |<font color="#0033ffff">7 </font>|	<font color="#0033ffff">1 </font>|	<font color="#0033ffff">Archived </font>|	<font color="#0033ffff">J1127+4228-BACKGROUND</font> | <font color="#0033ffff">MIRI Medium Resolution Spectroscopy </font> | <font color="#0033ffff">0.97 </font>	|
# |4 |	1|	Archived|	J1053+0556 | MIRI Medium Resolution Spectroscopy | 4.56	|
# |8 |	1|	Archived|	J1053+0556-BACKGROUND | MIRI Medium Resolution Spectroscopy | 0.56	|

# %%
# Set parameters for demo_mode, channel, band, data mode directories, and 
# processing steps.

# -----------------------------Demo Mode---------------------------------
demo_mode = True

if demo_mode:
    print('Running in demonstration mode using Data of Interest!')

# --------------------------User Mode Directories------------------------
# If demo_mode = False, look for user data in these paths
if not demo_mode:
    # Set directory paths for processing specific data; these will need
    # to be changed to your local directory setup (below are given as
    # examples)
    user_home_dir = os.path.expanduser('~')

    # Point to where science observation data are
    # Assumes uncalibrated data in sci_dir/uncal/ and results in stage1,
    # stage2, stage3 directories
    sci_dir = os.path.join(user_home_dir, 'FlightData/APT1523/data/Obs003/')

    # Point to where background observation data are
    # Assumes uncalibrated data in bg_dir/uncal/ and results in stage1,
    # stage2, stage3 directories
    bg_dir = os.path.join(user_home_dir, 'FlightData/APT1523/data/Obs004/')
    #bg_dir = '' # If no background observation, use an empty string

# --------------------------Set Processing Steps--------------------------
# Whether or not to process only data from a given MRS band/channel (useful
# if overriding reference files)
# Note that BOTH parameters must be set in order to work

# Channel 	|       Sub-band	    | Wavelength Range (µm)
# 1	        |  SHORT / MED / LONG   | 4.9–7.7
# 2	        |  SHORT / MED / LONG	| 7.5–11.9
# 3	        |  SHORT / MED / LONG	| 11.5–18.3
# 4	        |  SHORT / MED / LONG	| 17.7–28.8
# !!! Remember, Channels 1-2 are mirifushort, and Channels 3-4 are mirifulong
# these are not the same as the sub-bands SHORT, MEDIUM, LONG !!!

use_ch = ''  # '12' or '34'
use_band = ''  # 'SHORT', 'MEDIUM', or 'LONG'

# Individual pipeline stages can be turned on/off here.  Note that a later
# stage won't be able to run unless data products have already been
# produced from the prior stage.

# Science processing
dodet1 = True  # calwebb_detector1
dospec2 = True  # calwebb_spec2
dospec3 = True  # calwebb_spec3
doviz = True # Visualize calwebb_spec3 results

# Background processing
dodet1bg = True  # calwebb_detector1
dospec2bg = True  # calwebb_spec2 (needed for Master Background subtraction)

# How should background subtraction using any dedicated backgrounds be done?
# If none are selected, cubes will not be background subtracted.  1d spectra
# will always use local annular background subtraction for point sources.
# Note that if using master-background subtraction, background observations
# must be selected above to process through spec2 (dospec2bg = True).
master_bg = True  # Master-background subtraction in spec3 (subtract spectrum generated from the backgrounds).  This is the default pipeline setting.
pixel_bg = False  # Pixel-based background subtraction in spec2 (direct pixel subtraction).
# Out:
# Running in demonstration mode using Data of Interest!

# %% [markdown]
# ### Set CRDS context and server
# Before importing <code>CRDS</code> and <code>JWST</code> modules, we need to configure our environment. This includes defining a CRDS cache directory in which to keep the reference files that will be used by the calibration pipeline.
#
# If the root directory for the local CRDS cache directory has not been set already, it will be set to create one in the home directory.

# %% [markdown]
# ### What is CRDS (Calibration Reference Data System)?
# [CRDS is a metadata-based system that maps datasets to data using mapping rules. The calibration pipelines, pre-archive processing, and reprocessing of HST and JWST observations, use CRDS to identify the best reference files for the data.](https://www.stsci.edu/hst/instrumentation/reference-data-for-calibration-and-tools)
#
# CRDS mathes data with calibration files (darks, flats, bad pixel maps, distortion models(?), etc.) based on the pipeline version, context, and the data's metadata. It then retrieves those calibration files from a server to be used in the pipeline. These files are stored elsewhere and are not stored locally after the pipeline has been run.
#
# The code cell below sets up the connection between your machine and this system, if it has not been set already.

# %%
# ------------------------Set CRDS context and paths----------------------

# Set CRDS reference file context.  Leave commented-out to use the default context
# (latest reference files associated with the calibration pipeline version)
# or set a specific context here.
#%env CRDS_CONTEXT  jwst_1295.pmap

# Check whether the local CRDS cache directory has been set.
# If not, set it to the user home directory
if (os.getenv('CRDS_PATH') is None):
    os.environ['CRDS_PATH'] = os.path.join(os.path.expanduser('~'), 'crds')
# Check whether the CRDS server URL has been set.  If not, set it.
if (os.getenv('CRDS_SERVER_URL') is None):
    os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# Echo CRDS path and context in use
print('CRDS local filepath:', os.environ['CRDS_PATH'])
print('CRDS file server:', os.environ['CRDS_SERVER_URL'])
# Out:
# CRDS local filepath: /home/fatih/crds_cache
# CRDS file server: https://jwst-crds.stsci.edu

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 2.<font color='white'>-</font>Package Imports<a class="anchor" id="intro"></a>
# ------------------

# %%
# Use the entire available screen width for this notebook (purely a visual tweak)
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Basic system utilities for interacting with files
# ----------------------General Imports------------------------------------
import glob
import copy
import time
from pathlib import Path

# Numpy for doing calculations
import numpy as np

# -----------------------Astropy Imports-----------------------------------
# Astropy utilities for opening FITS and ASCII files, and downloading demo files
from astropy.io import fits
from astroquery.mast import Observations

# -----------------------Plotting Imports----------------------------------
# Matplotlib for making plots
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
# --------------JWST Calibration Pipeline Imports---------------------------
# Import the base JWST and calibration reference data packages
import jwst
import crds

# JWST pipelines (each encompassing many steps)
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Spec3Pipeline

# JWST pipeline utilities
from jwst import datamodels  # JWST datamodels

# Relationships between multiple exposures are captured in an association, which is a means of identifying
# a set of exposures that belong together and may be dependent upon one another. The association concept 
# permits exposures to be calibrated, archived, retrieved, and reprocessed as a set rather than as individual
# objects
from jwst.associations import asn_from_list as afl  # Tools for creating association files 
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase  # Definition of a Lvl2 association file
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base  # Definition of a Lvl3 association file

from jwst.stpipe import Step  # Import the wrapper class for pipeline steps

# Echo pipeline version and CRDS context in use
print("JWST Calibration Pipeline Version = {}".format(jwst.__version__))
print("Using CRDS Context = {}".format(crds.get_context_name('jwst')))
# Out:
# JWST Calibration Pipeline Version = 1.19.2
# Using CRDS Context = jwst_1413.pmap

# %% [markdown]
# ### Define convenience functions

# %%
# Define a convenience function to select only files of a given channel/band from an input set
# Used if overriding reference files for a specific channel/band in a previous cell
def select_ch_band_files(files, use_ch, use_band):
    if ((use_ch != '') & (use_band != '')):
        keep = np.zeros(len(files))
        for ii in range(0, len(files)):
            with fits.open(files[ii]) as hdu:
                hdu.verify()
                hdr = hdu[0].header
                if ((hdr['CHANNEL'] == use_ch) & (hdr['BAND'] == use_band)):
                    keep[ii] = 1
        indx = np.where(keep == 1)
        files_culled = files[indx]
    else:
        files_culled = files
        
    return files_culled

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 3.<font color='white'>-</font>Demo Mode Setup<a class="anchor" id="intro"></a> (ignore if not using demo data)
# ------------------
# If running in demonstration mode, set up the program information to
# retrieve the uncalibrated data automatically from MAST using
# [astroquery](https://astroquery.readthedocs.io/en/latest/mast/mast.html).
# MAST allows for flexibility of searching by the proposal ID and the
# observation ID instead of just filenames.<br>
#
# More information about the JWST file naming conventions can be found at:
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/file_naming.html

# %%
# Set up the program information and paths for demo program
if demo_mode:
    print('Running in demonstration mode and will download example data from MAST!')
    program = "03722" # "01523"
    sci_observtn = "003"  # "003" # observation ID
    back_observtn = "007" # "004" # background obs ID
    visit = "001" 
    
    # These create a folder tree
    # mrs_demo_data/
    # ├── Obs003/
    # │  └── uncal/
    # └── Obs007/
    #    └── uncal/cd .
    basedir = os.path.join('.', 'mrs_data')
    download_dir = basedir
    sci_dir = os.path.join(basedir, 'Obs' + sci_observtn)
    bg_dir = os.path.join(basedir, 'Obs' + back_observtn)
    uncal_dir = os.path.join(sci_dir, 'uncal')
    uncal_bgdir = os.path.join(bg_dir, 'uncal')

    # Ensure filepaths for input data exist
    if not os.path.exists(uncal_dir):
        os.makedirs(uncal_dir)
    if not os.path.exists(uncal_bgdir):
        os.makedirs(uncal_bgdir)

# When using your own data, these would come from your own FITS headers or proposal info,
# or from the following website using Program ID 
# https://www.stsci.edu/jwst/science-execution/program-information
# Out:
# Running in demonstration mode and will download example data from MAST!

# %% [markdown]
# Identify list of science (SCI) and background (BG) uncalibrated files associated with visits.
# <div class="alert alert-block alert-warning">
# Selects only <i>mirifu</i> data (ignores MIRI imager).
# </div>

# %%
# Obtain a list of observation IDs for the specified demo program
if demo_mode:
    # Science data
    sci_obs_id_table = Observations.query_criteria(instrument_name=["MIRI/IFU"],
                                                   provenance_name=["CALJWST"],  # Executed observations
                                                   obs_id=['jw' + program + '-o' + sci_observtn + '*']
                                                   )

    # Background data
    bg_obs_id_table = Observations.query_criteria(instrument_name=["MIRI/IFU"],
                                                  provenance_name=["CALJWST"],  # Executed observations
                                                  obs_id=['jw' + program + '-o' + back_observtn + '*']
                                                  )


# This cell asks MAST for the metadata of the observations with
# given parameters such as the program ID, observation ID etc.

# Trying out how these tables work and look
#print(type(sci_obs_id_table))
#print(sci_obs_id_table.columns)
#print(sci_obs_id_table['obs_id'])
#print(bg_obs_id_table['obs_id'])
print(len(sci_obs_id_table))
print(sci_obs_id_table.colnames)   # see what metadata fields are present
print(sci_obs_id_table[0])        # peek first rows
# Out:
# 8
# ['intentType', 'obs_collection', 'provenance_name', 'instrument_name', 'project', 'filters', 'wavelength_region', 'target_name', 'target_classification', 'obs_id', 's_ra', 's_dec', 'dataproduct_type', 'proposal_pi', 'calib_level', 't_min', 't_max', 't_exptime', 'em_min', 'em_max', 'obs_title', 't_obs_release', 'proposal_id', 'proposal_type', 'sequence_number', 's_region', 'jpegURL', 'dataURL', 'dataRights', 'mtFlag', 'srcDen', 'obsid', 'objID']
# intentType obs_collection provenance_name instrument_name project  filters   wavelength_region target_name     target_classification                    obs_id                     s_ra              s_dec       dataproduct_type   proposal_pi    calib_level       t_min             t_max       t_exptime em_min  em_max                                                obs_title                                                t_obs_release  proposal_id proposal_type sequence_number                                                       s_region                                                                                jpegURL                                                     dataURL                            dataRights mtFlag srcDen   obsid     objID
# ---------- -------------- --------------- --------------- ------- ---------- ----------------- ----------- ------------------------------ --------------------------------- ------------------ ----------------- ---------------- ---------------- ----------- ----------------- ----------------- --------- ------ ------- ------------------------------------------------------------------------------------------------------- -------------- ----------- ------------- --------------- ------------------------------------------------------------------------------------------------------------------- ----------------------------------------------------------- ------------------------------------------------------------ ---------- ------ ------ --------- ---------
#    science           JWST         CALJWST        MIRI/IFU    JWST CH2-MEDIUM          INFRARED  J1127+4228 Galaxy; High-redshift galaxies jw03722-o003_t003_miri_ch2-medium 171.81115416666665 42.47317777777778             cube Nesvadba, Nicole           3 60444.81015311342 60444.93265278935  1911.192 8670.0 10130.0 A new window onto star formation regulation in the most intense, dusty starbursts in the early Universe 60810.23704865        3722            GO              -- POLYGON 171.809731012 42.472315203 171.809731012 42.474298536 171.812291939 42.474298536 171.812291939 42.472315203 mast:JWST/product/jw03722-o003_t003_miri_ch2-medium_s3d.jpg mast:JWST/product/jw03722-o003_t003_miri_ch2-medium_s3d.fits     PUBLIC  False    nan 250872567 996441604

# %%
# Turn the list of visits into a list of uncalibrated data files
if demo_mode:
    # Define types of files to select
    file_dict = {'uncal': {'product_type': 'SCIENCE', 'productSubGroupDescription': 'UNCAL', 'calib_level': [1]}}

    # Science files
    sci_files_to_download = []
    # Loop over visits identifying uncalibrated files that are associated with them
    for exposure in (sci_obs_id_table): # iterate over each row/exposure which has the metadata including the url
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             calib_level=query_dict['calib_level'])
            sci_files_to_download.extend(filtered_products['dataURI']) # basically collects the URLs of the uncal 
                                                                       # files to download. you then pass these URLs
                                                                       # to the <Observations.download_file> method

    # Background files
    bg_files_to_download = []
    # Loop over visits identifying uncalibrated files that are associated with them
    for exposure in (bg_obs_id_table):
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             calib_level=query_dict['calib_level'])
            bg_files_to_download.extend(filtered_products['dataURI'])

    # Cull to a unique list of files that contain 'mirifu' in the filename
    # (i.e., not MIRI imager)
    sci_files_to_download = np.unique([i for i in sci_files_to_download if 'mirifu' in i])
    bg_files_to_download = np.unique([i for i in bg_files_to_download if 'mirifu' in i])

    print("Science files selected for downloading: ", len(sci_files_to_download))
    print("Background selected for downloading: ", len(bg_files_to_download))
# Out:
# Science files selected for downloading:  16
# Background selected for downloading:  4

# %% [markdown]
# Download all the uncal files and place them into the appropriate directories.
#
# <div class="alert alert-block alert-warning">
# Warning: If this notebook is halted during this step the downloaded file may be incomplete, and cause crashes later on!
# </div>

# %%
if demo_mode:
    for filename in sci_files_to_download:
        sci_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_dir, Path(filename).name))
    for filename in bg_files_to_download:
        bg_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_bgdir, Path(filename).name))

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 4.<font color='white'>-</font>Directory Setup<a class="anchor" id="intro"></a>
# ------------------
# Set up detailed paths to input/output stages here.

# %%
# Define output subdirectories to keep science data products organized
uncal_dir = os.path.join(sci_dir, 'uncal')  # Uncalibrated pipeline inputs should be here
det1_dir = os.path.join(sci_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
spec2_dir = os.path.join(sci_dir, 'stage2')  # calwebb_spec2 pipeline outputs will go here
spec3_dir = os.path.join(sci_dir, 'stage3')  # calwebb_spec3 pipeline outputs will go here

# Output subdirectories to keep background data products organized
uncal_bgdir = os.path.join(bg_dir, 'uncal')  # Uncalibrated pipeline inputs should be here
det1_bgdir = os.path.join(bg_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
spec2_bgdir = os.path.join(bg_dir, 'stage2')  # calwebb_spec2 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)
if (bg_dir != ''):
    if not os.path.exists(det1_bgdir):
        os.makedirs(det1_bgdir)
    if not os.path.exists(spec2_bgdir):
        os.makedirs(spec2_bgdir)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# If there is no background folder, ensure we don't try to process it.
# </div>

# %%
if (bg_dir == ''):
    dodet1bg = False
    dospec2bg = False

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 106.9801 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 5.<font color='white'>-</font>Detector1 Pipeline<a class="anchor" id="det1"></a>
# ------------------
# In this section we process our data through the calwebb_detector1
# pipeline to create Stage 1 data products (i.e., uncalibrated slope
# images of the form *rate.fits).  These data products have units of DN/s.<BR><BR>
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_detector1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# To override certain steps and reference files, use the examples provided below.<br>
# E.g., turn on detection of cosmic ray showers.
# </div>

# %%
# Set up a dictionary to define how the Detector1 pipeline should be configured
# -----------Detector 1 Configuration Cell-----------
# *_uncal.fits -> *_rate.fits files

# Boilerplate dictionary setup

# This line creates EMPTY dictionaries within the "det1dict" dictionary for each step
det1dict = {}
det1dict['group_scale'], det1dict['dq_init'], det1dict['emicorr'], det1dict['saturation'], det1dict['ipc'] = {}, {}, {}, {}, {}
det1dict['firstframe'], det1dict['lastframe'], det1dict['reset'], det1dict['linearity'], det1dict['rscd'] = {}, {}, {}, {}, {}
det1dict['dark_current'], det1dict['refpix'], det1dict['charge_migration'], det1dict['jump'], det1dict['ramp_fit'] = {}, {}, {}, {}, {}
det1dict['gain_scale'] = {}

# Overrides for whether or not certain steps should be skipped (example)
#det1dict['emicorr']['skip'] = True

# Option to use the first frame for very bright MIRI data that otherwise saturates fast enough to provide no slope
# Turning this on makes it use the first frame for the very bright sources
#det1dict['firstframe']['bright_use_group1'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path

# This whole chunk then configures the detector 1 pipeline by giving values to those empty dictionaries
# Usually CRDS will pull out the reference files but you can choose to use manual masks, reference files etc.

#det1dict['dq_init']['override_mask'] = 'myfile.fits' # Bad pixel mask
#det1dict['saturation']['override_saturation'] = 'myfile.fits' # Saturation
#det1dict['reset']['override_reset'] = 'myfile.fits' # Reset
#det1dict['linearity']['override_linearity'] = 'myfile.fits' # Linearity
#det1dict['rscd']['override_rscd'] = 'myfile.fits' # RSCD
#det1dict['dark_current']['override_dark'] = 'myfile.fits' # Dark current subtraction
#det1dict['jump']['override_gain'] = 'myfile.fits' # Gain used by jump step
#det1dict['ramp_fit']['override_gain'] = 'myfile.fits' # Gain used by ramp fitting step
#det1dict['jump']['override_readnoise'] = 'myfile.fits' # Read noise used by jump step
#det1dict['ramp_fit']['override_readnoise'] = 'myfile.fits' # Read noise used by ramp fitting step

# Turn on multi-core processing for jump step (off by default).  Choose what fraction of cores to use (quarter, half, or all)
det1dict['jump']['maximum_cores'] = 'all'

# Toggle detection of cosmic ray showers if desired (on by default) (set it to false if want to turn it off)
#det1dict['jump']['find_showers'] = True

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Below an example of how to insert custom pipeline steps using the
# pre-hook/post-hook framework.
#
# For more information see [Tips and Trick for working with the JWST Pipeline](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/tips-and-tricks-for-working-with-the-jwst-pipeline)
#     </div>

# %%
# Custom pipeline step example ?
# Migh be useful once i know how this virtual machine works


# Define a new step called XplyStep that multiplies everything by 1.0
# I.e., it does nothing, but could be changed to do something more interesting.
class XplyStep(Step):
    spec = '''
    '''
    class_alias = 'xply'

    def process(self, input_data):
        with datamodels.open(input_data) as model:
            result = model.copy()
        sci = result.data
        sci = sci * 1.0
        result.data = sci
        self.log.info('Multiplied everything by one in custom step!')
        return result


# And here we'll insert it into our pipeline dictionary to be run at the end right after the gain_scale step
det1dict['gain_scale']['post_hooks'] = [XplyStep]

# %% [markdown]
# ### Calibrating Science Files
# Look for input science files and run calwebb_detector1 pipeline using the call method.

# %%
# Look for input files of the form *uncal.fits from the science observation
sstring = os.path.join(uncal_dir, 'jw*mirifu*uncal.fits')
uncal_files = np.array(sorted(glob.glob(sstring))) # returns all files matchin the sstring pattern in /uncal_dir
# Check that these are the band/channel to use
uncal_files = select_ch_band_files(uncal_files, use_ch, use_band) # We can look for certain channels/bands if desired

print('Found ' + str(len(uncal_files)) + ' science input files')

# uncal_files is a list that contains the paths to the uncalibrated SCIENCE FITS files
# Out:
# Found 16 science input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1:
    for file in uncal_files:
        # Using det1dict configured above, goes through all fines in Obs/003/uncal/ and saves
        # them into our Obs003/stage1/ after applying det1dict parameters
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_dir) 
else:
    print('Skipping Detector1 processing for SCI data')

# %% [markdown]
# ### Calibrating Background Files
# Look for input background files and run calwebb_detector1
# pipeline using the call method.

# %%
# Now let's look for input files of the form *uncal.fits from the background
# observations
sstring = os.path.join(uncal_bgdir, 'jw*mirifu*uncal.fits')
uncal_files = np.array(sorted(glob.glob(sstring)))
# Check that these are the band/channel to use
uncal_files = select_ch_band_files(uncal_files, use_ch, use_band)

print('Found ' + str(len(uncal_files)) + ' background input files')
# Out:
# Found 4 background input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1bg:
    for file in uncal_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_bgdir)
else:
    print('Skipping Detector1 processing for BG data')
# Out:
# 2025-11-24 00:18:31,833 - stpipe - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2025-11-24 00:18:31,844 - stpipe - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2025-11-24 00:18:31,851 - stpipe - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2025-11-24 00:18:31,859 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2025-11-24 00:18:31,871 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2025-11-24 00:18:31,872 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-11-24 00:18:31,872 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-11-24 00:18:31,873 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-11-24 00:18:31,874 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-11-24 00:18:31,876 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-11-24 00:18:31,877 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-11-24 00:18:31,878 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-11-24 00:18:31,878 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-11-24 00:18:31,879 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-11-24 00:18:31,880 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-11-24 00:18:31,881 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-11-24 00:18:31,882 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-11-24 00:18:31,883 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2025-11-24 00:18:31,884 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-11-24 00:18:31,884 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-11-24 00:18:31,885 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2025-11-24 00:18:31,886 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-11-24 00:18:31,887 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-11-24 00:18:31,888 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-11-24 00:18:31,889 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - XplyStep instance created.
# 2025-11-24 00:18:31,964 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_demo_data/Obs007/uncal/jw03722007001_02101_00001_mirifulong_uncal.fits'),).
# 2025-11-24 00:18:31,975 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_demo_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-11-24 00:18:31,988 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02101_00001_mirifulong_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2025-11-24 00:18:31,990 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits'.
# 2025-11-24 00:18:31,991 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits'.
# 2025-11-24 00:18:31,991 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits'.
# 2025-11-24 00:18:31,991 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits'.
# 2025-11-24 00:18:31,992 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-11-24 00:18:31,992 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits'.
# 2025-11-24 00:18:31,993 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits'.
# 2025-11-24 00:18:31,993 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0016.fits'.
# 2025-11-24 00:18:31,994 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits'.
# 2025-11-24 00:18:31,995 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-11-24 00:18:31,995 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-11-24 00:18:31,996 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-11-24 00:18:31,996 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2025-11-24 00:18:32,606 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:32,612 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-11-24 00:18:32,613 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-11-24 00:18:32,614 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-11-24 00:18:32,685 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:32,692 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits
# 2025-11-24 00:18:33,186 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-11-24 00:18:33,257 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:33,257 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-11-24 00:18:33,327 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:33,334 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits
# 2025-11-24 00:18:33,334 - stpipe.Detector1Pipeline.saturation - INFO - Using SUPERBIAS reference file N/A
# 2025-11-24 00:18:33,353 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:33,362 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:33,476 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2025-11-24 00:18:34,000 - stcal.saturation.saturation - INFO - Detected 448 saturated pixels
# 2025-11-24 00:18:34,031 - stcal.saturation.saturation - INFO - Detected 80 A/D floor pixels
# 2025-11-24 00:18:34,036 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-11-24 00:18:34,115 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:34,115 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2025-11-24 00:18:34,182 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:34,296 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-11-24 00:18:34,367 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:34,487 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-11-24 00:18:34,560 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:34,566 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits
# 2025-11-24 00:18:34,682 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:34,691 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:34,887 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-11-24 00:18:34,962 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:34,968 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits
# 2025-11-24 00:18:35,087 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:35,096 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:18:35,505 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-11-24 00:18:35,577 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:35,583 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0016.fits
# 2025-11-24 00:18:35,678 - jwst.rscd.rscd_sub - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-11-24 00:18:35,680 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-11-24 00:18:35,750 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:35,757 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits
# 2025-11-24 00:18:38,507 - stpipe.Detector1Pipeline.dark_current - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2025-11-24 00:18:38,508 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2025-11-24 00:18:38,509 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-11-24 00:18:42,367 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-11-24 00:18:42,455 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:42,456 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2025-11-24 00:18:42,529 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:42,530 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2025-11-24 00:18:42,617 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:42,622 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2025-11-24 00:18:42,623 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = all
# 2025-11-24 00:18:42,764 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2025-11-24 00:18:42,766 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2025-11-24 00:18:43,106 - stcal.jump.jump - INFO - Executing two-point difference method
# 2025-11-24 00:18:43,107 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2025-11-24 00:18:46,238 - stcal.jump.jump - INFO - Flagging Showers
# 2025-11-24 00:18:59,247 - stcal.jump.jump - INFO - Total showers= 8746
# 2025-11-24 00:18:59,247 - stcal.jump.jump - INFO - Total elapsed time = 16.141 sec
# 2025-11-24 00:18:59,294 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 16.671524
# 2025-11-24 00:18:59,296 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2025-11-24 00:18:59,378 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:59,379 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-11-24 00:18:59,446 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:18:59,625 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2025-11-24 00:18:59,626 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2025-11-24 00:18:59,670 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2025-11-24 00:18:59,670 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2025-11-24 00:18:59,888 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2025-11-24 00:18:59,894 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2025-11-24 00:18:59,895 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-11-24 00:19:04,569 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 4.672148704528809
# 2025-11-24 00:19:04,608 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2025-11-24 00:19:04,675 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:19:04,691 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-11-24 00:19:04,691 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-11-24 00:19:04,756 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:19:04,770 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2025-11-24 00:19:04,771 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply done
# 2025-11-24 00:19:04,772 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-11-24 00:19:04,838 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:19:04,853 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-11-24 00:19:04,853 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-11-24 00:19:04,916 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply running with args (<CubeModel(2, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2025-11-24 00:19:04,934 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2025-11-24 00:19:04,935 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply done
# 2025-11-24 00:19:04,937 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-11-24 00:19:05,021 - stpipe.Detector1Pipeline - INFO - Saved model in ./mrs_demo_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rateints.fits
# 2025-11-24 00:19:05,021 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2025-11-24 00:19:05,023 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1413.pmap
# 2025-11-24 00:19:05,070 - stpipe.Detector1Pipeline - INFO - Saved model in ./mrs_demo_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits
# 2025-11-24 00:19:05,071 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2025-11-24 00:19:05,071 - jwst.stpipe.core - INFO - Results used jwst version: 1.19.2
# 2025-11-24 00:19:05,089 - stpipe - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2025-11-24 00:19:05,101 - stpipe - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2025-11-24 00:19:05,109 - stpipe - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2025-11-24 00:19:05,117 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2025-11-24 00:19:05,128 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2025-11-24 00:19:05,129 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-11-24 00:19:05,130 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-11-24 00:19:05,131 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-11-24 00:19:05,131 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-11-24 00:19:05,132 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-11-24 00:19:05,133 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-11-24 00:19:05,135 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-11-24 00:19:05,136 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-11-24 00:19:05,137 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-11-24 00:19:05,138 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-11-24 00:19:05,139 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-11-24 00:19:05,142 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-11-24 00:19:05,145 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2025-11-24 00:19:05,146 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-11-24 00:19:05,148 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-11-24 00:19:05,150 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2025-11-24 00:19:05,152 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-11-24 00:19:05,155 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-11-24 00:19:05,156 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-11-24 00:19:05,158 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - XplyStep instance created.
# 2025-11-24 00:19:05,237 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_demo_data/Obs007/uncal/jw03722007001_02101_00001_mirifushort_uncal.fits'),).
# 2025-11-24 00:19:05,249 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_demo_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-11-24 00:19:05,265 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02101_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2025-11-24 00:19:05,268 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2025-11-24 00:19:05,268 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2025-11-24 00:19:05,269 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2025-11-24 00:19:05,270 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2025-11-24 00:19:05,270 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-11-24 00:19:05,271 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2025-11-24 00:19:05,272 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2025-11-24 00:19:05,272 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits'.
# 2025-11-24 00:19:05,273 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2025-11-24 00:19:05,273 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-11-24 00:19:05,274 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-11-24 00:19:05,274 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-11-24 00:19:05,275 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2025-11-24 00:19:05,781 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:05,785 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-11-24 00:19:05,786 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-11-24 00:19:05,787 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-11-24 00:19:05,850 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:05,857 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2025-11-24 00:19:06,110 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-11-24 00:19:06,175 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:06,176 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-11-24 00:19:06,237 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:06,244 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2025-11-24 00:19:06,245 - stpipe.Detector1Pipeline.saturation - INFO - Using SUPERBIAS reference file N/A
# 2025-11-24 00:19:06,279 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:06,287 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:06,352 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2025-11-24 00:19:06,796 - stcal.saturation.saturation - INFO - Detected 5253 saturated pixels
# 2025-11-24 00:19:06,826 - stcal.saturation.saturation - INFO - Detected 90 A/D floor pixels
# 2025-11-24 00:19:06,833 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-11-24 00:19:06,895 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:06,896 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2025-11-24 00:19:06,954 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:07,022 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-11-24 00:19:07,085 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:07,154 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-11-24 00:19:07,219 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:07,225 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2025-11-24 00:19:07,358 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:07,366 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:07,494 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-11-24 00:19:07,558 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:07,564 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2025-11-24 00:19:07,591 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:07,600 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:07,980 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-11-24 00:19:08,046 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:08,052 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits
# 2025-11-24 00:19:08,134 - jwst.rscd.rscd_sub - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-11-24 00:19:08,136 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-11-24 00:19:08,200 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:08,206 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2025-11-24 00:19:08,783 - stpipe.Detector1Pipeline.dark_current - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2025-11-24 00:19:08,784 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2025-11-24 00:19:08,784 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-11-24 00:19:09,110 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-11-24 00:19:09,175 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:09,176 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2025-11-24 00:19:09,238 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:09,238 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2025-11-24 00:19:09,301 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:09,306 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2025-11-24 00:19:09,306 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = all
# 2025-11-24 00:19:09,371 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2025-11-24 00:19:09,372 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2025-11-24 00:19:09,475 - stcal.jump.jump - INFO - Executing two-point difference method
# 2025-11-24 00:19:09,475 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2025-11-24 00:19:11,827 - stcal.jump.jump - INFO - Flagging Showers
# 2025-11-24 00:19:21,578 - stcal.jump.jump - INFO - Total showers= 1623
# 2025-11-24 00:19:21,579 - stcal.jump.jump - INFO - Total elapsed time = 12.1036 sec
# 2025-11-24 00:19:21,632 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 12.326495
# 2025-11-24 00:19:21,635 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2025-11-24 00:19:21,705 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:21,705 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-11-24 00:19:21,769 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# ...
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-11-24 00:19:34,534 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02102_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2025-11-24 00:19:34,536 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2025-11-24 00:19:34,537 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2025-11-24 00:19:34,538 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2025-11-24 00:19:34,538 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2025-11-24 00:19:34,538 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-11-24 00:19:34,539 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2025-11-24 00:19:34,539 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2025-11-24 00:19:34,540 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits'.
# 2025-11-24 00:19:34,540 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2025-11-24 00:19:34,540 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-11-24 00:19:34,541 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-11-24 00:19:34,541 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-11-24 00:19:34,541 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2025-11-24 00:19:34,723 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:34,727 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-11-24 00:19:34,728 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-11-24 00:19:34,730 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-11-24 00:19:34,789 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:34,795 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2025-11-24 00:19:34,879 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-11-24 00:19:34,944 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:34,945 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-11-24 00:19:35,012 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,019 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2025-11-24 00:19:35,019 - stpipe.Detector1Pipeline.saturation - INFO - Using SUPERBIAS reference file N/A
# 2025-11-24 00:19:35,043 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,051 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,073 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2025-11-24 00:19:35,199 - stcal.saturation.saturation - INFO - Detected 2476 saturated pixels
# 2025-11-24 00:19:35,207 - stcal.saturation.saturation - INFO - Detected 33 A/D floor pixels
# 2025-11-24 00:19:35,211 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-11-24 00:19:35,273 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,274 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2025-11-24 00:19:35,336 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,361 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-11-24 00:19:35,427 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,454 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-11-24 00:19:35,516 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,522 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2025-11-24 00:19:35,623 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,632 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,706 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-11-24 00:19:35,772 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:35,778 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2025-11-24 00:19:35,819 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,828 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-11-24 00:19:35,937 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-11-24 00:19:36,000 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:36,006 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits
# 2025-11-24 00:19:36,046 - jwst.rscd.rscd_sub - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-11-24 00:19:36,048 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-11-24 00:19:36,115 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:36,121 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2025-11-24 00:19:36,422 - stpipe.Detector1Pipeline.dark_current - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2025-11-24 00:19:36,423 - stcal.dark_current.dark_sub - INFO - Science data nints=1, ngroups=20, nframes=1, groupgap=0
# 2025-11-24 00:19:36,423 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-11-24 00:19:36,616 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-11-24 00:19:36,678 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:36,679 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2025-11-24 00:19:36,741 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:36,741 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2025-11-24 00:19:36,802 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:36,807 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2025-11-24 00:19:36,808 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = all
# 2025-11-24 00:19:36,829 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2025-11-24 00:19:36,830 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2025-11-24 00:19:36,872 - stcal.jump.jump - INFO - Executing two-point difference method
# 2025-11-24 00:19:36,873 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2025-11-24 00:19:38,164 - stcal.jump.jump - INFO - Flagging Showers
# 2025-11-24 00:19:39,998 - stcal.jump.jump - INFO - Total showers= 559
# 2025-11-24 00:19:39,998 - stcal.jump.jump - INFO - Total elapsed time = 3.12598 sec
# 2025-11-24 00:19:40,014 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 3.206170
# 2025-11-24 00:19:40,016 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2025-11-24 00:19:40,085 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:40,085 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-11-24 00:19:40,149 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:40,176 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2025-11-24 00:19:40,176 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2025-11-24 00:19:40,195 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2025-11-24 00:19:40,195 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2025-11-24 00:19:40,243 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2025-11-24 00:19:40,247 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2025-11-24 00:19:40,247 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-11-24 00:19:41,109 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 0.860060453414917
# 2025-11-24 00:19:41,143 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2025-11-24 00:19:41,207 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:41,220 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-11-24 00:19:41,220 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-11-24 00:19:41,283 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:41,296 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2025-11-24 00:19:41,297 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply done
# 2025-11-24 00:19:41,298 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-11-24 00:19:41,362 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:41,375 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-11-24 00:19:41,376 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-11-24 00:19:41,442 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply running with args (<CubeModel(1, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2025-11-24 00:19:41,454 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2025-11-24 00:19:41,455 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Step xply done
# 2025-11-24 00:19:41,457 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-11-24 00:19:41,501 - stpipe.Detector1Pipeline - INFO - Saved model in ./mrs_demo_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rateints.fits
# 2025-11-24 00:19:41,501 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2025-11-24 00:19:41,502 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1413.pmap
# 2025-11-24 00:19:41,547 - stpipe.Detector1Pipeline - INFO - Saved model in ./mrs_demo_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rate.fits
# 2025-11-24 00:19:41,548 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2025-11-24 00:19:41,548 - jwst.stpipe.core - INFO - Results used jwst version: 1.19.2

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 23568.6723 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 6.<font color='white'>-</font>Spec2 Pipeline<a class="anchor" id="spec2"></a>
# ------------------
#
# In this section we process our countrate (slope) image products from
# Stage 1 (calwebb_detector1) through the Spec2 (calwebb_spec2) pipeline
# in order to produce Stage 2
# data products (i.e., calibrated slope images and quick-look data cubes
# and 1d spectra).  These data products have units of MJy/sr (or Jy for
# extracted point-source spectra).
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_spec2
#
# <div class="alert alert-block alert-warning">
# If pixel-based background subtraction was chosen above, this will be
# applied during this stage.
#
# To override certain steps and reference files use the examples below.
# </div>

# %%
time_spec2 = time.perf_counter()

# %%
# Set up a dictionary to define how the Spec2 pipeline should be configured.

# Boilerplate dictionary setup
spec2dict = {}
spec2dict['assign_wcs'], spec2dict['badpix_selfcal'], spec2dict['bkg_subtract'], spec2dict['flat_field'], spec2dict['srctype'] = {}, {}, {}, {}, {}
spec2dict['straylight'], spec2dict['fringe'], spec2dict['photom'], spec2dict['residual_fringe'], spec2dict['pixel_replace'] = {}, {}, {}, {}, {}
spec2dict['cube_build'], spec2dict['extract_1d'] = {}, {}

# Overrides for whether or not certain steps should be skipped (example)
#spec2dict['straylight']['skip'] = True

# Pixel-based background usage was set up above, propagate that here
if (pixel_bg is True):
    spec2dict['bkg_subtract']['skip'] = False
else:
    spec2dict['bkg_subtract']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#spec2dict['assign_wcs']['override_distortion'] = 'myfile.asdf' # Spatial distortion (ASDF file)
#spec2dict['assign_wcs']['override_regions'] = 'myfile.asdf' # IFU slice regions on detector (ASDF file)
#spec2dict['assign_wcs']['override_specwcs'] = 'myfile.asdf' # Spectral distortion (ASDF file)
#spec2dict['assign_wcs']['override_wavelengthrange'] = 'myfile.asdf' # Wavelength channel mapping (ASDF file)
#spec2dict['flat_field']['override_flat'] = 'myfile.fits' # Pixel flatfield
#spec2dict['straylight']['override_mrsxartcorr'] = 'myfile.fits' # Cross-artifact model parameters
#spec2dict['fringe']['override_fringe'] = 'myfile.fits' # Static fringe-flat
#spec2dict['photom']['override_photom'] = 'myfile.fits' # Photometric calibration array
#spec2dict['cube_build']['override_cubepar'] = 'myfile.fits' # Cube-building parameters
#spec2dict['extract_1d']['override_extract1d'] = 'myfile.asdf' # Spectral extraction parameters (ASDF file)
#spec2dict['extract_1d']['override_apcorr'] = 'myfile.asdf' # Aperture correction parameters (ASDF file)

# !!!!
# Turn on residual cosmic-ray shower correction (off by default)
# (see https://jwst-docs.stsci.edu/known-issues-with-jwst-data/shower-and-snowball-artifacts)
#spec2dict['straylight']['clean_showers'] = True
# !!!!

# Turn on 2d residual fringe correction (off by default)
# This can sometimes improve residual fringing in science results, but takes
# a long time to run and often does not work as well as 1d residual fringe
# correction (in calwebb_spec3)
#spec2dict['residual_fringe']['skip'] = False

# Turn on bad pixel self-calibration, where all exposures on a given detector are used to find and
# flag bad pixels that may have been missed by the bad pixel mask.
# This step is experimental, and works best when dedicated background observations are included
#spec2dict['badpix_selfcal']['skip'] = False
#spec2dict['badpix_selfcal']['flagfrac_upper']=0.005 # Fraction of pixels to flag (dial as desired; 1.0 would be 100% of pixels)

# %% [markdown]
# Define a function to create association files for Stage 2. This will enable use of the pixel-based background subtraction, if chosen above. This requires *one* input SCI file, but can have multiple input background files.
#
# <div class="alert alert-block alert-warning">
# Note that the background will not be applied properly to all files if more than *one* SCI file is included in the association.
# </div>

# %%
# This cell defines the association files, .json files that are required
# to tell for each channels and bands which background to subtract

def writel2asn(onescifile, bgfiles, selfcalfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list([onescifile], rule=DMSLevel2bBase, product_name=prodname)  # Wrap in array since input was single exposure

    #Channel/band configuration for this sci file
    with fits.open(onescifile) as hdu:
        hdu.verify()
        hdr = hdu[0].header
        this_channel, this_band = hdr['CHANNEL'], hdr['BAND']

    # If backgrounds were provided, find which are appropriate to this
    # channel/band and add to association
    for file in bgfiles:
        with fits.open(file) as hdu:
            hdu.verify()
            if ((hdu[0].header['CHANNEL'] == this_channel) & (hdu[0].header['BAND'] == this_band)):
                asn['products'][0]['members'].append({'expname': file, 'exptype': 'background'})
                
    # If provided with a list of files to use for bad pixel self-calibration, find which
    # are appropriate to this detector and add to association
    for file in selfcalfiles:
        with fits.open(file) as hdu:
            hdu.verify()
            if (hdu[0].header['CHANNEL'] == this_channel):
                asn['products'][0]['members'].append({'expname': file, 'exptype': 'selfcal'})                

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths

# %%
sstring = os.path.join(det1_dir, 'jw*mirifu*rate.fits')  # Use files from the detector1 output folder
ratefiles = sorted(glob.glob(sstring))
for ii in range(0, len(ratefiles)):
    ratefiles[ii] = os.path.abspath(ratefiles[ii])
ratefiles = np.array(ratefiles)
# Check that these are the band/channel to use
ratefiles = select_ch_band_files(ratefiles, use_ch, use_band)

# Background Files
sstring = os.path.join(det1_bgdir, 'jw*mirifu*rate.fits')
bgfiles = sorted(glob.glob(sstring))
for ii in range(0, len(bgfiles)):
    bgfiles[ii] = os.path.abspath(bgfiles[ii])
bgfiles = np.array(bgfiles)
# Check that these are the band/channel to use
bgfiles = select_ch_band_files(bgfiles, use_ch, use_band)

# Define any files to use for self-calibration (if step enabled)
# Typically this is all science and background exposures
selfcalfiles = ratefiles.copy()
selfcalfiles = np.append(selfcalfiles, bgfiles)

print('Found ' + str(len(ratefiles)) + ' science files')
print('Found ' + str(len(bgfiles)) + ' background files')
print('Found ' + str(len(selfcalfiles)) + ' potential selfcal files')
# Out:
# Found 16 science files
# Found 4 background files
# Found 20 potential selfcal files

# %% [markdown]
# Step through each of the science files, using relevant associated backgrounds in calwebb_spec2 processing.
#
# <div class="alert alert-block alert-warning">
# The background files are used in this step to perform pixel-based background subtraction (if desired), otherwise background subtraction is done later with Spec3 files.
# </div>

# %%
# To save runtime, make a new version of our spec2 parameter dictionary
# that turns off creation of quicklook cubes and 1d spectra for science
# data
spec2dict_sci = copy.deepcopy(spec2dict)
spec2dict_sci['cube_build']['skip'] = True
spec2dict_sci['extract_1d']['skip'] = True

if dospec2:
    for file in ratefiles:
        asnfile = os.path.join(sci_dir, 'l2asn.json')
        writel2asn(file, bgfiles, selfcalfiles, asnfile, 'Level2')
        Spec2Pipeline.call(asnfile, steps=spec2dict_sci, save_results=True, output_dir=spec2_dir)
else:
    print('Skipping Spec2 processing for SCI data')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Reduce the backgrounds individually.  This will be needed for the Master Background step in calwebb_spec3, but is unnecessary if doing calwebb_spec2 pixel based background instead.
# </div>

# %%
if dospec2bg:
    for file in bgfiles:
        asnfile = os.path.join(bg_dir, 'l2asn.json')
        writel2asn(file, '', selfcalfiles, asnfile, 'Level2')
        Spec2Pipeline.call(asnfile, steps=spec2dict, save_results=True, output_dir=spec2_bgdir)
else:
    print('Skipping Spec2 processing for BG data')

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec2: {time1 - time_spec2} seconds")
# Out:
# Runtime so far: 26604.1258 seconds
# Runtime for Spec2: 2863.6927959860004 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 7.<font color='white'>-</font>Spec3 Pipeline<a class="anchor" id="spec3"></a>
# ------------------
# In this section we'll run the Spec3 (calwebb_spec3) pipeline to produce a
# composite data cube and extracted spectrumfrom all dithered exposures.
# We will need to create an association file from all science (*cal.fits)
# and background (*x1d.fits) data in order for the pipeline to use them
# appropriately.<br>
#
# Note that the data cubes created by the JWST pipeline are in SURFACE
# BRIGHTNESS units (MJy/steradian), not flux units. What that means is
# that if you intend to sum spectra within an aperture you need to be sure
# to multiply by the pixel area in steradians first in order to get a
# spectrum in flux units. This correction is already build into the pipeline
# Extract1D algorithm.
# The nominal pixel area in steradians is provided in the
# <code>PIXAR_SR</code> keyword and can be found in the SCI
# extension header.<BR>
#
# Spectral extraction for point sources uses a conical aperture extraction whose radius increases with wavelength, with annular background subtraction and aperture correction.  Spectral extraction for extended sources sums the entire image at each wavelength plane (note this is different for each channel). <BR>
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_spec3
#
# <div class="alert alert-block alert-warning">
# If master background subtraction was selected above this will be applied
# during this stage.<BR><BR>
# To override certain steps and reference files use the examples below.
# </div>

# %%
time_spec3 = time.perf_counter()

# %%
# Set up a dictionary to define how the Spec3 pipeline should be configured

# Boilerplate dictionary setup
spec3dict = {}
spec3dict['assign_mtwcs'], spec3dict['master_background'], spec3dict['outlier_detection'], spec3dict['mrs_imatch'], spec3dict['cube_build'] = {}, {}, {}, {}, {}
spec3dict['pixel_replace'], spec3dict['extract_1d'], spec3dict['spectral_leak'] = {}, {}, {}

# Overrides for whether or not certain steps should be skipped (example)
#spec3dict['outlier_detection']['skip'] = True

# Master background usage was set up above, propagate that here
if (master_bg is True):
    spec3dict['master_background']['skip'] = False
else:
    spec3dict['master_background']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#spec3dict['cube_build']['override_cubepar'] = 'myfile.fits'  # Cube-building parameters
#spec3dict['extract_1d']['override_extract1d'] = 'myfile.asdf'  # Spectral extraction parameters (ASDF file)
#spec3dict['extract_1d']['override_apcorr'] = 'myfile.asdf'  # Aperture correction parameters (ASDF file)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Set certain parameters here to:
#
# * adjusting performance for the outlier detection step
# * adjust the cube building step
# * adjust the 1d spectral extraction
# </div>

# %%
# Options for adjusting performance for the outlier detection step
#spec3dict['outlier_detection']['kernel_size'] = '11 1'  # Dial this to adjust the detector kernel size
#spec3dict['outlier_detection']['threshold_percent'] = 99.5  # Dial this to be more/less aggressive in outlier flagging (values closer to 100% are less aggressive)

# Run pixel replacement code to extrapolate values for otherwise bad pixels
# This can help mitigate 5-10% negative dips in spectra of bright sources
# Use the 'mingrad' algorithm
spec3dict['pixel_replace']['skip'] = False
spec3dict['pixel_replace']['algorithm'] = 'mingrad'
#spec3dict['pixel_replace']['save_results'] = True # Enable if desired to write out these files for spot checking

# Options for adjusting the cube building step
#spec3dict['cube_build']['output_file'] = 'mycube'  # Custom output name
spec3dict['cube_build']['output_type'] = 'band'  # 'band', 'channel' (default), or 'multi' type cube output.  'band' is best for 1d residual fringe correction.
#spec3dict['cube_build']['channel'] = '1'  # Build everything from just channel 1 into a single cube (we could also choose '2','3','4', or 'ALL')
# !!!
#spec3dict['cube_build']['weighting'] = 'drizzle'  # Algorithm used: 'emsm' or 'drizzle' (default)
# drizzle → better spatial resolution
# emsm → better S/N for faint sources
# !!!

#spec3dict['cube_build']['coord_system'] = 'ifualign'  # Cube rotation: 'ifualign', 'skyalign' (default), or 'internal_cal'
#spec3dict['cube_build']['scalexy'] = 0.5  # Output cube spaxel scale (arcsec) if setting it by hand
#spec3dict['cube_build']['scalew'] = 0.002  # Output cube voxel depth in wavelength (micron) if setting it by hand
#spec3dict['cube_build']['ra_center'] = 65.0  # Force cube to be centered at this R.A.
#spec3dict['cube_build']['dec_center'] = -35.0  # Force cube to be centered at this Decl.
#spec3dict['cube_build']['cube_pa'] = 45.0  # Force cube to have this position angle
#spec3dict['cube_build']['nspax_x'] = 61  # Force cube to have this number of spaxels in cube X direction
#spec3dict['cube_build']['nspax_y'] = 61  # Force cube to have this number of spaxels in cube Y direction
#spec3dict['cube_build']['wavemin'] = 4.8  # Custom minimum wavelength for the cube
#spec3dict['cube_build']['wavemax'] = 6.3  # Custom maximum wavelength for the cube

# Options for adjusting the 1d spectral extraction
#spec3dict['extract_1d']['ifu_set_srctype'] = 'POINT' # Force a certain type of spectral extraction ('POINT' or 'EXTENDED')
#spec3dict['extract_1d']['ifu_rscale'] = 2  # Number of FWHM to use for point-source conical aperture extraction radius (default is 2)
spec3dict['extract_1d']['ifu_autocen'] = True  # Enable auto-centering of the extraction aperture (default is True)
#spec3dict['extract_1d']['center_xy'] = (20,20)  # Override aperture location if desired

# %% [markdown]
# Define a function to create association files for Stage 3.

# %%
def writel3asn(scifiles, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)

    # Add background files to the association
    for file in bgfiles:
        asn['products'][0]['members'].append({'expname': file, 'exptype': 'background'})

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths

# %%
# Science Files need the cal.fits files
sstring = os.path.join(spec2_dir, 'jw*mirifu*_cal.fits')
calfiles = sorted(glob.glob(sstring))
for ii in range(0, len(calfiles)):
    calfiles[ii] = os.path.abspath(calfiles[ii])
calfiles = np.array(calfiles)
# Check that these are the band/channel to use
calfiles = select_ch_band_files(calfiles, use_ch, use_band)

# Background Files need the x1d.fits files for Master Background subtraction
sstring = os.path.join(spec2_bgdir, 'jw*mirifu*x1d.fits')
bgfiles = sorted(glob.glob(sstring))
for ii in range(0, len(bgfiles)):
    bgfiles[ii] = os.path.abspath(bgfiles[ii])
bgfiles = np.array(bgfiles)
# Check that these are the band/channel to use
bgfiles = select_ch_band_files(bgfiles, use_ch, use_band)

print('Found ' + str(len(calfiles)) + ' science files to process')
print('Found ' + str(len(bgfiles)) + ' background files to process')
# Out:
# Found 16 science files to process
# Found 4 background files to process

# %% [markdown]
# Make an association file that includes all of the different exposures. If using Master Background subtraction include the background data.
#
# <div class="alert alert-block alert-warning">
# Note that science data must be of type cal.fits and background exposures must be of type x1d.fits
# </div>

# %%
asnfile = os.path.join(sci_dir, 'l3asn.json')
if dospec3:
    writel3asn(calfiles, bgfiles, asnfile, 'Level3')

# %% [markdown]
# Run calwebb_spec3 using the call method.

# %%
if dospec3:
    Spec3Pipeline.call(asnfile, steps=spec3dict, save_results=True, output_dir=spec3_dir)
else:
    print('Skipping Spec3 processing')

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec3: {time1 - time_spec3} seconds")
# Out:
# Runtime so far: 27659.0211 seconds
# Runtime for Spec3: 917.8420355840026 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 8.<font color='white'>-</font>Plot the spectra<a class="anchor" id="plots"></a>
# ------------------
# Here we'll plot the spectra to see what our source looks like.

# %%
if doviz:
    # Find and sort all of the input files

    # Science Files
    # Use the final extracted spectra (x1d.fits)
    sstring = sorted(glob.glob(os.path.join(spec3_dir, '*x1d.fits')))
    x1dfiles = np.array(sorted(sstring))

# %%
if doviz:
    # Make normal plots
    # %matplotlib inline
    # Interactive plots
    #%matplotlib notebook

    rc('axes', linewidth=2)
    fig, ax = plt.subplots(1, 1, figsize=(10, 3), dpi=150)

    if (len(x1dfiles) > 0):
        hdu = fits.open(x1dfiles[0])
        objname = hdu[0].header['TARGPROP']
        hdu.close()
    else:
        objname = 'Unknown'

    ymin, ymax = np.nan, np.nan
    for file in x1dfiles:
        x1d = fits.open(file)
        x1ddata = x1d[1].data
        wave = x1ddata['WAVELENGTH']
        # Plot residual-fringe corrected spectra
        flux = x1ddata['RF_FLUX']
        ymin = np.nanmin([ymin, np.nanpercentile(flux, 2)])
        ymax = np.nanmax([ymax, np.nanpercentile(flux, 99.5)])

        # labels
        label = x1d[0].header['CHANNEL'] + x1d[0].header['BAND']

        plt.plot(wave, flux, label=label)

        x1d.close()

    plt.xlabel(r'Wavelength ($\mu$m)')
    plt.ylabel('Flux (Jy)')
    plt.title(objname)
    plt.ylim(ymin, ymax)
    plt.legend(fontsize=8, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid()
    plt.tight_layout()
    plt.savefig('mrs_data_plot1.png')

# %%
# Another attempt at creating continuous spectra from all the cubes
# That was a miserable attempt using AI, Ill try to do it myself now 01:53
import numpy as np
import matplotlib.pyplot as plt

from astropy.io import fits
from astropy.wcs import WCS
from astropy import units as u
from astropy.wcs.utils import proj_plane_pixel_area
from spectral_cube import SpectralCube
from regions import Regions
import glob
import os


# Import the region file CRTF
region_file = "/home/fatih/G165_main/G165_miri_bg_subtraction/data/carta_regions/science_footprints"
regions = Regions.read(region_file)
# print(regions)

# Define directory to find cubes
cube_dir = spec3_dir
cube_files = sorted(glob.glob(os.path.join(cube_dir, "*s3d.fits")))
# print(cube_files)


# Extracting spectra from a region in from the CRTF file
def extract_region_spectrum(cube_path, regions):
    """
    Load a MIRI cube and extract a region-integrated spectrum 
    defined by one or more CRTF regions.
    Returns wavelength and flux arrays.
    """

    # Load cube
    cube = SpectralCube.read(cube_path, hdu="SCI")
    wcs = cube.wcs
    # pixel area in steradians
    pix_area_sr = proj_plane_pixel_area(cube.wcs) * u.sr

    # convert MJy/sr → Jy
    cube = (cube * pix_area_sr).to(u.Jy)    
    # Convert cube to Jy (JWST cubes usually already are)
    

    # Initialize final mask = False everywhere
    full_mask = np.zeros(cube.shape[1:], dtype=bool)

    # Create masks for all regions and OR them together
    for reg in regions:
        pixel_reg = reg.to_pixel(wcs)
        mask = reg.to_mask(mode='center')
        # In 'center' mode, a pixel is considered to be inside the region if
        # its central position falls within the region's boundaries. This results
        #  in a mask where pixel values are either 0 (outside) or 1 (inside), representing a binary mask.
        
        # Convert region mask to full image coordinates
        region_mask = mask.to_image(full_mask.shape)
        full_mask |= region_mask.astype(bool)

    # Apply mask to each wavelength slice and integrate
    wavelengths = cube.spectral_axis.to_value('micron') # smart package converting to micron
    flux = []

    for i in range(len(wavelengths)):
        slice2d = cube.unmasked_data[i, :, :]     # 2D slice at wavelength i
        masked = slice2d[full_mask]               # apply region mask
        flux.append(np.nansum(masked))            # integrate flux in region

    flux = np.array(flux)

    return wavelengths, flux


# Looping through all cubes
all_waves = []
all_fluxes = []

for cube_path in cube_files:
    wave, flux = extract_region_spectrum(cube_path, regions)
    all_waves.append(wave)
    all_fluxes.append(flux)


# Combine all spectra into single arrays
wave_all = np.concatenate(all_waves)
flux_all = np.concatenate(all_fluxes)

# Sort by wavelength
order = np.argsort(wave_all) # np.argsort returns the indices you would sort an array
wave_all = wave_all[order]
flux_all = flux_all[order]


# Plotting 
plt.figure(figsize=(12,4))
plt.plot(wave_all, flux_all, linewidth=1.2)

plt.xlabel("Wavelength (µm)")
plt.ylabel("Flux (Jy)")
plt.title("Region-Integrated Spectrum")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Attempt 2

# Import the region file CRTF
region_file = "/home/fatih/G165_main/G165_miri_bg_subtraction/data/carta_regions/science_footprints_ds9_world"
regions = Regions.read(region_file)
print(regions)

# Define directory to find cubes
cube_dir = spec3_dir
cube_files = sorted(glob.glob(os.path.join(cube_dir, "*s3d.fits")))
# print(cube_files)
# Out:
# [<RectangleSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81107636, 42.47317676)>, width=3.8739 arcsec, height=4.1011 arcsec, angle=311.6987 deg)>, <EllipseSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81137112, 42.47284274)>, width=2.1956 arcsec, height=0.3422 arcsec, angle=67.71442 deg)>, <EllipseSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81122448, 42.47326812)>, width=2.1048 arcsec, height=0.2762 arcsec, angle=65.695465 deg)>, <CircleSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81142645, 42.47310616)>, radius=0.1559 arcsec)>, <CircleSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81159569, 42.47280554)>, radius=0.1192 arcsec)>, <RectangleSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81133155, 42.47296598)>, width=1.1061 arcsec, height=4.9774 arcsec, angle=334.9831 deg)>, <RectangleSkyRegion(center=<SkyCoord (ICRS): (ra, dec) in deg
#     (171.81048004, 42.4732238)>, width=0.2804 arcsec, height=1.304 arcsec, angle=333.10376 deg)>]

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# <img style="float: center;" src="https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_footer.png" alt="stsci_logo" width="200px"/>
