# %% [markdown]
# <img style="float: center;" src='https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_header.png' alt="stsci_logo" width="900px"/>

# %% [markdown]
# <a id="title_ID"></a>
# # MIRI MRS Pipeline Notebook #

# %% [markdown]
# **Authors**: David Law, Kirsten Larson; MIRI branch<br>
# **Last Updated**: April 17, 2026<br>
# **Pipeline Version**: 2.0.0 (Build 12.3)

# %% [markdown]
# **Purpose**:<BR>
# This notebook provides a framework for processing generic Mid-Infrared
# Instrument (MIRI) Medium Resolution Spectroscopy (MRS) data through all
# three James Webb Space Telescope (JWST) pipeline stages.  Data is assumed
# to be located in two observation folders (science and background)
# according to paths set up below.  It should not be necessary to edit any
# cells other than in the [Configuration](#1.-Configuration) section
# unless modifying the standard pipeline processing options.
#
# **Data**:<BR>
# ~~This example is set up to use observations of the LMC planetary nebula
# SMP LMC 058 obtained by Proposal ID (PID) 1523 Observation 3. This is a
# point source that uses a standard 4-point dither in all three grating
# settings.  It incorporates a dedicated background in observation 4.
# Example input data to use will be downloaded automatically unless
# disabled (i.e., to use local files instead).~~
#
# This setup uses the MIRI MRS data of Target **J1127+4228** and its background. It is a gravitationally lensed star-forming galaxy in the PLCK G165.7 galaxy cluster. The parameters in the ``demo_mode`` are set to download not the SMP LMC 058 planetary nebula data, but the lensed galaxy. Because it is more convenient to just leave the demo mode on and change its parameters. For now.
#
# **JWST pipeline version and CRDS context**:<BR>
# This notebook was written for the
# calibration pipeline version given above.  If you use it with a different pipeline
# version or specify a non-default reference file context please see the relevant
# release notes
# ([here for pipeline](https://github.com/spacetelescope/jwst),
# [here for CRDS](https://jwst-crds.stsci.edu/)) for possibly relevant
# changes.<BR>
#
# **Updates**:<BR>
# This notebook is regularly updated as improvements are made to the
# pipeline. Find the most up to date version of this notebook at:
# https://github.com/spacetelescope/jwst-pipeline-notebooks/
#
# **Recent Changes**:<br>
# Jan 16 2025: Update to Build 11.2 (jwst 1.17.1); no significant changes.<br>
# May 5 2025: Update to Build 11.3 (jwst 1.18.0); add optional command to remove residual showers, plot spectra from updated x1d.fits data model with rf-corrected columns.<br>
# May 22 2025: Update example plot use of regular and rf-corrected spectra.<br>
# July 16 2025: No significant updates.<br>
# Sep 03 2025: Minor update to remove mrs_imatch step<br>
# December 10 2025: No significant updates.<br>
# April 17, 2026: Updated to jwst 2.0.0; add Adaptive Trace Model option to spec3.

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## Table of Contents
#
# 1. [Configuration](#1.-Configuration)
# 2. [Package Imports](#2.-Package-Imports)
# 3. [Demo Mode Setup](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data))
# 4. [Directory Setup](#4.-Directory-Setup)
# 5. [Detector1 Pipeline](#5.-Detector1-Pipeline)
# 6. [Spec2 Pipeline](#6.-Spec2-Pipeline)
# 7. [Spec3 Pipeline](#7.-Spec3-Pipeline)
# 8. [Plot the spectra](#8.-Plot-the-spectra)

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 1.<font color='white'>-</font>Configuration<a class="anchor" id="intro"></a>
# ------------------
# Set basic parameters to use with notebook. These will affect
# what data is used, where data is located (if already in disk),
# pipeline modules run in this data, and type of background
# subtraction (if any). The list of parameters are:
#
# * demo_mode
# * channel
# * band
# * directories with data
# * pipeline modules
# * Backgroud subtraction method

# %%
# Basic import necessary for configuration
import os

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Note that <code>demo_mode</code> must be set appropriately below.
# </div>
#
# Set <code>demo_mode = True </code> to run in demonstration mode. In this mode this
# notebook will download example data from the
# Barbara A. Mikulski Archive for Space Telescopes (MAST) and process it through the pipeline.
# This will all happen in a local directory unless modified
# in [Section 3](#3.-Demo-Mode-Setup-(ignore-if-not-using-demo-data)) below.
#
# Set <code>demo_mode = False</code> if you want to process your own data that has already
# been downloaded and provide the location of the data.<br>

# %% [markdown]
# Explanation of uncal file naming, example `jw01355017001_02101_00001_mirifulong_uncal.fits`:
# - `jw`    = JWST
# - `01355` = TEMPLATES program ID number
# - `017`   = Observation number
# - `001`   = Visit number
# - `02101` = The `02` exposures are on-source, the `04` exposures are backgrounds.
# - `00001` = Exposure number, 1 to 4 for each dither position at both on- and off-source
# - `mirifulong` = Long- (or short-) wavelength MRS detector. Note this is not the same as the SHORT/MEDIUM/LONG grating specifications (it's confusing!). Channels 1 and 2 are always on the short detector, 3 and 4 always on the long detector, regardless of the grating setting.
# - `uncal` = We are starting on the raw uncalibrated exposures
# - `fits`  = This file is in the "Flexible Image Transport System" format

# %% [markdown]
# The following is the observation information regarding our object/area of interest. We are interested in the MIRI MRS data of Target **J1127+4228** and its background. This means that observation number of our target is <u>**3**</u> and for our background it is <u>**7**</u>
#
# Visit Status Report for JWST 3722
# Mon Nov 24 01:01:20 EST 2025
# |Observation|	Visit|	Status|	Target(s) |	Templates |	Hours |
# |:---:|:---:|:---:|:---|:---|:---:|
# |17 |	1|	Archived|	J1609+6045-BACKGROUND | MIRI Medium Resolution Spectroscopy |  1.11|
# |18 |	1|	Archived|	J1609+6045 | MIRI Medium Resolution Spectroscopy | 3.51	|
# |9 |	1|	Archived|	J1127+4228 | NIRSpec IFU Spectroscopy | 1.52	|
# |10 |	1|	Archived|	J1127+4228-BACKGROUND | NIRSpec IFU Spectroscopy | 0.66	|
# |<font color="#0033ffff">3 </font>|	<font color="#0033ffff">1 </font>|	<font color="#0033ffff">Archived </font>|	<font color="#0033ffff">J1127+4228 </font> | <font color="#0033ffff">MIRI Medium Resolution Spectroscopy </font> | <font color="#0033ffff">3.73 </font>	|
# |<font color="#0033ffff">7 </font>|	<font color="#0033ffff">1 </font>|	<font color="#0033ffff">Archived </font>|	<font color="#0033ffff">J1127+4228-BACKGROUND</font> | <font color="#0033ffff">MIRI Medium Resolution Spectroscopy </font> | <font color="#0033ffff">0.97 </font>	|
# |4 |	1|	Archived|	J1053+0556 | MIRI Medium Resolution Spectroscopy | 4.56	|
# |8 |	1|	Archived|	J1053+0556-BACKGROUND | MIRI Medium Resolution Spectroscopy | 0.56	|

# %%
# Set parameters for demo_mode, channel, band, data mode directories, and 
# processing steps.

# -----------------------------Demo Mode---------------------------------
demo_mode = True

if demo_mode:
    print('Running in demonstration mode using Data of Interest!')

# --------------------------User Mode Directories------------------------
# If demo_mode = False, look for user data in these paths
if not demo_mode:
    # Set directory paths for processing specific data; these will need
    # to be changed to your local directory setup (below are given as
    # examples)
    user_home_dir = os.path.expanduser('~')

    # Point to where science observation data are
    # Assumes uncalibrated data in sci_dir/uncal/ and results in stage1,
    # stage2, stage3 directories
    sci_dir = os.path.join(user_home_dir, 'FlightData/APT1523/data/Obs003/')

    # Point to where background observation data are
    # Assumes uncalibrated data in bg_dir/uncal/ and results in stage1,
    # stage2, stage3 directories
    bg_dir = os.path.join(user_home_dir, 'FlightData/APT1523/data/Obs004/')
    #bg_dir = '' # If no background observation, use an empty string

# --------------------------Set Processing Steps--------------------------
# Whether or not to process only data from a given MRS band/channel (useful
# if overriding reference files)
# Note that BOTH parameters must be set in order to work

# Channel 	|       Sub-band	    | Wavelength Range (µm)
# 1	        |  SHORT / MED / LONG   | 4.9–7.7
# 2	        |  SHORT / MED / LONG	| 7.5–11.9
# 3	        |  SHORT / MED / LONG	| 11.5–18.3
# 4	        |  SHORT / MED / LONG	| 17.7–28.8
# !!! Remember, Channels 1-2 are mirifushort, and Channels 3-4 are mirifulong
# these are not the same as the sub-bands SHORT, MEDIUM, LONG !!!

use_ch = ''  # '12' or '34'
use_band = ''  # 'SHORT', 'MEDIUM', or 'LONG'

# Individual pipeline stages can be turned on/off here.  Note that a later
# stage won't be able to run unless data products have already been
# produced from the prior stage.

# Science processing
dodet1 = True  # calwebb_detector1
dospec2 = True  # calwebb_spec2
dospec3 = True  # calwebb_spec3
doviz = True # Visualize calwebb_spec3 results

# Background processing
dodet1bg = True  # calwebb_detector1
dospec2bg = True  # calwebb_spec2 (needed for Master Background subtraction)

# How should background subtraction using any dedicated backgrounds be done?
# If none are selected, cubes will not be background subtracted.  1d spectra
# will always use local annular background subtraction for point sources.
# Note that if using master-background subtraction, background observations
# must be selected above to process through spec2 (dospec2bg = True).
master_bg = False  # Master-background subtraction in spec3 (subtract spectrum generated from the backgrounds).  This is the default pipeline setting.
pixel_bg = True  # Pixel-based background subtraction in spec2 (direct pixel subtraction).
# Out:
# Running in demonstration mode using Data of Interest!

# %% [markdown]
# ### Set CRDS context and server
# Before importing <code>CRDS</code> and <code>JWST</code> modules, we need to configure our environment. This includes defining a CRDS cache directory in which to keep the reference files that will be used by the calibration pipeline.
#
# If the root directory for the local CRDS cache directory has not been set already, it will be set to create one in the home directory.

# %% [markdown]
# ### What is CRDS (Calibration Reference Data System)?
# [CRDS is a metadata-based system that maps datasets to data using mapping rules. The calibration pipelines, pre-archive processing, and reprocessing of HST and JWST observations, use CRDS to identify the best reference files for the data.](https://www.stsci.edu/hst/instrumentation/reference-data-for-calibration-and-tools)
#
# CRDS mathes data with calibration files (darks, flats, bad pixel maps, distortion models(?), etc.) based on the pipeline version, context, and the data's metadata. It then retrieves those calibration files from a server to be used in the pipeline. These files are stored elsewhere and are not stored locally after the pipeline has been run.
#
# The code cell below sets up the connection between your machine and this system, if it has not been set already.

# %%
# ------------------------Set CRDS context and paths----------------------

# Set CRDS reference file context.  Leave commented-out to use the default context
# (latest reference files associated with the calibration pipeline version)
# or set a specific context here.
#%env CRDS_CONTEXT  jwst_1295.pmap

# Check whether the local CRDS cache directory has been set.
# If not, set it to the user home directory
if (os.getenv('CRDS_PATH') is None):
    os.environ['CRDS_PATH'] = os.path.join(os.path.expanduser('~'), 'crds')
# Check whether the CRDS server URL has been set.  If not, set it.
if (os.getenv('CRDS_SERVER_URL') is None):
    os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

# Echo CRDS path and context in use
print('CRDS local filepath:', os.environ['CRDS_PATH'])
print('CRDS file server:', os.environ['CRDS_SERVER_URL'])
# Out:
# CRDS local filepath: /home/fatih/crds_cache
# CRDS file server: https://jwst-crds.stsci.edu

# %%
from crds import client
import jwst # -> Imports the pipeline stages
import stcal # -> "support package for calibration pipeline software" (https://github.com/spacetelescope/stcal)

# CRDS is the Calibration Reference Data System

import os

print("Server URL:", client.get_crds_server())
print("Latest context:", client.get_default_context("jwst"))
print('# JWST pipe version = {0:s}'.format(jwst.__version__))
print('# STCAL version = {0:s}'.format(stcal.__version__))
# Out:
# Server URL: https://jwst-crds.stsci.edu
# Latest context: jwst_1535.pmap
# # JWST pipe version = 2.0.1
# # STCAL version = 1.18.0

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ## 2.<font color='white'>-</font>Package Imports<a class="anchor" id="intro"></a>
# ------------------

# %%
# Use the entire available screen width for this notebook
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# Basic system utilities for interacting with files
# ----------------------General Imports------------------------------------
import glob
import copy
import time
from pathlib import Path
from collections import defaultdict
from pathlib import Path

# Numpy for doing calculations
import numpy as np

# -----------------------Astropy Imports-----------------------------------
# Astropy utilities for opening FITS and ASCII files, and downloading demo files
from astropy.io import fits
from astroquery.mast import Observations

# -----------------------Plotting Imports----------------------------------
# Matplotlib for making plots
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
# --------------JWST Calibration Pipeline Imports---------------------------
# Import the base JWST and calibration reference data packages
import jwst
import crds

# JWST pipelines (each encompassing many steps)
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Spec3Pipeline

# JWST pipeline utilities
from jwst import datamodels  # JWST datamodels
from jwst.associations import asn_from_list as afl  # Tools for creating association files
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase  # Definition of a Lvl2 association file
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base  # Definition of a Lvl3 association file

from jwst.stpipe import Step  # Import the wrapper class for pipeline steps

# Echo pipeline version and CRDS context in use
print("JWST Calibration Pipeline Version = {}".format(jwst.__version__))
print("Using CRDS Context = {}".format(crds.get_context_name('jwst')))
# Out:
# JWST Calibration Pipeline Version = 2.0.1
# Using CRDS Context = jwst_1535.pmap

# %% [markdown]
# ### Define convenience functions

# %%
# Define a convenience function to select only files of a given channel/band from an input set
# Used if overriding reference files for a specific channel/band in a previous cell
def select_ch_band_files(files, use_ch, use_band):
    if ((use_ch != '') & (use_band != '')):
        keep = np.zeros(len(files))
        for ii in range(0, len(files)):
            with fits.open(files[ii]) as hdu:
                hdu.verify()
                hdr = hdu[0].header
                if ((hdr['CHANNEL'] == use_ch) & (hdr['BAND'] == use_band)):
                    keep[ii] = 1
        indx = np.where(keep == 1)
        files_culled = files[indx]
    else:
        files_culled = files
        
    return files_culled

# %%
# Start a timer to keep track of runtime
time0 = time.perf_counter()

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 3.<font color='white'>-</font>Demo Mode Setup<a class="anchor" id="intro"></a> (ignore if not using demo data)
# ------------------
# If running in demonstration mode, set up the program information to
# retrieve the uncalibrated data automatically from MAST using
# [astroquery](https://astroquery.readthedocs.io/en/latest/mast/mast.html).
# MAST allows for flexibility of searching by the proposal ID and the
# observation ID instead of just filenames.<br>
#
# More information about the JWST file naming conventions can be found at:
# https://jwst-pipeline.readthedocs.io/en/latest/jwst/data_products/file_naming.html

# %%
# Set up the program information and paths for demo program
if demo_mode:
    print('Running in customized-demonstration mode and will NOT download  daexampleta from MAST!')
    program = "03722" # "01523"
    sci_observtn = "003"  # "003" # observation ID
    back_observtn = "007" # "004" # background obs ID
    visit = "001" 
    
    # These create a folder tree
    # mrs_data/
    # ├── Obs003/
    # │  └── uncal/
    # └── Obs007/
    #    └── uncal/cd .
    basedir = os.path.join('.', 'mrs_data')
    download_dir = basedir
    sci_dir = os.path.join(basedir, 'Obs' + sci_observtn)
    bg_dir = os.path.join(basedir, 'Obs' + back_observtn)
    uncal_dir = os.path.join(sci_dir, 'uncal')
    uncal_bgdir = os.path.join(bg_dir, 'uncal')

    # Ensure filepaths for input data exist
    if not os.path.exists(uncal_dir):
        os.makedirs(uncal_dir)
    if not os.path.exists(uncal_bgdir):
        os.makedirs(uncal_bgdir)

# When using your own data, these would come from your own FITS headers or proposal info,
# or from the following website using Program ID 
# https://www.stsci.edu/jwst/science-execution/program-information
# Out:
# Running in customized-demonstration mode and will NOT download  daexampleta from MAST!

# %% [markdown]
# Identify list of science (SCI) and background (BG) uncalibrated files associated with visits.
# <div class="alert alert-block alert-warning">
# Selects only <i>mirifu</i> data (ignores MIRI imager).
# </div>

# %%
# Obtain a list of observation IDs for the specified demo program
if demo_mode:
    # Science data
    sci_obs_id_table = Observations.query_criteria(instrument_name=["MIRI/IFU"],
                                                   provenance_name=["CALJWST"],  # Executed observations
                                                   obs_id=['jw' + program + '-o' + sci_observtn + '*']
                                                   )

    # Background data
    bg_obs_id_table = Observations.query_criteria(instrument_name=["MIRI/IFU"],
                                                  provenance_name=["CALJWST"],  # Executed observations
                                                  obs_id=['jw' + program + '-o' + back_observtn + '*']
                                                  )

# %%
# Turn the list of visits into a list of uncalibrated data files
if demo_mode:
    # Define types of files to select
    file_dict = {'uncal': {'product_type': 'SCIENCE', 'productSubGroupDescription': 'UNCAL', 'calib_level': [1]}}

    # Science files
    sci_files_to_download = []
    # Loop over visits identifying uncalibrated files that are associated with them
    for exposure in (sci_obs_id_table):
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             calib_level=query_dict['calib_level'])
            sci_files_to_download.extend(filtered_products['dataURI'])

    # Background files
    bg_files_to_download = []
    # Loop over visits identifying uncalibrated files that are associated with them
    for exposure in (bg_obs_id_table):
        products = Observations.get_product_list(exposure)
        for filetype, query_dict in file_dict.items():
            filtered_products = Observations.filter_products(products, productType=query_dict['product_type'],
                                                             productSubGroupDescription=query_dict['productSubGroupDescription'],
                                                             calib_level=query_dict['calib_level'])
            bg_files_to_download.extend(filtered_products['dataURI'])

    # Cull to a unique list of files that contain 'mirifu' in the filename
    # (i.e., not MIRI imager)
    sci_files_to_download = np.unique([i for i in sci_files_to_download if 'mirifu' in i])
    bg_files_to_download = np.unique([i for i in bg_files_to_download if 'mirifu' in i])

    print("Science files selected for downloading: ", len(sci_files_to_download))
    print("Background selected for downloading: ", len(bg_files_to_download))
# Out:
# Science files selected for downloading:  16
# Background selected for downloading:  4

# %% [markdown]
# Download all the uncal files and place them into the appropriate directories.
#
# <div class="alert alert-block alert-warning">
# Warning: If this notebook is halted during this step the downloaded file may be incomplete, and cause crashes later on!
# </div>

# %%
if demo_mode:
    for filename in sci_files_to_download:
        sci_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_dir, Path(filename).name))
    for filename in bg_files_to_download:
        bg_manifest = Observations.download_file(filename, local_path=os.path.join(uncal_bgdir, Path(filename).name))
# Out:
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00001_mirifulong_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00001_mirifushort_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00002_mirifulong_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00002_mirifushort_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00003_mirifulong_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00003_mirifushort_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00004_mirifulong_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_02101_00004_mirifushort_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00001_mirifulong_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00001_mirifushort_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00002_mirifulong_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00002_mirifushort_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00003_mirifulong_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00003_mirifushort_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00004_mirifulong_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs003/uncal/jw03722003001_04101_00004_mirifushort_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs007/uncal/jw03722007001_02101_00001_mirifulong_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs007/uncal/jw03722007001_02101_00001_mirifushort_uncal.fits with expected size 211412160. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs007/uncal/jw03722007001_02102_00001_mirifulong_uncal.fits with expected size 52894080. [astroquery.query]
# INFO: Found cached file ./mrs_data/Obs007/uncal/jw03722007001_02102_00001_mirifushort_uncal.fits with expected size 52894080. [astroquery.query]

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 4.<font color='white'>-</font>Directory Setup<a class="anchor" id="intro"></a>
# ------------------
# Set up detailed paths to input/output stages here.

# %%
# Define output subdirectories to keep science data products organized
uncal_dir = os.path.join(sci_dir, 'uncal')  # Uncalibrated pipeline inputs should be here
det1_dir = os.path.join(sci_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
spec2_dir = os.path.join(sci_dir, 'stage2')  # calwebb_spec2 pipeline outputs will go here
spec3_dir = os.path.join(sci_dir, 'stage3')  # calwebb_spec3 pipeline outputs will go here

# Output subdirectories to keep background data products organized
uncal_bgdir = os.path.join(bg_dir, 'uncal')  # Uncalibrated pipeline inputs should be here
det1_bgdir = os.path.join(bg_dir, 'stage1')  # calwebb_detector1 pipeline outputs will go here
spec2_bgdir = os.path.join(bg_dir, 'stage2')  # calwebb_spec2 pipeline outputs will go here

# We need to check that the desired output directories exist, and if not create them
if not os.path.exists(det1_dir):
    os.makedirs(det1_dir)
if not os.path.exists(spec2_dir):
    os.makedirs(spec2_dir)
if not os.path.exists(spec3_dir):
    os.makedirs(spec3_dir)
if (bg_dir != ''):
    if not os.path.exists(det1_bgdir):
        os.makedirs(det1_bgdir)
    if not os.path.exists(spec2_bgdir):
        os.makedirs(spec2_bgdir)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# If there is no background folder, ensure we don't try to process it.
# </div>

# %%
if (bg_dir == ''):
    dodet1bg = False
    dospec2bg = False

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 9.8979 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 5.<font color='white'>-</font>Detector1 Pipeline<a class="anchor" id="det1"></a>
# ------------------
# In this section we process our data through the calwebb_detector1
# pipeline to create Stage 1 data products (i.e., uncalibrated slope
# images of the form *rate.fits).  These data products have units of DN/s.<BR><BR>
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_detector1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# To override certain steps and reference files, use the examples provided below.<br>
# E.g., turn on detection of cosmic ray showers.
# </div>

# %%
# Set up a dictionary to define how the Detector1 pipeline should be configured

# Boilerplate dictionary setup
det1dict = defaultdict(dict)


# on pewvious versions, this was:

# det1dict = {}
# det1dict['group_scale'], det1dict['dq_init'], det1dict['emicorr'], det1dict['saturation'], det1dict['ipc'] = {}, {}, {}, {}, {}
# det1dict['firstframe'], det1dict['lastframe'], det1dict['reset'], det1dict['linearity'], det1dict['rscd'] = {}, {}, {}, {}, {}
# det1dict['dark_current'], det1dict['refpix'], det1dict['charge_migration'], det1dict['jump'], det1dict['ramp_fit'] = {}, {}, {}, {}, {}
# det1dict['gain_scale'] = {}



# Overrides for whether or not certain steps should be skipped (example)
#det1dict['emicorr']['skip'] = True

# Option to use the first frame for very bright MIRI data that otherwise saturates fast enough to provide no slope
#det1dict['firstframe']['bright_use_group1'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path

# This whole chunk then configures the detector 1 pipeline by giving values to those empty dictionaries
# Usually CRDS will pull out the reference files but you can choose to use manual masks, reference files etc.

#det1dict['dq_init']['override_mask'] = 'myfile.fits' # Bad pixel mask
#det1dict['saturation']['override_saturation'] = 'myfile.fits' # Saturation
#det1dict['reset']['override_reset'] = 'myfile.fits' # Reset
#det1dict['linearity']['override_linearity'] = 'myfile.fits' # Linearity
#det1dict['rscd']['override_rscd'] = 'myfile.fits' # RSCD
#det1dict['dark_current']['override_dark'] = 'myfile.fits' # Dark current subtraction
#det1dict['jump']['override_gain'] = 'myfile.fits' # Gain used by jump step
#det1dict['ramp_fit']['override_gain'] = 'myfile.fits' # Gain used by ramp fitting step
#det1dict['jump']['override_readnoise'] = 'myfile.fits' # Read noise used by jump step
#det1dict['ramp_fit']['override_readnoise'] = 'myfile.fits' # Read noise used by ramp fitting step

# Turn on multi-core processing for jump step (off by default).  Choose what fraction of cores to use (quarter, half, or all)
det1dict['jump']['maximum_cores'] = 'all'

# Toggle detection of cosmic ray showers if desired (on by default)
#det1dict['jump']['find_showers'] = True

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Below an example of how to insert custom pipeline steps using the
# pre-hook/post-hook framework.
#
# For more information see [Tips and Trick for working with the JWST Pipeline](https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/tips-and-tricks-for-working-with-the-jwst-pipeline)
#     </div>

# %%
# Define a new step called XplyStep that multiplies everything by 1.0
# I.e., it does nothing, but could be changed to do something more interesting.
class XplyStep(Step):
    spec = '''
    '''
    class_alias = 'xply'

    def process(self, input_data):
        with datamodels.open(input_data) as model:
            result = model.copy()
        sci = result.data
        sci = sci * 1.0
        result.data = sci
        self.log.info('Multiplied everything by one in custom step!')
        return result


# And here we'll insert it into our pipeline dictionary to be run at the end right after the gain_scale step
det1dict['gain_scale']['post_hooks'] = [XplyStep]

# %% [markdown]
# ### Calibrating Science Files
# Look for input science files and run calwebb_detector1 pipeline using the call method.

# %%
# Look for input files of the form *uncal.fits from the science observation
sstring = os.path.join(uncal_dir, 'jw*mirifu*uncal.fits')
uncal_files = np.array(sorted(glob.glob(sstring)))
# Check that these are the band/channel to use
uncal_files = select_ch_band_files(uncal_files, use_ch, use_band)

print('Found ' + str(len(uncal_files)) + ' science input files')
# Out:
# Found 16 science input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1:
    for file in uncal_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_dir)
else:
    print('Skipping Detector1 processing for SCI data')
# Out:
# 2026-09-16 12:17:17,379 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-09-16 12:17:17,395 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-09-16 12:17:17,403 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2026-09-16 12:17:17,414 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2026-09-16 12:17:17,426 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-09-16 12:17:17,427 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-09-16 12:17:17,428 - stpipe.step - INFO - DQInitStep instance created.
# 2026-09-16 12:17:17,429 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-09-16 12:17:17,431 - stpipe.step - INFO - SaturationStep instance created.
# 2026-09-16 12:17:17,432 - stpipe.step - INFO - IPCStep instance created.
# 2026-09-16 12:17:17,433 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-09-16 12:17:17,434 - stpipe.step - INFO - RefPixStep instance created.
# 2026-09-16 12:17:17,434 - stpipe.step - INFO - RscdStep instance created.
# 2026-09-16 12:17:17,435 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-09-16 12:17:17,436 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-09-16 12:17:17,436 - stpipe.step - INFO - LinearityStep instance created.
# 2026-09-16 12:17:17,437 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-09-16 12:17:17,438 - stpipe.step - INFO - ResetStep instance created.
# 2026-09-16 12:17:17,438 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-09-16 12:17:17,439 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-09-16 12:17:17,441 - stpipe.step - INFO - JumpStep instance created.
# 2026-09-16 12:17:17,442 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-09-16 12:17:17,443 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:17:17,444 - stpipe.step - INFO - RampFitStep instance created.
# 2026-09-16 12:17:17,445 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-09-16 12:17:17,446 - stpipe.step - INFO - XplyStep instance created.
# 2026-09-16 12:17:17,516 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_data/Obs003/uncal/jw03722003001_02101_00001_mirifulong_uncal.fits'),).
# 2026-09-16 12:17:17,532 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs003/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:17:17,550 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifulong_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:17:17,553 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits'.
# 2026-09-16 12:17:17,554 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits'.
# 2026-09-16 12:17:17,554 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits'.
# 2026-09-16 12:17:17,555 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits'.
# 2026-09-16 12:17:17,556 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:17:17,556 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits'.
# 2026-09-16 12:17:17,557 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits'.
# 2026-09-16 12:17:17,557 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0019.fits'.
# 2026-09-16 12:17:17,558 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits'.
# 2026-09-16 12:17:17,558 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:17:17,559 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:17:17,559 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:17:17,560 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:17:18,149 - stpipe.step - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:18,150 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:17:18,151 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:17:18,153 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:17:18,231 - stpipe.step - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:18,244 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits
# 2026-09-16 12:17:18,288 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:18,342 - CRDS - INFO -  Calibration SW Found: jwst 2.0.1 (/home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst-2.0.1.dist-info)
# 2026-09-16 12:17:18,671 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:17:18,757 - stpipe.step - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:18,757 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:17:18,845 - stpipe.step - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:18,855 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits
# 2026-09-16 12:17:18,856 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:17:18,887 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:18,888 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:18,899 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:18,903 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:17:19,620 - stcal.saturation.saturation - INFO - Detected 513 saturated pixels
# 2026-09-16 12:17:19,651 - stcal.saturation.saturation - INFO - Detected 71 A/D floor pixels
# 2026-09-16 12:17:19,655 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:17:19,729 - stpipe.step - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:19,730 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:17:19,816 - stpipe.step - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:19,818 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:17:19,911 - stpipe.step - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:19,914 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:17:20,005 - stpipe.step - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:20,017 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits
# 2026-09-16 12:17:20,269 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,269 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,280 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,343 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:17:20,418 - stpipe.step - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:20,432 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits
# 2026-09-16 12:17:20,463 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,464 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,473 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:20,841 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:17:20,922 - stpipe.step - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:20,928 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0019.fits
# 2026-09-16 12:17:20,939 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:17:20,939 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:17:20,942 - jwst.rscd.rscd_sub - INFO -  There are 8 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:17:20,979 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:17:20,981 - jwst.rscd.rscd_sub - INFO -  There are 13 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:17:20,986 - jwst.rscd.rscd_sub - INFO - Flagged 13 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-09-16 12:17:21,036 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 13
# 2026-09-16 12:17:21,040 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:17:21,120 - stpipe.step - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:21,129 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits
# 2026-09-16 12:17:21,813 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:17:21,840 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:17:21,841 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2026-09-16 12:17:21,841 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:17:22,401 - stpipe.step - INFO - Step dark_current done
# 2026-09-16 12:17:22,472 - stpipe.step - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:22,473 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:17:22,559 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:22,560 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:17:22,718 - stpipe.step - INFO - Step jump running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:17:22,719 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-09-16 12:17:22,721 - jwst.jump.jump_step - INFO - Maximum cores to use = all
# 2026-09-16 12:17:22,737 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:17:22,740 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2026-09-16 12:17:22,845 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-09-16 12:17:22,846 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2026-09-16 12:17:25,221 - stcal.jump.jump - INFO - Flagging Showers
# 2026-09-16 12:18:10,216 - stcal.jump.jump - INFO - Total showers= 17092
# 2026-09-16 12:18:10,217 - stcal.jump.jump - INFO - Total elapsed time = 47.3718 sec
# 2026-09-16 12:18:10,229 - jwst.jump.jump_step - INFO - The execution time in seconds: 47.509330
# 2026-09-16 12:18:10,232 - stpipe.step - INFO - Step jump done
# 2026-09-16 12:18:10,401 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:10,407 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:18:10,556 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:10,559 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:18:10,658 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:10,669 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2026-09-16 12:18:10,670 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:18:10,704 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-09-16 12:18:10,704 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-09-16 12:18:10,930 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-09-16 12:18:10,931 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 0
# 2026-09-16 12:18:10,932 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-09-16 12:18:14,900 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 3.9666359424591064
# 2026-09-16 12:18:14,959 - stpipe.step - INFO - Step ramp_fit done
# 2026-09-16 12:18:15,045 - stpipe.step - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:15,051 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:18:15,078 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:18:15,080 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:18:15,191 - stpipe.step - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:15,215 - py.warnings - WARNING - /tmp/ipykernel_25883/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
#
# 2026-09-16 12:18:15,216 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:18:15,217 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:18:15,220 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:18:15,305 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:15,310 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:18:15,329 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:18:15,329 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:18:15,451 - stpipe.step - INFO - Step xply running with args (<CubeModel(2, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:18:15,495 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:18:15,497 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:18:15,499 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:18:15,589 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong_rateints.fits
# 2026-09-16 12:18:15,589 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-09-16 12:18:15,590 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:18:15,660 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong_rate.fits
# 2026-09-16 12:18:15,661 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-09-16 12:18:15,662 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1
# 2026-09-16 12:18:15,686 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-09-16 12:18:15,697 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-09-16 12:18:15,705 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2026-09-16 12:18:15,714 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2026-09-16 12:18:15,726 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-09-16 12:18:15,727 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-09-16 12:18:15,727 - stpipe.step - INFO - DQInitStep instance created.
# 2026-09-16 12:18:15,729 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-09-16 12:18:15,729 - stpipe.step - INFO - SaturationStep instance created.
# 2026-09-16 12:18:15,730 - stpipe.step - INFO - IPCStep instance created.
# 2026-09-16 12:18:15,731 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-09-16 12:18:15,732 - stpipe.step - INFO - RefPixStep instance created.
# 2026-09-16 12:18:15,733 - stpipe.step - INFO - RscdStep instance created.
# 2026-09-16 12:18:15,733 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-09-16 12:18:15,734 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-09-16 12:18:15,735 - stpipe.step - INFO - LinearityStep instance created.
# 2026-09-16 12:18:15,735 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-09-16 12:18:15,736 - stpipe.step - INFO - ResetStep instance created.
# 2026-09-16 12:18:15,737 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-09-16 12:18:15,738 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-09-16 12:18:15,740 - stpipe.step - INFO - JumpStep instance created.
# 2026-09-16 12:18:15,740 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-09-16 12:18:15,741 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:18:15,743 - stpipe.step - INFO - RampFitStep instance created.
# 2026-09-16 12:18:15,743 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-09-16 12:18:15,744 - stpipe.step - INFO - XplyStep instance created.
# 2026-09-16 12:18:15,853 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_data/Obs003/uncal/jw03722003001_02101_00001_mirifushort_uncal.fits'),).
# 2026-09-16 12:18:15,885 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs003/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:18:15,912 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:18:15,914 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2026-09-16 12:18:15,915 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2026-09-16 12:18:15,916 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2026-09-16 12:18:15,916 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2026-09-16 12:18:15,917 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:18:15,917 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2026-09-16 12:18:15,918 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2026-09-16 12:18:15,918 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits'.
# 2026-09-16 12:18:15,919 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2026-09-16 12:18:15,919 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:18:15,920 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:18:15,921 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:18:15,921 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:18:16,464 - stpipe.step - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:16,465 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:18:16,466 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:18:16,469 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:18:16,555 - stpipe.step - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:16,558 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2026-09-16 12:18:16,587 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:16,637 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:18:16,721 - stpipe.step - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:16,723 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:18:16,809 - stpipe.step - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:16,812 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2026-09-16 12:18:16,813 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:18:16,847 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:16,848 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:16,859 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:16,861 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:18:17,412 - stcal.saturation.saturation - INFO - Detected 5666 saturated pixels
# 2026-09-16 12:18:17,446 - stcal.saturation.saturation - INFO - Detected 94 A/D floor pixels
# 2026-09-16 12:18:17,450 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:18:17,544 - stpipe.step - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:17,546 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:18:17,652 - stpipe.step - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:17,653 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:18:17,754 - stpipe.step - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:17,756 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:18:17,840 - stpipe.step - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:17,842 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2026-09-16 12:18:17,987 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:17,988 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:17,997 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:18,037 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:18:18,121 - stpipe.step - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:18,124 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2026-09-16 12:18:18,158 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:18,158 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:18,170 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:18,478 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:18:18,553 - stpipe.step - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:18,556 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits
# 2026-09-16 12:18:18,577 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:18:18,577 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:18:18,580 - jwst.rscd.rscd_sub - INFO -  There are 65 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:18:18,613 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:18:18,616 - jwst.rscd.rscd_sub - INFO -  There are 63 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:18:18,622 - jwst.rscd.rscd_sub - INFO - Flagged 63 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-09-16 12:18:18,670 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 63
# 2026-09-16 12:18:18,673 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:18:18,757 - stpipe.step - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:18:18,760 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2026-09-16 12:18:19,594 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:18:19,621 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:18:19,622 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2026-09-16 12:18:19,622 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:18:20,158 - stpipe.step - INFO - Step dark_current done
# ...
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:25:33,750 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_04101_00004_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:25:33,752 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2026-09-16 12:25:33,753 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2026-09-16 12:25:33,754 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2026-09-16 12:25:33,754 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2026-09-16 12:25:33,755 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:25:33,755 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2026-09-16 12:25:33,756 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2026-09-16 12:25:33,756 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits'.
# 2026-09-16 12:25:33,757 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2026-09-16 12:25:33,758 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:25:33,758 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:25:33,758 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:25:33,759 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:25:33,977 - stpipe.step - INFO - Step group_scale running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:33,978 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:25:33,979 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:25:33,981 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:25:34,071 - stpipe.step - INFO - Step dq_init running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,074 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2026-09-16 12:25:34,138 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:34,163 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:25:34,274 - stpipe.step - INFO - Step emicorr running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,275 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:34,390 - stpipe.step - INFO - Step saturation running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,394 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2026-09-16 12:25:34,395 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:25:34,442 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:34,443 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:34,456 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:34,460 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:25:34,617 - stcal.saturation.saturation - INFO - Detected 2120 saturated pixels
# 2026-09-16 12:25:34,625 - stcal.saturation.saturation - INFO - Detected 28 A/D floor pixels
# 2026-09-16 12:25:34,629 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:25:34,717 - stpipe.step - INFO - Step ipc running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,718 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:34,832 - stpipe.step - INFO - Step firstframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,833 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:34,930 - stpipe.step - INFO - Step lastframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:34,933 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:25:35,016 - stpipe.step - INFO - Step reset running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:35,019 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2026-09-16 12:25:35,213 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,214 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,222 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,264 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:25:35,360 - stpipe.step - INFO - Step linearity running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:35,369 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2026-09-16 12:25:35,453 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,454 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,466 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:35,551 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:25:35,629 - stpipe.step - INFO - Step rscd running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:35,632 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits
# 2026-09-16 12:25:35,642 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:25:35,642 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:25:35,644 - jwst.rscd.rscd_sub - INFO -  There are 35 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:25:35,663 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:25:35,667 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:25:35,781 - stpipe.step - INFO - Step dark_current running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:35,790 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2026-09-16 12:25:36,092 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:36,121 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:25:36,122 - stcal.dark_current.dark_sub - INFO - Science data nints=1, ngroups=20, nframes=1, groupgap=0
# 2026-09-16 12:25:36,123 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:25:36,325 - stpipe.step - INFO - Step dark_current done
# 2026-09-16 12:25:36,410 - stpipe.step - INFO - Step refpix running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:36,412 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:36,513 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:36,514 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:36,690 - stpipe.step - INFO - Step jump running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:36,691 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-09-16 12:25:36,692 - jwst.jump.jump_step - INFO - Maximum cores to use = all
# 2026-09-16 12:25:36,695 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:25:36,701 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2026-09-16 12:25:36,759 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-09-16 12:25:36,760 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2026-09-16 12:25:38,062 - stcal.jump.jump - INFO - Flagging Showers
# 2026-09-16 12:25:44,885 - stcal.jump.jump - INFO - Total showers= 937
# 2026-09-16 12:25:44,886 - stcal.jump.jump - INFO - Total elapsed time = 8.12541 sec
# 2026-09-16 12:25:44,890 - jwst.jump.jump_step - INFO - The execution time in seconds: 8.198704
# 2026-09-16 12:25:44,892 - stpipe.step - INFO - Step jump done
# 2026-09-16 12:25:45,018 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:45,020 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:45,155 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:45,156 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:45,253 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:45,267 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2026-09-16 12:25:45,269 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:25:45,308 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-09-16 12:25:45,309 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-09-16 12:25:45,380 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-09-16 12:25:45,381 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 0
# 2026-09-16 12:25:45,382 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-09-16 12:25:46,135 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 0.7515053749084473
# 2026-09-16 12:25:46,176 - stpipe.step - INFO - Step ramp_fit done
# 2026-09-16 12:25:46,267 - stpipe.step - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:46,278 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:25:46,311 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:25:46,312 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:25:46,446 - stpipe.step - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:46,482 - py.warnings - WARNING - /tmp/ipykernel_25883/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
#
# 2026-09-16 12:25:46,488 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:25:46,492 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:25:46,499 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:25:46,674 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:46,687 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:25:46,730 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:25:46,732 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:25:46,872 - stpipe.step - INFO - Step xply running with args (<CubeModel(1, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2026-09-16 12:25:46,896 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:25:46,898 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:25:46,901 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:25:46,955 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage1/jw03722003001_04101_00004_mirifushort_rateints.fits
# 2026-09-16 12:25:46,956 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-09-16 12:25:46,956 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:25:47,007 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage1/jw03722003001_04101_00004_mirifushort_rate.fits
# 2026-09-16 12:25:47,007 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-09-16 12:25:47,008 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1

# %% [markdown]
# ### Calibrating Background Files
# Look for input background files and run calwebb_detector1
# pipeline using the call method.

# %%
# Now let's look for input files of the form *uncal.fits from the background
# observations
sstring = os.path.join(uncal_bgdir, 'jw*mirifu*uncal.fits')
uncal_files = np.array(sorted(glob.glob(sstring)))
# Check that these are the band/channel to use
uncal_files = select_ch_band_files(uncal_files, use_ch, use_band)

print('Found ' + str(len(uncal_files)) + ' background input files')
# Out:
# Found 4 background input files

# %%
# Run the pipeline on these input files by a simple loop over files using
# our custom parameter dictionary
if dodet1bg:
    for file in uncal_files:
        Detector1Pipeline.call(file, steps=det1dict, save_results=True, output_dir=det1_bgdir)
else:
    print('Skipping Detector1 processing for BG data')
# Out:
# 2026-09-16 12:25:47,072 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-09-16 12:25:47,088 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-09-16 12:25:47,099 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2026-09-16 12:25:47,111 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2026-09-16 12:25:47,125 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-09-16 12:25:47,125 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-09-16 12:25:47,126 - stpipe.step - INFO - DQInitStep instance created.
# 2026-09-16 12:25:47,127 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-09-16 12:25:47,128 - stpipe.step - INFO - SaturationStep instance created.
# 2026-09-16 12:25:47,129 - stpipe.step - INFO - IPCStep instance created.
# 2026-09-16 12:25:47,130 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-09-16 12:25:47,130 - stpipe.step - INFO - RefPixStep instance created.
# 2026-09-16 12:25:47,131 - stpipe.step - INFO - RscdStep instance created.
# 2026-09-16 12:25:47,132 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-09-16 12:25:47,132 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-09-16 12:25:47,133 - stpipe.step - INFO - LinearityStep instance created.
# 2026-09-16 12:25:47,134 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-09-16 12:25:47,134 - stpipe.step - INFO - ResetStep instance created.
# 2026-09-16 12:25:47,135 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-09-16 12:25:47,136 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-09-16 12:25:47,137 - stpipe.step - INFO - JumpStep instance created.
# 2026-09-16 12:25:47,138 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-09-16 12:25:47,139 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:25:47,139 - stpipe.step - INFO - RampFitStep instance created.
# 2026-09-16 12:25:47,140 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-09-16 12:25:47,141 - stpipe.step - INFO - XplyStep instance created.
# 2026-09-16 12:25:47,231 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_data/Obs007/uncal/jw03722007001_02101_00001_mirifulong_uncal.fits'),).
# 2026-09-16 12:25:47,263 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:25:47,291 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02101_00001_mirifulong_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:25:47,296 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits'.
# 2026-09-16 12:25:47,298 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits'.
# 2026-09-16 12:25:47,299 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits'.
# 2026-09-16 12:25:47,301 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits'.
# 2026-09-16 12:25:47,302 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:25:47,304 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits'.
# 2026-09-16 12:25:47,305 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits'.
# 2026-09-16 12:25:47,306 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0019.fits'.
# 2026-09-16 12:25:47,308 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits'.
# 2026-09-16 12:25:47,309 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:25:47,309 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:25:47,310 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:25:47,310 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:25:47,890 - stpipe.step - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:47,893 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:25:47,894 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:25:47,908 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:25:48,048 - stpipe.step - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:48,053 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits
# 2026-09-16 12:25:48,097 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:48,148 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:25:48,240 - stpipe.step - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:48,243 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:48,337 - stpipe.step - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:48,345 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits
# 2026-09-16 12:25:48,347 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:25:48,367 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:48,368 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:48,376 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:48,379 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:25:48,883 - stcal.saturation.saturation - INFO - Detected 448 saturated pixels
# 2026-09-16 12:25:48,916 - stcal.saturation.saturation - INFO - Detected 80 A/D floor pixels
# 2026-09-16 12:25:48,919 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:25:49,005 - stpipe.step - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:49,006 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:49,114 - stpipe.step - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:49,115 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:49,199 - stpipe.step - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:49,202 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:25:49,348 - stpipe.step - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:49,352 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits
# 2026-09-16 12:25:49,753 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:49,755 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:49,764 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:49,806 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:25:49,889 - stpipe.step - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:49,891 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits
# 2026-09-16 12:25:50,772 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:50,773 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:50,790 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:51,099 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:25:51,189 - stpipe.step - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:51,193 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0019.fits
# 2026-09-16 12:25:51,206 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:25:51,207 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:25:51,212 - jwst.rscd.rscd_sub - INFO -  There are 8 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:25:51,267 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:25:51,270 - jwst.rscd.rscd_sub - INFO -  There are 17 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:25:51,275 - jwst.rscd.rscd_sub - INFO - Flagged 17 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-09-16 12:25:51,321 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 17
# 2026-09-16 12:25:51,324 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:25:51,406 - stpipe.step - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:51,408 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0117.fits
# 2026-09-16 12:25:51,702 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:25:51,728 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:25:51,729 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2026-09-16 12:25:51,730 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:25:52,247 - stpipe.step - INFO - Step dark_current done
# 2026-09-16 12:25:52,337 - stpipe.step - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:52,339 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:52,437 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:52,439 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:25:52,622 - stpipe.step - INFO - Step jump running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:25:52,623 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-09-16 12:25:52,623 - jwst.jump.jump_step - INFO - Maximum cores to use = all
# 2026-09-16 12:25:52,625 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:25:52,627 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2026-09-16 12:25:52,724 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-09-16 12:25:52,725 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2026-09-16 12:25:55,012 - stcal.jump.jump - INFO - Flagging Showers
# 2026-09-16 12:26:36,823 - stcal.jump.jump - INFO - Total showers= 17252
# 2026-09-16 12:26:36,824 - stcal.jump.jump - INFO - Total elapsed time = 44.0984 sec
# 2026-09-16 12:26:36,835 - jwst.jump.jump_step - INFO - The execution time in seconds: 44.212914
# 2026-09-16 12:26:36,840 - stpipe.step - INFO - Step jump done
# 2026-09-16 12:26:36,929 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:36,930 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:26:37,032 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:37,033 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:26:37,124 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:37,129 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2026-09-16 12:26:37,130 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:26:37,157 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-09-16 12:26:37,158 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-09-16 12:26:37,372 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-09-16 12:26:37,374 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 0
# 2026-09-16 12:26:37,375 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-09-16 12:26:41,326 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 3.9494376182556152
# 2026-09-16 12:26:41,368 - stpipe.step - INFO - Step ramp_fit done
# 2026-09-16 12:26:41,464 - stpipe.step - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:41,468 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:26:41,481 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:26:41,482 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:26:41,591 - stpipe.step - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:41,607 - py.warnings - WARNING - /tmp/ipykernel_25883/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
#
# 2026-09-16 12:26:41,609 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:26:41,612 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:26:41,615 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:26:41,708 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:41,713 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2026-09-16 12:26:41,745 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:26:41,745 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:26:41,837 - stpipe.step - INFO - Step xply running with args (<CubeModel(2, 1024, 1032) from jw03722007001_02101_00001_mirifulong_uncal.fits>,).
# 2026-09-16 12:26:41,866 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:26:41,867 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:26:41,870 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:26:41,940 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rateints.fits
# 2026-09-16 12:26:41,941 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-09-16 12:26:41,942 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:26:41,987 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits
# 2026-09-16 12:26:41,988 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-09-16 12:26:41,988 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1
# 2026-09-16 12:26:42,009 - stpipe.step - INFO - PARS-EMICORRSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0003.asdf
# 2026-09-16 12:26:42,020 - stpipe.step - INFO - PARS-DARKCURRENTSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2026-09-16 12:26:42,028 - stpipe.step - INFO - PARS-JUMPSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0007.asdf
# 2026-09-16 12:26:42,037 - stpipe.pipeline - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0010.asdf
# 2026-09-16 12:26:42,049 - stpipe.step - INFO - Detector1Pipeline instance created.
# 2026-09-16 12:26:42,049 - stpipe.step - INFO - GroupScaleStep instance created.
# 2026-09-16 12:26:42,050 - stpipe.step - INFO - DQInitStep instance created.
# 2026-09-16 12:26:42,051 - stpipe.step - INFO - EmiCorrStep instance created.
# 2026-09-16 12:26:42,051 - stpipe.step - INFO - SaturationStep instance created.
# 2026-09-16 12:26:42,052 - stpipe.step - INFO - IPCStep instance created.
# 2026-09-16 12:26:42,053 - stpipe.step - INFO - SuperBiasStep instance created.
# 2026-09-16 12:26:42,054 - stpipe.step - INFO - RefPixStep instance created.
# 2026-09-16 12:26:42,055 - stpipe.step - INFO - RscdStep instance created.
# 2026-09-16 12:26:42,055 - stpipe.step - INFO - FirstFrameStep instance created.
# 2026-09-16 12:26:42,056 - stpipe.step - INFO - LastFrameStep instance created.
# 2026-09-16 12:26:42,057 - stpipe.step - INFO - LinearityStep instance created.
# 2026-09-16 12:26:42,057 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-09-16 12:26:42,058 - stpipe.step - INFO - ResetStep instance created.
# 2026-09-16 12:26:42,059 - stpipe.step - INFO - PersistenceStep instance created.
# 2026-09-16 12:26:42,060 - stpipe.step - INFO - ChargeMigrationStep instance created.
# 2026-09-16 12:26:42,061 - stpipe.step - INFO - JumpStep instance created.
# 2026-09-16 12:26:42,061 - stpipe.step - INFO - PictureFrameStep instance created.
# 2026-09-16 12:26:42,062 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:26:42,063 - stpipe.step - INFO - RampFitStep instance created.
# 2026-09-16 12:26:42,064 - stpipe.step - INFO - GainScaleStep instance created.
# 2026-09-16 12:26:42,065 - stpipe.step - INFO - XplyStep instance created.
# 2026-09-16 12:26:42,161 - stpipe.step - INFO - Step Detector1Pipeline running with args (np.str_('./mrs_data/Obs007/uncal/jw03722007001_02101_00001_mirifushort_uncal.fits'),).
# 2026-09-16 12:26:42,176 - stpipe.step - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs007/stage1
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       user_supplied_dq: None
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: joint
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 4.0
#       three_group_rejection_threshold: 100
#       four_group_rejection_threshold: 5.0
#       maximum_cores: all
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 10.0
#       after_jump_flag_dn1: 0.0
#       after_jump_flag_time1: 0.0
#       after_jump_flag_dn2: 0.0
#       after_jump_flag_time2: 0.0
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 5.0
#       expand_factor: 2.0
#       use_ellipses: False
#       sat_required_snowball: True
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: True
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     picture_frame:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       mask_science_regions: True
#       n_sigma: 2.0
#       save_mask: False
#       save_correction: False
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:26:42,194 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02101_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:26:42,197 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2026-09-16 12:26:42,197 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2026-09-16 12:26:42,198 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2026-09-16 12:26:42,198 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2026-09-16 12:26:42,199 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:26:42,199 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2026-09-16 12:26:42,200 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2026-09-16 12:26:42,201 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits'.
# 2026-09-16 12:26:42,201 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2026-09-16 12:26:42,202 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:26:42,202 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:26:42,203 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:26:42,203 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:26:42,751 - stpipe.step - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:42,752 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:26:42,753 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:26:42,757 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:26:42,870 - stpipe.step - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:42,873 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2026-09-16 12:26:42,902 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:42,943 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:26:43,051 - stpipe.step - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:43,052 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:26:43,147 - stpipe.step - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:43,160 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2026-09-16 12:26:43,164 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:26:43,220 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:43,222 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:43,240 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:43,246 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:26:43,725 - stcal.saturation.saturation - INFO - Detected 5253 saturated pixels
# 2026-09-16 12:26:43,757 - stcal.saturation.saturation - INFO - Detected 90 A/D floor pixels
# 2026-09-16 12:26:43,760 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:26:43,847 - stpipe.step - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:43,848 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:26:43,955 - stpipe.step - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:43,956 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:26:44,155 - stpipe.step - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:44,158 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:26:44,294 - stpipe.step - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:44,298 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2026-09-16 12:26:44,448 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,449 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,462 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,517 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:26:44,607 - stpipe.step - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:44,611 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2026-09-16 12:26:44,657 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,659 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,670 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:44,996 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:26:45,098 - stpipe.step - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:45,101 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits
# 2026-09-16 12:26:45,116 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:26:45,117 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:26:45,120 - jwst.rscd.rscd_sub - INFO -  There are 65 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:26:45,157 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:26:45,160 - jwst.rscd.rscd_sub - INFO -  There are 56 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:26:45,166 - jwst.rscd.rscd_sub - INFO - Flagged 56 pixels as FLUX_ESTIMATED due to RSCD back-off.
# 2026-09-16 12:26:45,219 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 56
# 2026-09-16 12:26:45,223 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:26:45,322 - stpipe.step - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:26:45,324 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2026-09-16 12:26:46,054 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:26:46,086 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:26:46,087 - stcal.dark_current.dark_sub - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2026-09-16 12:26:46,087 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:26:46,560 - stpipe.step - INFO - Step dark_current done
# 2026-09-16 12:26:46,645 - stpipe.step - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722007001_02101_00001_mirifushort_uncal.fits>,).
# ...
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks:
#       - !!python/name:__main__.XplyStep ''
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:27:42,705 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw03722007001_02102_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2026-09-16 12:27:42,708 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits'.
# 2026-09-16 12:27:42,709 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2026-09-16 12:27:42,710 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2026-09-16 12:27:42,711 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2026-09-16 12:27:42,711 - stpipe.pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2026-09-16 12:27:42,712 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2026-09-16 12:27:42,713 - stpipe.pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2026-09-16 12:27:42,714 - stpipe.pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits'.
# 2026-09-16 12:27:42,714 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2026-09-16 12:27:42,715 - stpipe.pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2026-09-16 12:27:42,715 - stpipe.pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2026-09-16 12:27:42,716 - stpipe.pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2026-09-16 12:27:42,716 - jwst.pipeline.calwebb_detector1 - INFO - Starting calwebb_detector1 ...
# 2026-09-16 12:27:42,951 - stpipe.step - INFO - Step group_scale running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:42,952 - jwst.group_scale.group_scale_step - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2026-09-16 12:27:42,953 - jwst.group_scale.group_scale_step - INFO - Step will be skipped
# 2026-09-16 12:27:42,955 - stpipe.step - INFO - Step group_scale done
# 2026-09-16 12:27:43,045 - stpipe.step - INFO - Step dq_init running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,048 - jwst.dq_init.dq_init_step - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2026-09-16 12:27:43,074 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:43,099 - stpipe.step - INFO - Step dq_init done
# 2026-09-16 12:27:43,185 - stpipe.step - INFO - Step emicorr running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,186 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:43,272 - stpipe.step - INFO - Step saturation running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,276 - jwst.saturation.saturation_step - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2026-09-16 12:27:43,276 - jwst.saturation.saturation_step - INFO - Using SUPERBIAS reference file N/A
# 2026-09-16 12:27:43,300 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:43,301 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:43,312 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:43,316 - jwst.saturation.saturation - INFO - Using read_pattern with nframes 1
# 2026-09-16 12:27:43,467 - stcal.saturation.saturation - INFO - Detected 2476 saturated pixels
# 2026-09-16 12:27:43,476 - stcal.saturation.saturation - INFO - Detected 33 A/D floor pixels
# 2026-09-16 12:27:43,480 - stpipe.step - INFO - Step saturation done
# 2026-09-16 12:27:43,584 - stpipe.step - INFO - Step ipc running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,585 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:43,676 - stpipe.step - INFO - Step firstframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,677 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:43,767 - stpipe.step - INFO - Step lastframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,771 - stpipe.step - INFO - Step lastframe done
# 2026-09-16 12:27:43,901 - stpipe.step - INFO - Step reset running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:43,905 - jwst.reset.reset_step - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2026-09-16 12:27:44,059 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,060 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,071 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,106 - stpipe.step - INFO - Step reset done
# 2026-09-16 12:27:44,204 - stpipe.step - INFO - Step linearity running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:44,207 - jwst.linearity.linearity_step - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2026-09-16 12:27:44,232 - stdatamodels.dynamicdq - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,233 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,242 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,344 - stpipe.step - INFO - Step linearity done
# 2026-09-16 12:27:44,446 - stpipe.step - INFO - Step rscd running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:44,448 - jwst.rscd.rscd_step - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0021.fits
# 2026-09-16 12:27:44,459 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 1 to flag: 0
# 2026-09-16 12:27:44,460 - jwst.rscd.rscd_sub - INFO - # groups from RSCD reference file for int 2 and higher to flag: 1
# 2026-09-16 12:27:44,462 - jwst.rscd.rscd_sub - INFO -  There are 35 saturated pixels that require the number of rscd groups flagged to be lowered
# 2026-09-16 12:27:44,482 - jwst.rscd.rscd_sub - INFO - Number of usable bright pixels with rscd flag groups not set to DO_NOT_USE: 0
# 2026-09-16 12:27:44,485 - stpipe.step - INFO - Step rscd done
# 2026-09-16 12:27:44,568 - stpipe.step - INFO - Step dark_current running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:44,571 - jwst.dark_current.dark_current_step - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0116.fits
# 2026-09-16 12:27:44,863 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:27:44,894 - jwst.dark_current.dark_current_step - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2026-09-16 12:27:44,895 - stcal.dark_current.dark_sub - INFO - Science data nints=1, ngroups=20, nframes=1, groupgap=0
# 2026-09-16 12:27:44,896 - stcal.dark_current.dark_sub - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2026-09-16 12:27:45,092 - stpipe.step - INFO - Step dark_current done
# 2026-09-16 12:27:45,178 - stpipe.step - INFO - Step refpix running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:45,179 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:45,265 - stpipe.step - INFO - Step charge_migration running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:45,266 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:45,378 - stpipe.step - INFO - Step jump running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:45,379 - jwst.jump.jump_step - INFO - CR rejection threshold = 4 sigma
# 2026-09-16 12:27:45,380 - jwst.jump.jump_step - INFO - Maximum cores to use = all
# 2026-09-16 12:27:45,382 - jwst.jump.jump_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:27:45,385 - jwst.jump.jump_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2026-09-16 12:27:45,435 - stcal.jump.jump - INFO - Executing two-point difference method
# 2026-09-16 12:27:45,436 - stcal.jump.jump - INFO - Creating 16 processes for jump detection
# 2026-09-16 12:27:46,786 - stcal.jump.jump - INFO - Flagging Showers
# 2026-09-16 12:27:54,054 - stcal.jump.jump - INFO - Total showers= 1212
# 2026-09-16 12:27:54,055 - stcal.jump.jump - INFO - Total elapsed time = 8.61951 sec
# 2026-09-16 12:27:54,060 - jwst.jump.jump_step - INFO - The execution time in seconds: 8.681156
# 2026-09-16 12:27:54,063 - stpipe.step - INFO - Step jump done
# 2026-09-16 12:27:54,148 - stpipe.step - INFO - Step picture_frame running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:54,150 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:54,236 - stpipe.step - INFO - Step clean_flicker_noise running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:54,237 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:54,348 - stpipe.step - INFO - Step ramp_fit running with args (<RampModel(1, 20, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:54,358 - jwst.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2026-09-16 12:27:54,359 - jwst.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:27:54,403 - jwst.ramp_fitting.ramp_fit_step - INFO - Using algorithm = OLS_C
# 2026-09-16 12:27:54,403 - jwst.ramp_fitting.ramp_fit_step - INFO - Using weighting = optimal
# 2026-09-16 12:27:54,499 - stcal.ramp_fitting.ols_fit - INFO - Number of multiprocessing slices: 1
# 2026-09-16 12:27:54,500 - stcal.ramp_fitting.ols_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 0
# 2026-09-16 12:27:54,501 - stcal.ramp_fitting.ols_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2026-09-16 12:27:55,288 - stcal.ramp_fitting.ols_fit - INFO - Ramp Fitting C Time: 0.7850182056427002
# 2026-09-16 12:27:55,342 - stpipe.step - INFO - Step ramp_fit done
# 2026-09-16 12:27:55,464 - stpipe.step - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:55,467 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:27:55,480 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:27:55,481 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:27:55,570 - stpipe.step - INFO - Step xply running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:55,586 - py.warnings - WARNING - /tmp/ipykernel_25883/3735983842.py:14: DeprecationWarning: The Step.log attribute is deprecated and will be removed in a future release. Please use a local logger, retrieved via logging.getLogger.
#   self.log.info('Multiplied everything by one in custom step!')
#
# 2026-09-16 12:27:55,587 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:27:55,588 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:27:55,591 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:27:55,687 - stpipe.step - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:55,691 - jwst.gain_scale.gain_scale_step - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2026-09-16 12:27:55,706 - jwst.gain_scale.gain_scale_step - INFO - GAINFACT not found in gain reference file
# 2026-09-16 12:27:55,707 - jwst.gain_scale.gain_scale_step - INFO - Step will be skipped
# 2026-09-16 12:27:55,790 - stpipe.step - INFO - Step xply running with args (<CubeModel(1, 1024, 1032) from jw03722007001_02102_00001_mirifushort_uncal.fits>,).
# 2026-09-16 12:27:55,806 - stpipe.Detector1Pipeline.gain_scale.xply - INFO - Multiplied everything by one in custom step!
# 2026-09-16 12:27:55,808 - stpipe.step - INFO - Step xply done
# 2026-09-16 12:27:55,811 - stpipe.step - INFO - Step gain_scale done
# 2026-09-16 12:27:55,862 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rateints.fits
# 2026-09-16 12:27:55,863 - jwst.pipeline.calwebb_detector1 - INFO - ... ending calwebb_detector1
# 2026-09-16 12:27:55,864 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:27:55,911 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rate.fits
# 2026-09-16 12:27:55,911 - stpipe.step - INFO - Step Detector1Pipeline done
# 2026-09-16 12:27:55,912 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
# Out:
# Runtime so far: 633.6632 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 6.<font color='white'>-</font>Spec2 Pipeline<a class="anchor" id="spec2"></a>
# ------------------
#
# In this section we process our countrate (slope) image products from
# Stage 1 (calwebb_detector1) through the Spec2 (calwebb_spec2) pipeline
# in order to produce Stage 2
# data products (i.e., calibrated slope images and quick-look data cubes
# and 1d spectra).  These data products have units of MJy/sr (or Jy for
# extracted point-source spectra).
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_spec2
#
# <div class="alert alert-block alert-warning">
# If pixel-based background subtraction was chosen above, this will be
# applied during this stage.
#
# To override certain steps and reference files use the examples below.
# </div>

# %%
time_spec2 = time.perf_counter()

# %%
# Set up a dictionary to define how the Spec2 pipeline should be configured.

# Boilerplate dictionary setup
spec2dict = defaultdict(dict)


# old setup:
# spec2dict = {}
# spec2dict['assign_wcs'], spec2dict['badpix_selfcal'], spec2dict['bkg_subtract'], spec2dict['flat_field'], spec2dict['srctype'] = {}, {}, {}, {}, {}
# spec2dict['straylight'], spec2dict['fringe'], spec2dict['photom'], spec2dict['residual_fringe'], spec2dict['pixel_replace'] = {}, {}, {}, {}, {}
# spec2dict['cube_build'], spec2dict['extract_1d'] = {}, {}


# Overrides for whether or not certain steps should be skipped (example)
#spec2dict['straylight']['skip'] = True

# Pixel-based background usage was set up above, propagate that here
if (pixel_bg is True):
    spec2dict['bkg_subtract']['skip'] = False
else:
    spec2dict['bkg_subtract']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#spec2dict['assign_wcs']['override_distortion'] = 'myfile.asdf' # Spatial distortion (ASDF file)
#spec2dict['assign_wcs']['override_regions'] = 'myfile.asdf' # IFU slice regions on detector (ASDF file)
#spec2dict['assign_wcs']['override_specwcs'] = 'myfile.asdf' # Spectral distortion (ASDF file)
#spec2dict['assign_wcs']['override_wavelengthrange'] = 'myfile.asdf' # Wavelength channel mapping (ASDF file)
#spec2dict['flat_field']['override_flat'] = 'myfile.fits' # Pixel flatfield
#spec2dict['straylight']['override_mrsxartcorr'] = 'myfile.fits' # Cross-artifact model parameters
#spec2dict['fringe']['override_fringe'] = 'myfile.fits' # Static fringe-flat
#spec2dict['photom']['override_photom'] = 'myfile.fits' # Photometric calibration array
#spec2dict['cube_build']['override_cubepar'] = 'myfile.fits' # Cube-building parameters
#spec2dict['extract_1d']['override_extract1d'] = 'myfile.asdf' # Spectral extraction parameters (ASDF file)
#spec2dict['extract_1d']['override_apcorr'] = 'myfile.asdf' # Aperture correction parameters (ASDF file)

# Turn on residual cosmic-ray shower correction (off by default)
# (see https://jwst-docs.stsci.edu/known-issues-with-jwst-data/shower-and-snowball-artifacts)
spec2dict['straylight']['clean_showers'] = True

# Turn on 2d residual fringe correction (off by default)
# This can sometimes improve residual fringing in science results, but takes
# a long time to run and often does not work as well as 1d residual fringe
# correction (in calwebb_spec3)
spec2dict['residual_fringe']['skip'] = False

# Turn on bad pixel self-calibration, where all exposures on a given detector are used to find and
# flag bad pixels that may have been missed by the bad pixel mask.
# This step is experimental, and works best when dedicated background observations are included
#spec2dict['badpix_selfcal']['skip'] = False
#spec2dict['badpix_selfcal']['flagfrac_upper']=0.005 # Fraction of pixels to flag (dial as desired; 1.0 would be 100% of pixels)

# %% [markdown]
# Define a function to create association files for Stage 2. This will enable use of the pixel-based background subtraction, if chosen above. This requires *one* input SCI file, but can have multiple input background files.
#
# <div class="alert alert-block alert-warning">
# Note that the background will not be applied properly to all files if more than *one* SCI file is included in the association.
# </div>

# %%
def writel2asn(onescifile, bgfiles, selfcalfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list([onescifile], rule=DMSLevel2bBase, product_name=prodname)  # Wrap in array since input was single exposure

    #Channel/band configuration for this sci file
    with fits.open(onescifile) as hdu:
        hdu.verify()
        hdr = hdu[0].header
        this_channel, this_band = hdr['CHANNEL'], hdr['BAND']

    # If backgrounds were provided, find which are appropriate to this
    # channel/band and add to association
    for file in bgfiles:
        with fits.open(file) as hdu:
            hdu.verify()
            if ((hdu[0].header['CHANNEL'] == this_channel) & (hdu[0].header['BAND'] == this_band)):
                asn['products'][0]['members'].append({'expname': file, 'exptype': 'background'})
                
    # If provided with a list of files to use for bad pixel self-calibration, find which
    # are appropriate to this detector and add to association
    for file in selfcalfiles:
        with fits.open(file) as hdu:
            hdu.verify()
            if (hdu[0].header['CHANNEL'] == this_channel):
                asn['products'][0]['members'].append({'expname': file, 'exptype': 'selfcal'})                

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths

# %%
sstring = os.path.join(det1_dir, 'jw*mirifu*rate.fits')  # Use files from the detector1 output folder
ratefiles = sorted(glob.glob(sstring))
for ii in range(0, len(ratefiles)):
    ratefiles[ii] = os.path.abspath(ratefiles[ii])
ratefiles = np.array(ratefiles)
# Check that these are the band/channel to use
ratefiles = select_ch_band_files(ratefiles, use_ch, use_band)

# Background Files
sstring = os.path.join(det1_bgdir, 'jw*mirifu*rate.fits')
bgfiles = sorted(glob.glob(sstring))
for ii in range(0, len(bgfiles)):
    bgfiles[ii] = os.path.abspath(bgfiles[ii])
bgfiles = np.array(bgfiles)
# Check that these are the band/channel to use
bgfiles = select_ch_band_files(bgfiles, use_ch, use_band)

# Define any files to use for self-calibration (if step enabled)
# Typically this is all science and background exposures
selfcalfiles = ratefiles.copy()
selfcalfiles = np.append(selfcalfiles, bgfiles)

print('Found ' + str(len(ratefiles)) + ' science files')
print('Found ' + str(len(bgfiles)) + ' background files')
print('Found ' + str(len(selfcalfiles)) + ' potential selfcal files')
# Out:
# Found 16 science files
# Found 4 background files
# Found 20 potential selfcal files

# %% [markdown]
# Step through each of the science files, using relevant associated backgrounds in calwebb_spec2 processing.
#
# <div class="alert alert-block alert-warning">
# The background files are used in this step to perform pixel-based background subtraction (if desired), otherwise background subtraction is done later with Spec3 files.
# </div>

# %%
# Important block to look when checking intermediate pipeline products


# To save runtime, make a new version of our spec2 parameter dictionary
# that turns off creation of quicklook cubes and 1d spectra for science
# data
spec2dict_sci = copy.deepcopy(spec2dict)
spec2dict_sci['cube_build']['skip'] = True
spec2dict_sci['extract_1d']['skip'] = True

if dospec2:
    for file in ratefiles:
        asnfile = os.path.join(sci_dir, 'l2asn.json')
        writel2asn(file, bgfiles, selfcalfiles, asnfile, 'Level2')
        Spec2Pipeline.call(asnfile, steps=spec2dict_sci, save_results=True, output_dir=spec2_dir)
else:
    print('Skipping Spec2 processing for SCI data')
# Out:
# /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-09-16 12:27:56,241 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:27:56,248 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:27:56,255 - CRDS - ERROR -  Error determining best reference for 'pars-targcentroidstep'  =   Unknown reference type 'pars-targcentroidstep'
# 2026-09-16 12:27:56,261 - stpipe.step - INFO - PARS-ADAPTIVETRACEMODELSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-adaptivetracemodelstep_0001.asdf
# 2026-09-16 12:27:56,268 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:27:56,275 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:27:56,281 - stpipe.pipeline - INFO - PARS-SPEC2PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec2pipeline_0005.asdf
# 2026-09-16 12:27:56,299 - stpipe.step - INFO - Spec2Pipeline instance created.
# 2026-09-16 12:27:56,300 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-16 12:27:56,301 - stpipe.step - INFO - BadpixSelfcalStep instance created.
# 2026-09-16 12:27:56,302 - stpipe.step - INFO - MSAFlagOpenStep instance created.
# 2026-09-16 12:27:56,303 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:27:56,304 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-09-16 12:27:56,305 - stpipe.step - INFO - ImprintStep instance created.
# 2026-09-16 12:27:56,306 - stpipe.step - INFO - Extract2dStep instance created.
# 2026-09-16 12:27:56,310 - stpipe.step - INFO - MasterBackgroundMosStep instance created.
# 2026-09-16 12:27:56,311 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-16 12:27:56,312 - stpipe.step - INFO - PathLossStep instance created.
# 2026-09-16 12:27:56,313 - stpipe.step - INFO - BarShadowStep instance created.
# 2026-09-16 12:27:56,313 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-16 12:27:56,315 - stpipe.step - INFO - PixelReplaceStep instance created.
# 2026-09-16 12:27:56,316 - stpipe.step - INFO - ResampleSpecStep instance created.
# 2026-09-16 12:27:56,317 - stpipe.step - INFO - Extract1dStep instance created.
# 2026-09-16 12:27:56,318 - stpipe.step - INFO - TargCentroidStep instance created.
# 2026-09-16 12:27:56,319 - stpipe.step - INFO - WavecorrStep instance created.
# 2026-09-16 12:27:56,320 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-16 12:27:56,321 - stpipe.step - INFO - SourceTypeStep instance created.
# 2026-09-16 12:27:56,322 - stpipe.step - INFO - StraylightStep instance created.
# 2026-09-16 12:27:56,323 - stpipe.step - INFO - FringeStep instance created.
# 2026-09-16 12:27:56,324 - stpipe.step - INFO - ResidualFringeStep instance created.
# 2026-09-16 12:27:56,325 - stpipe.step - INFO - PathLossStep instance created.
# 2026-09-16 12:27:56,325 - stpipe.step - INFO - BarShadowStep instance created.
# 2026-09-16 12:27:56,327 - stpipe.step - INFO - WfssContamStep instance created.
# 2026-09-16 12:27:56,327 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-16 12:27:56,328 - stpipe.step - INFO - AdaptiveTraceModelStep instance created.
# 2026-09-16 12:27:56,329 - stpipe.step - INFO - PixelReplaceStep instance created.
# 2026-09-16 12:27:56,330 - stpipe.step - INFO - ResampleSpecStep instance created.
# 2026-09-16 12:27:56,332 - stpipe.step - INFO - CubeBuildStep instance created.
# 2026-09-16 12:27:56,333 - stpipe.step - INFO - Extract1dStep instance created.
# 2026-09-16 12:27:56,432 - stpipe.step - INFO - Step Spec2Pipeline running with args ('./mrs_data/Obs003/l2asn.json',).
# 2026-09-16 12:27:56,457 - stpipe.step - INFO - Step Spec2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs003/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   fail_on_exception: True
#   save_wfss_esec: False
#   steps:
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     badpix_selfcal:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       flagfrac_lower: 0.001
#       flagfrac_upper: 0.001
#       kernel_size: 15
#       force_single: False
#       save_flagged_bkg: False
#     msa_flagging:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     imprint_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     extract_2d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       slit_names: None
#       source_ids: None
#       source_ra: None
#       source_dec: None
#       source_max_sep: 2.0
#       extract_orders: None
#       grism_objects: None
#       tsgrism_extract_height: None
#       wfss_extract_half_height: 5
#       wfss_mmag_extract: None
#       wfss_nbright: 1000
#     master_background_mos:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sigma_clip: 3.0
#       median_kernel: 1
#       force_subtract: False
#       save_background: False
#       user_background: None
#       inverse: False
#       steps:
#         flat_field:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           save_interpolated_flat: False
#           user_supplied_flat: None
#           inverse: False
#         pathloss:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           user_slit_loc: None
#         barshadow:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#         photom:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           apply_time_correction: True
#         pixel_replace:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: True
#           output_use_index: True
#           save_results: False
#           skip: True
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           algorithm: fit_profile
#           n_adjacent_cols: 3
#         resample_spec:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           pixfrac: 1.0
#           kernel: square
#           fillval: NAN
#           weight_type: exptime
#           output_shape: None
#           pixel_scale_ratio: 1.0
#           pixel_scale: None
#           output_wcs: ''
#           single: False
#           blendheaders: True
#           in_memory: True
#           propagate_dq: False
#         extract_1d:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           subtract_background: None
#           apply_apcorr: True
#           extraction_type: box
#           use_source_posn: None
#           position_offset: 0.0
#           model_nod_pair: True
#           optimize_psf_location: True
#           smoothing_length: None
#           bkg_fit: None
#           bkg_order: None
#           log_increment: 50
#           save_profile: False
#           save_scene_model: False
#           save_residual_image: False
#           center_xy: None
#           ifu_autocen: True
#           bkg_sigma_clip: 3.0
#           ifu_rfcorr: True
#           ifu_set_srctype: None
#           ifu_rscale: None
#           ifu_covar_scale: 1.8
#           soss_atoca: True
#           soss_threshold: 0.01
#           soss_n_os: 2
#           soss_wave_grid_in: None
#           soss_wave_grid_out: None
#           soss_estimate: None
#           soss_rtol: 0.0001
#           soss_max_grid_size: 20000
#           soss_tikfac: None
#           soss_width: 40.0
#           soss_bad_pix: masking
#           soss_modelname: None
#           soss_order_3: True
#     targ_centroid:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       ta_file: None
#     wavecorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     srctype:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       source_type: None
#     straylight:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       clean_showers: True
#       shower_plane: 3
#       shower_x_stddev: 18.0
#       shower_y_stddev: 5.0
#       shower_low_reject: 0.1
#       shower_high_reject: 99.9
#       save_shower_model: False
#     fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     residual_fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: residual_fringe
#       search_output_file: False
#       input_dir: ''
#       save_intermediate_results: False
#       ignore_region_min: None
#       ignore_region_max: None
#     pathloss:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       user_slit_loc: None
#     barshadow:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#     wfss_contam:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_simulated_image: False
#       save_contam_images: False
#       maximum_cores: '1'
#       orders: None
#       magnitude_limit: None
#       wl_oversample: 2
#       max_pixels_per_chunk: 5000
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     adaptive_trace_model:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_threshold: 10.0
#       oversample: 3
#       slope_limit: 0.1
#       psf_optimal: False
#       save_intermediate_results: False
#     pixel_replace:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: fit_profile
#       n_adjacent_cols: 3
#     resample_spec:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       propagate_dq: False
#     cube_build:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: s3d
#       search_output_file: False
#       input_dir: ''
#       pipeline: 3
#       channel: all
#       band: all
#       grating: all
#       filter: all
#       output_type: None
#       linear_wave: True
#       scalexy: 0.0
#       scalew: 0.0
#       weighting: drizzle
#       coord_system: skyalign
#       ra_center: None
#       dec_center: None
#       cube_pa: None
#       nspax_x: None
#       nspax_y: None
#       rois: 0.0
#       roiw: 0.0
#       weight_power: 2.0
#       wavemin: None
#       wavemax: None
#       single: False
#       skip_dqflagging: False
#       offset_file: None
#       debug_spaxel: -1 -1 -1
#     extract_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       subtract_background: None
#       apply_apcorr: True
#       extraction_type: box
#       use_source_posn: None
#       position_offset: 0.0
#       model_nod_pair: True
#       optimize_psf_location: True
#       smoothing_length: None
#       bkg_fit: None
#       bkg_order: None
#       log_increment: 50
#       save_profile: False
#       save_scene_model: False
#       save_residual_image: False
#       center_xy: None
#       ifu_autocen: True
#       bkg_sigma_clip: 3.0
#       ifu_rfcorr: True
#       ifu_set_srctype: None
#       ifu_rscale: None
#       ifu_covar_scale: 1.8
#       soss_atoca: True
#       soss_threshold: 0.01
#       soss_n_os: 2
#       soss_wave_grid_in: None
#       soss_wave_grid_out: None
#       soss_estimate: None
#       soss_rtol: 0.0001
#       soss_max_grid_size: 20000
#       soss_tikfac: None
#       soss_width: 40.0
#       soss_bad_pix: masking
#       soss_modelname: None
#       soss_order_3: True
# 2026-09-16 12:27:56,497 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'l2asn.json' reftypes = ['area', 'barshadow', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'fringefreq', 'ifufore', 'ifupost', 'ifuslicer', 'mrsxartcorr', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange']
# 2026-09-16 12:27:56,501 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-09-16 12:27:56,502 - stpipe.pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2026-09-16 12:27:56,502 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-09-16 12:27:56,502 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-09-16 12:27:56,503 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-09-16 12:27:56,504 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-09-16 12:27:56,504 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-09-16 12:27:56,505 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0145.asdf'.
# 2026-09-16 12:27:56,505 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-09-16 12:27:56,506 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2026-09-16 12:27:56,506 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0824.fits'.
# 2026-09-16 12:27:56,507 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-09-16 12:27:56,507 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-09-16 12:27:56,508 - stpipe.pipeline - INFO - Prefetch for FRINGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0074.fits'.
# 2026-09-16 12:27:56,509 - stpipe.pipeline - INFO - Prefetch for FRINGEFREQ reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0003.fits'.
# 2026-09-16 12:27:56,509 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-09-16 12:27:56,510 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-09-16 12:27:56,510 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-09-16 12:27:56,511 - stpipe.pipeline - INFO - Prefetch for MRSXARTCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits'.
# 2026-09-16 12:27:56,512 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-09-16 12:27:56,513 - stpipe.pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2026-09-16 12:27:56,513 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-09-16 12:27:56,513 - stpipe.pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2026-09-16 12:27:56,514 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0225.fits'.
# 2026-09-16 12:27:56,515 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf'.
# 2026-09-16 12:27:56,516 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-09-16 12:27:56,516 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0144.asdf'.
# 2026-09-16 12:27:56,518 - stpipe.pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2026-09-16 12:27:56,519 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0011.asdf'.
# 2026-09-16 12:27:56,519 - jwst.pipeline.calwebb_spec2 - INFO - Starting calwebb_spec2 ...
# 2026-09-16 12:27:56,525 - jwst.pipeline.calwebb_spec2 - INFO - Processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong
# 2026-09-16 12:27:56,526 - jwst.pipeline.calwebb_spec2 - INFO - Working on input /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong_rate.fits ...
# 2026-09-16 12:27:56,659 - stpipe.step - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:27:56,995 - jwst.assign_wcs.miri - INFO - Applied Barycentric velocity correction : 0.9999201354236006
# 2026-09-16 12:27:57,848 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0145.asdf', 'filteroffset': None, 'specwcs': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0144.asdf', 'regions': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf', 'wavelengthrange': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0011.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-09-16 12:27:58,528 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809027372 42.471676858 171.812793712 42.471676858 171.812793712 42.474523062 171.809027372 42.474523062
# 2026-09-16 12:27:58,529 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-09-16 12:27:58,533 - stpipe.step - INFO - Step assign_wcs done
# 2026-09-16 12:27:58,660 - stpipe.step - INFO - Step badpix_selfcal running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00002_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00003_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00004_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00002_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00003_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00004_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifulong_rate.fits'], ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits']).
# 2026-09-16 12:27:58,662 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:58,765 - stpipe.step - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:27:58,767 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:58,874 - stpipe.step - INFO - Step clean_flicker_noise running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:27:58,876 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:58,991 - stpipe.step - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>, []).
# 2026-09-16 12:27:58,993 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:59,127 - stpipe.step - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits', []).
# 2026-09-16 12:27:59,127 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:27:59,231 - stpipe.step - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits']).
# 2026-09-16 12:27:59,527 - jwst.background.background_step - INFO - Working on input <IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits> ...
# 2026-09-16 12:27:59,542 - jwst.background.background_sub - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits
# 2026-09-16 12:27:59,666 - jwst.background.background_sub - INFO - Subtracting avg bkg from jw03722003001_02101_00001_mirifulong_rate.fits
# 2026-09-16 12:27:59,670 - stpipe.step - INFO - Step bkg_subtract done
# 2026-09-16 12:27:59,822 - stpipe.step - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:27:59,824 - jwst.srctype.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2026-09-16 12:27:59,824 - jwst.srctype.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2026-09-16 12:27:59,825 - jwst.srctype.srctype - INFO - Using input source type = EXTENDED
# 2026-09-16 12:27:59,827 - stpipe.step - INFO - Step srctype done
# 2026-09-16 12:27:59,943 - stpipe.step - INFO - Step targ_centroid running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:27:59,946 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:00,078 - stpipe.step - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:00,103 - jwst.straylight.straylight_step - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2026-09-16 12:28:00,180 - jwst.straylight.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# 2026-09-16 12:28:16,164 - jwst.straylight.straylight - INFO - Found parameters for right detector half, applying Cross-Artifact correction.
# 2026-09-16 12:28:30,965 - jwst.straylight.straylight - INFO - Derived pedestal correction -0.0008417218923568726 DN/s
# 2026-09-16 12:28:30,966 - jwst.straylight.straylight - INFO - Cross-artifact model complete.
# 2026-09-16 12:28:30,981 - jwst.straylight.straylight - INFO - Applying correction for residual cosmic ray showers.
# 2026-09-16 12:28:31,191 - stpipe.step - INFO - Step straylight done
# 2026-09-16 12:28:31,317 - stpipe.step - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:31,376 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:28:31,379 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0824.fits
# 2026-09-16 12:28:31,380 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-09-16 12:28:31,381 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-09-16 12:28:31,382 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-09-16 12:28:31,424 - stpipe.step - INFO - Step flat_field done
# 2026-09-16 12:28:31,534 - stpipe.step - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:31,539 - jwst.fringe.fringe_step - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0074.fits
# 2026-09-16 12:28:31,569 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:28:31,569 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:28:31,570 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:28:31,583 - stpipe.step - INFO - Step fringe done
# 2026-09-16 12:28:31,692 - stpipe.step - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:31,693 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:31,832 - stpipe.step - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:31,833 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:31,960 - stpipe.step - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:31,970 - jwst.photom.photom_step - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0225.fits
# 2026-09-16 12:28:31,971 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-09-16 12:28:31,972 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-09-16 12:28:31,972 - jwst.photom.photom - INFO -  detector: MIRIFULONG
# 2026-09-16 12:28:31,973 - jwst.photom.photom - INFO -  exp_type: MIR_MRS
# 2026-09-16 12:28:31,974 - jwst.photom.photom - INFO -  band: LONG
# 2026-09-16 12:28:32,041 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:28:32,045 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-09-16 12:28:32,046 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-09-16 12:28:32,055 - jwst.photom.photom - INFO - Applying MRS IFU time dependent correction.
# 2026-09-16 12:28:32,500 - stpipe.step - INFO - Step photom done
# 2026-09-16 12:28:32,600 - stpipe.step - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:28:32,609 - jwst.residual_fringe.residual_fringe_step - INFO - Using FRINGEFREQ reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0003.fits
# 2026-09-16 12:28:32,612 - jwst.residual_fringe.residual_fringe_step - INFO - Using MRS regions reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf
# 2026-09-16 12:28:32,672 - jwst.residual_fringe.residual_fringe - INFO -  Using 8 throughput threshold.
# 2026-09-16 12:28:32,673 - jwst.residual_fringe.residual_fringe - INFO - Detector mirifulong [3, 4]
# 2026-09-16 12:28:33,154 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 3
# 2026-09-16 12:28:33,161 - jwst.residual_fringe.utils - INFO - Number of slices in channel 16
# 2026-09-16 12:28:33,242 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 301.0 =================================
# 2026-09-16 12:28:33,252 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 302.0 =================================
# 2026-09-16 12:28:33,262 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 303.0 =================================
# 2026-09-16 12:28:33,278 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 304.0 =================================
# 2026-09-16 12:28:33,293 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 305.0 =================================
# 2026-09-16 12:28:33,305 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 306.0 =================================
# 2026-09-16 12:28:33,315 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 307.0 =================================
# 2026-09-16 12:28:33,324 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 308.0 =================================
# 2026-09-16 12:28:33,335 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 309.0 =================================
# 2026-09-16 12:28:33,345 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 310.0 =================================
# 2026-09-16 12:28:33,354 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 311.0 =================================
# 2026-09-16 12:28:33,366 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 312.0 =================================
# 2026-09-16 12:28:33,381 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 313.0 =================================
# 2026-09-16 12:28:33,393 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 314.0 =================================
# 2026-09-16 12:28:33,404 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 315.0 =================================
# 2026-09-16 12:28:33,413 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 316.0 =================================
# 2026-09-16 12:28:33,421 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:28:33,422 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 4
# 2026-09-16 12:28:33,426 - jwst.residual_fringe.utils - INFO - Number of slices in channel 12
# 2026-09-16 12:28:33,483 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 401.0 =================================
# 2026-09-16 12:28:33,494 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 402.0 =================================
# 2026-09-16 12:28:33,546 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,548 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=363 402.0:
# 2026-09-16 12:28:33,549 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,553 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 403.0 =================================
# 2026-09-16 12:28:33,604 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,606 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=290 403.0:
# 2026-09-16 12:28:33,606 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,611 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 404.0 =================================
# 2026-09-16 12:28:33,649 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,650 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=216 404.0:
# 2026-09-16 12:28:33,651 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,654 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 405.0 =================================
# 2026-09-16 12:28:33,690 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,691 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=140 405.0:
# 2026-09-16 12:28:33,692 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,729 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,731 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=167 405.0:
# 2026-09-16 12:28:33,731 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,732 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 406.0 =================================
# 2026-09-16 12:28:33,741 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 407.0 =================================
# 2026-09-16 12:28:33,780 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,781 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=399 407.0:
# 2026-09-16 12:28:33,782 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,785 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 408.0 =================================
# 2026-09-16 12:28:33,794 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 409.0 =================================
# 2026-09-16 12:28:33,802 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 410.0 =================================
# 2026-09-16 12:28:33,841 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,842 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=178 410.0:
# 2026-09-16 12:28:33,843 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,846 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 411.0 =================================
# 2026-09-16 12:28:33,883 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,885 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=103 411.0:
# 2026-09-16 12:28:33,885 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,889 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 412.0 =================================
# 2026-09-16 12:28:33,929 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,930 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=25 412.0:
# 2026-09-16 12:28:33,931 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,966 - py.warnings - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/timeseries/periodograms/lombscargle/implementations/main.py:228: RuntimeWarning: invalid value encountered in scalar divide
#   PLS = METHODS[method](*args, **kwds)
#
# 2026-09-16 12:28:33,967 - jwst.residual_fringe.residual_fringe - WARNING -   Skipping col=26 412.0:
# 2026-09-16 12:28:33,967 - jwst.residual_fringe.residual_fringe - WARNING -   index 0 is out of bounds for axis 0 with size 0
# 2026-09-16 12:28:33,972 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:28:33,973 - jwst.residual_fringe.residual_fringe - INFO - Processing complete
# 2026-09-16 12:28:33,979 - stpipe.step - INFO - Step residual_fringe done
# 2026-09-16 12:28:34,364 - stpipe.step - INFO - Step adaptive_trace_model running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:28:34,370 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:34,606 - stpipe.step - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:28:34,607 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:34,751 - stpipe.step - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:28:34,753 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:35,145 - stpipe.step - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:28:35,146 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:28:35,149 - jwst.pipeline.calwebb_spec2 - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong
# 2026-09-16 12:28:35,150 - jwst.pipeline.calwebb_spec2 - INFO - Ending calwebb_spec2
# 2026-09-16 12:28:35,151 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:28:36,255 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage2/jw03722003001_02101_00001_mirifulong_cal.fits
# 2026-09-16 12:28:36,256 - stpipe.step - INFO - Step Spec2Pipeline done
# 2026-09-16 12:28:36,257 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1
# /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-09-16 12:28:36,428 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:28:36,434 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:28:36,441 - CRDS - ERROR -  Error determining best reference for 'pars-targcentroidstep'  =   Unknown reference type 'pars-targcentroidstep'
# 2026-09-16 12:28:36,447 - stpipe.step - INFO - PARS-ADAPTIVETRACEMODELSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-adaptivetracemodelstep_0001.asdf
# 2026-09-16 12:28:36,454 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# ...
# 2026-09-16 12:37:55,941 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:56,081 - stpipe.step - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:37:56,086 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:56,265 - stpipe.step - INFO - Step clean_flicker_noise running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:37:56,266 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:56,401 - stpipe.step - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>, []).
# 2026-09-16 12:37:56,402 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:56,533 - stpipe.step - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rate.fits', []).
# 2026-09-16 12:37:56,534 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:56,656 - stpipe.step - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rate.fits']).
# 2026-09-16 12:37:57,043 - jwst.background.background_step - INFO - Working on input <IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits> ...
# 2026-09-16 12:37:57,058 - jwst.background.background_sub - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort_rate.fits
# 2026-09-16 12:37:57,169 - jwst.background.background_sub - INFO - Subtracting avg bkg from jw03722003001_04101_00004_mirifushort_rate.fits
# 2026-09-16 12:37:57,174 - stpipe.step - INFO - Step bkg_subtract done
# 2026-09-16 12:37:58,216 - stpipe.step - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:37:58,218 - jwst.srctype.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2026-09-16 12:37:58,219 - jwst.srctype.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2026-09-16 12:37:58,219 - jwst.srctype.srctype - INFO - Using input source type = EXTENDED
# 2026-09-16 12:37:58,221 - stpipe.step - INFO - Step srctype done
# 2026-09-16 12:37:58,360 - stpipe.step - INFO - Step targ_centroid running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:37:58,361 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:37:58,519 - stpipe.step - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:37:58,524 - jwst.straylight.straylight_step - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2026-09-16 12:37:58,621 - jwst.straylight.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# 2026-09-16 12:38:13,231 - jwst.straylight.straylight - INFO - Found parameters for right detector half, applying Cross-Artifact correction.
# 2026-09-16 12:38:27,596 - jwst.straylight.straylight - INFO - Derived pedestal correction -5.96326406794289e-05 DN/s
# 2026-09-16 12:38:27,597 - jwst.straylight.straylight - INFO - Cross-artifact model complete.
# 2026-09-16 12:38:27,609 - jwst.straylight.straylight - INFO - Applying correction for residual cosmic ray showers.
# 2026-09-16 12:38:27,798 - stpipe.step - INFO - Step straylight done
# 2026-09-16 12:38:27,934 - stpipe.step - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:27,977 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:38:27,981 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0822.fits
# 2026-09-16 12:38:27,982 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-09-16 12:38:27,982 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-09-16 12:38:27,983 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-09-16 12:38:28,018 - stpipe.step - INFO - Step flat_field done
# 2026-09-16 12:38:28,180 - stpipe.step - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:28,197 - jwst.fringe.fringe_step - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0073.fits
# 2026-09-16 12:38:28,242 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:38:28,243 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:38:28,244 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:38:28,262 - stpipe.step - INFO - Step fringe done
# 2026-09-16 12:38:28,441 - stpipe.step - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:28,442 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:28,610 - stpipe.step - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:28,611 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:28,732 - stpipe.step - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:28,740 - jwst.photom.photom_step - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0226.fits
# 2026-09-16 12:38:28,741 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-09-16 12:38:28,742 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-09-16 12:38:28,742 - jwst.photom.photom - INFO -  detector: MIRIFUSHORT
# 2026-09-16 12:38:28,743 - jwst.photom.photom - INFO -  exp_type: MIR_MRS
# 2026-09-16 12:38:28,743 - jwst.photom.photom - INFO -  band: MEDIUM
# 2026-09-16 12:38:28,784 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:38:28,791 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-09-16 12:38:28,791 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-09-16 12:38:28,802 - jwst.photom.photom - INFO - Applying MRS IFU time dependent correction.
# 2026-09-16 12:38:29,259 - stpipe.step - INFO - Step photom done
# 2026-09-16 12:38:29,382 - stpipe.step - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_rate.fits>,).
# 2026-09-16 12:38:29,386 - jwst.residual_fringe.residual_fringe_step - INFO - Using FRINGEFREQ reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0004.fits
# 2026-09-16 12:38:29,390 - jwst.residual_fringe.residual_fringe_step - INFO - Using MRS regions reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0141.asdf
# 2026-09-16 12:38:29,447 - jwst.residual_fringe.residual_fringe - INFO -  Using 8 throughput threshold.
# 2026-09-16 12:38:29,448 - jwst.residual_fringe.residual_fringe - INFO - Detector mirifushort [1, 2]
# 2026-09-16 12:38:29,936 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 1
# 2026-09-16 12:38:29,943 - jwst.residual_fringe.utils - INFO - Number of slices in channel 21
# 2026-09-16 12:38:30,068 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 101.0 =================================
# 2026-09-16 12:38:30,076 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 102.0 =================================
# 2026-09-16 12:38:30,085 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 103.0 =================================
# 2026-09-16 12:38:30,093 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 104.0 =================================
# 2026-09-16 12:38:30,101 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 105.0 =================================
# 2026-09-16 12:38:30,108 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 106.0 =================================
# 2026-09-16 12:38:30,116 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 107.0 =================================
# 2026-09-16 12:38:30,124 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 108.0 =================================
# 2026-09-16 12:38:30,131 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 109.0 =================================
# 2026-09-16 12:38:30,139 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 110.0 =================================
# 2026-09-16 12:38:30,147 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 111.0 =================================
# 2026-09-16 12:38:30,156 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 112.0 =================================
# 2026-09-16 12:38:30,165 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 113.0 =================================
# 2026-09-16 12:38:30,172 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 114.0 =================================
# 2026-09-16 12:38:30,181 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 115.0 =================================
# 2026-09-16 12:38:30,188 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 116.0 =================================
# 2026-09-16 12:38:30,196 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 117.0 =================================
# 2026-09-16 12:38:30,204 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 118.0 =================================
# 2026-09-16 12:38:30,212 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 119.0 =================================
# 2026-09-16 12:38:30,220 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 120.0 =================================
# 2026-09-16 12:38:30,229 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 121.0 =================================
# 2026-09-16 12:38:30,237 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:38:30,238 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 2
# 2026-09-16 12:38:30,243 - jwst.residual_fringe.utils - INFO - Number of slices in channel 17
# 2026-09-16 12:38:30,319 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 201.0 =================================
# 2026-09-16 12:38:30,328 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 202.0 =================================
# 2026-09-16 12:38:30,337 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 203.0 =================================
# 2026-09-16 12:38:30,346 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 204.0 =================================
# 2026-09-16 12:38:30,354 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 205.0 =================================
# 2026-09-16 12:38:30,363 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 206.0 =================================
# 2026-09-16 12:38:31,179 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 207.0 =================================
# 2026-09-16 12:38:31,188 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 208.0 =================================
# 2026-09-16 12:38:31,196 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 209.0 =================================
# 2026-09-16 12:38:31,205 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 210.0 =================================
# 2026-09-16 12:38:31,215 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 211.0 =================================
# 2026-09-16 12:38:31,225 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 212.0 =================================
# 2026-09-16 12:38:31,236 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 213.0 =================================
# 2026-09-16 12:38:31,246 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 214.0 =================================
# 2026-09-16 12:38:31,256 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 215.0 =================================
# 2026-09-16 12:38:31,268 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 216.0 =================================
# 2026-09-16 12:38:31,277 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 217.0 =================================
# 2026-09-16 12:38:31,287 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:38:31,288 - jwst.residual_fringe.residual_fringe - INFO - Processing complete
# 2026-09-16 12:38:31,295 - stpipe.step - INFO - Step residual_fringe done
# 2026-09-16 12:38:31,930 - stpipe.step - INFO - Step adaptive_trace_model running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_04101_00004_mirifushort_cal.fits>,).
# 2026-09-16 12:38:31,932 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:32,114 - stpipe.step - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_04101_00004_mirifushort_cal.fits>,).
# 2026-09-16 12:38:32,116 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:32,280 - stpipe.step - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_04101_00004_mirifushort_cal.fits>,).
# 2026-09-16 12:38:32,281 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:32,830 - stpipe.step - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs003/stage2/jw03722003001_04101_00004_mirifushort_cal.fits>,).
# 2026-09-16 12:38:32,833 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:32,838 - jwst.pipeline.calwebb_spec2 - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00004_mirifushort
# 2026-09-16 12:38:32,839 - jwst.pipeline.calwebb_spec2 - INFO - Ending calwebb_spec2
# 2026-09-16 12:38:32,840 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:38:33,189 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage2/jw03722003001_04101_00004_mirifushort_cal.fits
# 2026-09-16 12:38:33,189 - stpipe.step - INFO - Step Spec2Pipeline done
# 2026-09-16 12:38:33,190 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Reduce the backgrounds individually.  This will be needed for the Master Background step in calwebb_spec3, but is unnecessary if doing calwebb_spec2 pixel based background instead.
# </div>

# %%
if dospec2bg:
    for file in bgfiles:
        asnfile = os.path.join(bg_dir, 'l2asn.json')
        writel2asn(file, '', selfcalfiles, asnfile, 'Level2')
        Spec2Pipeline.call(asnfile, steps=spec2dict, save_results=True, output_dir=spec2_bgdir)
else:
    print('Skipping Spec2 processing for BG data')
# Out:
# /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-09-16 12:38:33,348 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:38:33,354 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:38:33,361 - CRDS - ERROR -  Error determining best reference for 'pars-targcentroidstep'  =   Unknown reference type 'pars-targcentroidstep'
# 2026-09-16 12:38:33,367 - stpipe.step - INFO - PARS-ADAPTIVETRACEMODELSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-adaptivetracemodelstep_0001.asdf
# 2026-09-16 12:38:33,375 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:38:33,382 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:38:33,392 - stpipe.pipeline - INFO - PARS-SPEC2PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec2pipeline_0005.asdf
# 2026-09-16 12:38:33,415 - stpipe.step - INFO - Spec2Pipeline instance created.
# 2026-09-16 12:38:33,416 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-16 12:38:33,417 - stpipe.step - INFO - BadpixSelfcalStep instance created.
# 2026-09-16 12:38:33,418 - stpipe.step - INFO - MSAFlagOpenStep instance created.
# 2026-09-16 12:38:33,419 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:38:33,419 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-09-16 12:38:33,420 - stpipe.step - INFO - ImprintStep instance created.
# 2026-09-16 12:38:33,421 - stpipe.step - INFO - Extract2dStep instance created.
# 2026-09-16 12:38:33,425 - stpipe.step - INFO - MasterBackgroundMosStep instance created.
# 2026-09-16 12:38:33,425 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-16 12:38:33,426 - stpipe.step - INFO - PathLossStep instance created.
# 2026-09-16 12:38:33,427 - stpipe.step - INFO - BarShadowStep instance created.
# 2026-09-16 12:38:33,428 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-16 12:38:33,429 - stpipe.step - INFO - PixelReplaceStep instance created.
# 2026-09-16 12:38:33,430 - stpipe.step - INFO - ResampleSpecStep instance created.
# 2026-09-16 12:38:33,431 - stpipe.step - INFO - Extract1dStep instance created.
# 2026-09-16 12:38:33,432 - stpipe.step - INFO - TargCentroidStep instance created.
# 2026-09-16 12:38:33,433 - stpipe.step - INFO - WavecorrStep instance created.
# 2026-09-16 12:38:33,433 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-16 12:38:33,434 - stpipe.step - INFO - SourceTypeStep instance created.
# 2026-09-16 12:38:33,435 - stpipe.step - INFO - StraylightStep instance created.
# 2026-09-16 12:38:33,436 - stpipe.step - INFO - FringeStep instance created.
# 2026-09-16 12:38:33,437 - stpipe.step - INFO - ResidualFringeStep instance created.
# 2026-09-16 12:38:33,438 - stpipe.step - INFO - PathLossStep instance created.
# 2026-09-16 12:38:33,439 - stpipe.step - INFO - BarShadowStep instance created.
# 2026-09-16 12:38:33,440 - stpipe.step - INFO - WfssContamStep instance created.
# 2026-09-16 12:38:33,441 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-16 12:38:33,442 - stpipe.step - INFO - AdaptiveTraceModelStep instance created.
# 2026-09-16 12:38:33,443 - stpipe.step - INFO - PixelReplaceStep instance created.
# 2026-09-16 12:38:33,445 - stpipe.step - INFO - ResampleSpecStep instance created.
# 2026-09-16 12:38:33,446 - stpipe.step - INFO - CubeBuildStep instance created.
# 2026-09-16 12:38:33,448 - stpipe.step - INFO - Extract1dStep instance created.
# 2026-09-16 12:38:33,976 - stpipe.step - INFO - Step Spec2Pipeline running with args ('./mrs_data/Obs007/l2asn.json',).
# 2026-09-16 12:38:33,999 - stpipe.step - INFO - Step Spec2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs007/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   fail_on_exception: True
#   save_wfss_esec: False
#   steps:
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     badpix_selfcal:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       flagfrac_lower: 0.001
#       flagfrac_upper: 0.001
#       kernel_size: 15
#       force_single: False
#       save_flagged_bkg: False
#     msa_flagging:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       autoparam: False
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 3.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_mask: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     imprint_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     extract_2d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       slit_names: None
#       source_ids: None
#       source_ra: None
#       source_dec: None
#       source_max_sep: 2.0
#       extract_orders: None
#       grism_objects: None
#       tsgrism_extract_height: None
#       wfss_extract_half_height: 5
#       wfss_mmag_extract: None
#       wfss_nbright: 1000
#     master_background_mos:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sigma_clip: 3.0
#       median_kernel: 1
#       force_subtract: False
#       save_background: False
#       user_background: None
#       inverse: False
#       steps:
#         flat_field:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           save_interpolated_flat: False
#           user_supplied_flat: None
#           inverse: False
#         pathloss:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           user_slit_loc: None
#         barshadow:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#         photom:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           apply_time_correction: True
#         pixel_replace:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: True
#           output_use_index: True
#           save_results: False
#           skip: True
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           algorithm: fit_profile
#           n_adjacent_cols: 3
#         resample_spec:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           pixfrac: 1.0
#           kernel: square
#           fillval: NAN
#           weight_type: exptime
#           output_shape: None
#           pixel_scale_ratio: 1.0
#           pixel_scale: None
#           output_wcs: ''
#           single: False
#           blendheaders: True
#           in_memory: True
#           propagate_dq: False
#         extract_1d:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           subtract_background: None
#           apply_apcorr: True
#           extraction_type: box
#           use_source_posn: None
#           position_offset: 0.0
#           model_nod_pair: True
#           optimize_psf_location: True
#           smoothing_length: None
#           bkg_fit: None
#           bkg_order: None
#           log_increment: 50
#           save_profile: False
#           save_scene_model: False
#           save_residual_image: False
#           center_xy: None
#           ifu_autocen: True
#           bkg_sigma_clip: 3.0
#           ifu_rfcorr: True
#           ifu_set_srctype: None
#           ifu_rscale: None
#           ifu_covar_scale: 1.8
#           soss_atoca: True
#           soss_threshold: 0.01
#           soss_n_os: 2
#           soss_wave_grid_in: None
#           soss_wave_grid_out: None
#           soss_estimate: None
#           soss_rtol: 0.0001
#           soss_max_grid_size: 20000
#           soss_tikfac: None
#           soss_width: 40.0
#           soss_bad_pix: masking
#           soss_modelname: None
#           soss_order_3: True
#     targ_centroid:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       ta_file: None
#     wavecorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     srctype:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       source_type: None
#     straylight:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       clean_showers: True
#       shower_plane: 3
#       shower_x_stddev: 18.0
#       shower_y_stddev: 5.0
#       shower_low_reject: 0.1
#       shower_high_reject: 99.9
#       save_shower_model: False
#     fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     residual_fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: residual_fringe
#       search_output_file: False
#       input_dir: ''
#       save_intermediate_results: False
#       ignore_region_min: None
#       ignore_region_max: None
#     pathloss:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       user_slit_loc: None
#     barshadow:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#     wfss_contam:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_simulated_image: False
#       save_contam_images: False
#       maximum_cores: '1'
#       orders: None
#       magnitude_limit: None
#       wl_oversample: 2
#       max_pixels_per_chunk: 5000
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     adaptive_trace_model:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_threshold: 10.0
#       oversample: 3
#       slope_limit: 0.1
#       psf_optimal: False
#       save_intermediate_results: False
#     pixel_replace:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: fit_profile
#       n_adjacent_cols: 3
#     resample_spec:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       propagate_dq: False
#     cube_build:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: s3d
#       search_output_file: False
#       input_dir: ''
#       pipeline: 3
#       channel: all
#       band: all
#       grating: all
#       filter: all
#       output_type: None
#       linear_wave: True
#       scalexy: 0.0
#       scalew: 0.0
#       weighting: drizzle
#       coord_system: skyalign
#       ra_center: None
#       dec_center: None
#       cube_pa: None
#       nspax_x: None
#       nspax_y: None
#       rois: 0.0
#       roiw: 0.0
#       weight_power: 2.0
#       wavemin: None
#       wavemax: None
#       single: False
#       skip_dqflagging: False
#       offset_file: None
#       debug_spaxel: -1 -1 -1
#     extract_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       subtract_background: None
#       apply_apcorr: True
#       extraction_type: box
#       use_source_posn: None
#       position_offset: 0.0
#       model_nod_pair: True
#       optimize_psf_location: True
#       smoothing_length: None
#       bkg_fit: None
#       bkg_order: None
#       log_increment: 50
#       save_profile: False
#       save_scene_model: False
#       save_residual_image: False
#       center_xy: None
#       ifu_autocen: True
#       bkg_sigma_clip: 3.0
#       ifu_rfcorr: True
#       ifu_set_srctype: None
#       ifu_rscale: None
#       ifu_covar_scale: 1.8
#       soss_atoca: True
#       soss_threshold: 0.01
#       soss_n_os: 2
#       soss_wave_grid_in: None
#       soss_wave_grid_out: None
#       soss_estimate: None
#       soss_rtol: 0.0001
#       soss_max_grid_size: 20000
#       soss_tikfac: None
#       soss_width: 40.0
#       soss_bad_pix: masking
#       soss_modelname: None
#       soss_order_3: True
# 2026-09-16 12:38:34,039 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'l2asn.json' reftypes = ['apcorr', 'area', 'barshadow', 'bkg', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'fringefreq', 'ifufore', 'ifupost', 'ifuslicer', 'mrsxartcorr', 'msa', 'msaoper', 'ote', 'pastasoss', 'pathloss', 'photom', 'psf', 'regions', 'sflat', 'speckernel', 'specprofile', 'specwcs', 'wavecorr', 'wavelengthrange']
# 2026-09-16 12:38:34,044 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf'.
# 2026-09-16 12:38:34,044 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-09-16 12:38:34,045 - stpipe.pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2026-09-16 12:38:34,045 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-09-16 12:38:34,045 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-09-16 12:38:34,046 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-09-16 12:38:34,047 - stpipe.pipeline - INFO - Prefetch for CUBEPAR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits'.
# 2026-09-16 12:38:34,047 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-09-16 12:38:34,048 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-09-16 12:38:34,048 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0145.asdf'.
# 2026-09-16 12:38:34,048 - stpipe.pipeline - INFO - Prefetch for EXTRACT1D reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf'.
# 2026-09-16 12:38:34,049 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-09-16 12:38:34,050 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2026-09-16 12:38:34,050 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0824.fits'.
# 2026-09-16 12:38:34,050 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-09-16 12:38:34,051 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-09-16 12:38:34,051 - stpipe.pipeline - INFO - Prefetch for FRINGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0074.fits'.
# 2026-09-16 12:38:34,052 - stpipe.pipeline - INFO - Prefetch for FRINGEFREQ reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0003.fits'.
# 2026-09-16 12:38:34,053 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-09-16 12:38:34,053 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-09-16 12:38:34,054 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-09-16 12:38:34,054 - stpipe.pipeline - INFO - Prefetch for MRSXARTCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits'.
# 2026-09-16 12:38:34,055 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-09-16 12:38:34,055 - stpipe.pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2026-09-16 12:38:34,056 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-09-16 12:38:34,056 - stpipe.pipeline - INFO - Prefetch for PASTASOSS reference file is 'N/A'.
# 2026-09-16 12:38:34,057 - stpipe.pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2026-09-16 12:38:34,057 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0225.fits'.
# 2026-09-16 12:38:34,058 - stpipe.pipeline - INFO - Prefetch for PSF reference file is 'N/A'.
# 2026-09-16 12:38:34,058 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf'.
# 2026-09-16 12:38:34,059 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-09-16 12:38:34,059 - stpipe.pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2026-09-16 12:38:34,060 - stpipe.pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2026-09-16 12:38:34,060 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0144.asdf'.
# 2026-09-16 12:38:34,061 - stpipe.pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2026-09-16 12:38:34,061 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0011.asdf'.
# 2026-09-16 12:38:34,062 - jwst.pipeline.calwebb_spec2 - INFO - Starting calwebb_spec2 ...
# 2026-09-16 12:38:34,067 - jwst.pipeline.calwebb_spec2 - INFO - Processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong
# 2026-09-16 12:38:34,068 - jwst.pipeline.calwebb_spec2 - INFO - Working on input /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits ...
# 2026-09-16 12:38:34,217 - stpipe.step - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:34,520 - jwst.assign_wcs.miri - INFO - Applied Barycentric velocity correction : 0.9999201090428957
# 2026-09-16 12:38:35,339 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0145.asdf', 'filteroffset': None, 'specwcs': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0144.asdf', 'regions': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf', 'wavelengthrange': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0011.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-09-16 12:38:35,897 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809871304 42.472888490 171.813637145 42.472888490 171.813637145 42.475734486 171.809871304 42.475734486
# 2026-09-16 12:38:35,899 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-09-16 12:38:35,902 - stpipe.step - INFO - Step assign_wcs done
# 2026-09-16 12:38:36,028 - stpipe.step - INFO - Step badpix_selfcal running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00002_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00003_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_02101_00004_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00002_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00003_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs003/stage1/jw03722003001_04101_00004_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifulong_rate.fits'], []).
# 2026-09-16 12:38:36,030 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,152 - stpipe.step - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:36,153 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,292 - stpipe.step - INFO - Step clean_flicker_noise running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:36,294 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,434 - stpipe.step - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>, []).
# 2026-09-16 12:38:36,435 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,565 - stpipe.step - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>, []).
# 2026-09-16 12:38:36,566 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,686 - stpipe.step - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:36,688 - jwst.srctype.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2026-09-16 12:38:36,690 - jwst.srctype.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2026-09-16 12:38:36,692 - jwst.srctype.srctype - INFO - Using input source type = EXTENDED
# 2026-09-16 12:38:36,700 - stpipe.step - INFO - Step srctype done
# 2026-09-16 12:38:36,829 - stpipe.step - INFO - Step targ_centroid running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:36,831 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:38:36,998 - stpipe.step - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:38:37,007 - jwst.straylight.straylight_step - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2026-09-16 12:38:37,076 - jwst.straylight.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# 2026-09-16 12:38:51,561 - jwst.straylight.straylight - INFO - Found parameters for right detector half, applying Cross-Artifact correction.
# 2026-09-16 12:39:06,813 - jwst.straylight.straylight - INFO - Derived pedestal correction -0.07214322686195374 DN/s
# 2026-09-16 12:39:06,814 - jwst.straylight.straylight - INFO - Cross-artifact model complete.
# 2026-09-16 12:39:06,827 - jwst.straylight.straylight - INFO - Applying correction for residual cosmic ray showers.
# 2026-09-16 12:39:07,016 - stpipe.step - INFO - Step straylight done
# 2026-09-16 12:39:07,139 - stpipe.step - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:07,176 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:39:07,179 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0824.fits
# 2026-09-16 12:39:07,180 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-09-16 12:39:07,180 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-09-16 12:39:07,181 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-09-16 12:39:07,213 - stpipe.step - INFO - Step flat_field done
# 2026-09-16 12:39:07,336 - stpipe.step - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:07,339 - jwst.fringe.fringe_step - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0074.fits
# 2026-09-16 12:39:07,368 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:39:07,369 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:39:07,370 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:39:07,388 - stpipe.step - INFO - Step fringe done
# 2026-09-16 12:39:07,518 - stpipe.step - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:07,520 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:39:07,747 - stpipe.step - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:07,749 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:39:07,872 - stpipe.step - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:07,879 - jwst.photom.photom_step - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0225.fits
# 2026-09-16 12:39:07,880 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-09-16 12:39:07,881 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-09-16 12:39:07,881 - jwst.photom.photom - INFO -  detector: MIRIFULONG
# 2026-09-16 12:39:07,882 - jwst.photom.photom - INFO -  exp_type: MIR_MRS
# 2026-09-16 12:39:07,886 - jwst.photom.photom - INFO -  band: LONG
# 2026-09-16 12:39:07,947 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:39:07,951 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-09-16 12:39:07,952 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-09-16 12:39:07,961 - jwst.photom.photom - INFO - Applying MRS IFU time dependent correction.
# 2026-09-16 12:39:08,382 - stpipe.step - INFO - Step photom done
# 2026-09-16 12:39:08,489 - stpipe.step - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722007001_02101_00001_mirifulong_rate.fits>,).
# 2026-09-16 12:39:08,495 - jwst.residual_fringe.residual_fringe_step - INFO - Using FRINGEFREQ reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0003.fits
# 2026-09-16 12:39:08,498 - jwst.residual_fringe.residual_fringe_step - INFO - Using MRS regions reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0143.asdf
# 2026-09-16 12:39:08,546 - jwst.residual_fringe.residual_fringe - INFO -  Using 8 throughput threshold.
# 2026-09-16 12:39:08,547 - jwst.residual_fringe.residual_fringe - INFO - Detector mirifulong [3, 4]
# 2026-09-16 12:39:08,954 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 3
# 2026-09-16 12:39:08,959 - jwst.residual_fringe.utils - INFO - Number of slices in channel 16
# 2026-09-16 12:39:09,043 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 301.0 =================================
# 2026-09-16 12:39:11,824 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 302.0 =================================
# 2026-09-16 12:39:14,633 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 303.0 =================================
# 2026-09-16 12:39:17,608 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 304.0 =================================
# 2026-09-16 12:39:20,625 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 305.0 =================================
# 2026-09-16 12:39:23,707 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 306.0 =================================
# 2026-09-16 12:39:26,865 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 307.0 =================================
# 2026-09-16 12:39:30,139 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 308.0 =================================
# 2026-09-16 12:39:33,531 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 309.0 =================================
# 2026-09-16 12:39:36,463 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 310.0 =================================
# 2026-09-16 12:39:40,390 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 311.0 =================================
# 2026-09-16 12:39:43,515 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 312.0 =================================
# 2026-09-16 12:39:46,582 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 313.0 =================================
# 2026-09-16 12:39:49,597 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 314.0 =================================
# 2026-09-16 12:39:52,917 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 315.0 =================================
# 2026-09-16 12:39:56,106 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 316.0 =================================
# 2026-09-16 12:39:59,402 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 513
# 2026-09-16 12:39:59,403 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 4
# 2026-09-16 12:39:59,407 - jwst.residual_fringe.utils - INFO - Number of slices in channel 12
# 2026-09-16 12:39:59,460 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 401.0 =================================
# 2026-09-16 12:40:02,068 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 402.0 =================================
# 2026-09-16 12:40:04,833 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 403.0 =================================
# 2026-09-16 12:40:07,660 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 404.0 =================================
# 2026-09-16 12:40:10,487 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 405.0 =================================
# 2026-09-16 12:40:13,446 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 406.0 =================================
# 2026-09-16 12:40:16,303 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 407.0 =================================
# 2026-09-16 12:40:19,259 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 408.0 =================================
# 2026-09-16 12:40:22,241 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 409.0 =================================
# 2026-09-16 12:40:26,420 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 410.0 =================================
# 2026-09-16 12:40:29,646 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 411.0 =================================
# 2026-09-16 12:40:33,123 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 412.0 =================================
# 2026-09-16 12:40:36,173 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 335
# 2026-09-16 12:40:36,174 - jwst.residual_fringe.residual_fringe - INFO - Processing complete
# 2026-09-16 12:40:36,181 - stpipe.step - INFO - Step residual_fringe done
# 2026-09-16 12:40:36,594 - stpipe.step - INFO - Step adaptive_trace_model running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:40:36,596 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:40:36,762 - stpipe.step - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:40:36,764 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:40:36,944 - stpipe.step - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_cal.fits>,).
# 2026-09-16 12:40:36,947 - jwst.cube_build.cube_build_step - INFO - Starting IFU Cube Building Step
# 2026-09-16 12:40:36,950 - jwst.cube_build.cube_build_step - INFO - Input interpolation: drizzle
# 2026-09-16 12:40:36,955 - jwst.cube_build.cube_build_step - INFO - Coordinate system to use: skyalign
# 2026-09-16 12:40:36,965 - jwst.cube_build.cube_build_step - INFO - Setting output type to: multi
# 2026-09-16 12:40:37,032 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI Channels: ['3', '4']
# 2026-09-16 12:40:37,033 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['long', 'long']
# 2026-09-16 12:40:37,034 - jwst.cube_build.cube_build - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2026-09-16 12:40:37,222 - jwst.cube_build.cube_build - INFO - Output IFUcube are constructed from all the data
# 2026-09-16 12:40:37,223 - jwst.cube_build.cube_build_step - INFO - Number of IFU cubes produced by this run = 1
# 2026-09-16 12:40:37,225 - jwst.cube_build.ifu_cube - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2026-09-16 12:40:37,228 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:40:37,228 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:40:37,229 - jwst.cube_build.ifu_cube - INFO - Axis 1    53  27.00 171.81175422   0.20000000  -5.30000008   5.30000008
# 2026-09-16 12:40:37,230 - jwst.cube_build.ifu_cube - INFO - Axis 2    55  28.00  42.47431149   0.20000000  -5.50000008   5.50000008
# 2026-09-16 12:40:37,230 - jwst.cube_build.ifu_cube - INFO - Non-linear wavelength dimension; CDELT3 variable
# 2026-09-16 12:40:37,231 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL     Min & Max (microns)
# 2026-09-16 12:40:37,231 - jwst.cube_build.ifu_cube - INFO - Axis 3  2486   1.00  15.40774059  15.40774059  28.69605064
# 2026-09-16 12:40:37,232 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 3, long
# 2026-09-16 12:40:37,232 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 4, long
# 2026-09-16 12:40:37,233 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['long']
# 2026-09-16 12:40:37,233 - jwst.cube_build.ifu_cube - INFO - Output Name: ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_s3d.fits
# 2026-09-16 12:40:38,012 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 822 with wavelength below 15.404848098754883
# 2026-09-16 12:40:45,289 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:40:45,290 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:40:45,298 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:40:45,540 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809795822 42.472811471 171.809795822 42.475811471 171.813712627 42.475811471 171.813712627 42.472811471
# 2026-09-16 12:40:45,543 - stpipe.step - INFO - Step cube_build done
# 2026-09-16 12:40:45,656 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_s3d.fits
# 2026-09-16 12:40:45,816 - stpipe.step - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8ae3885df0>,).
# 2026-09-16 12:40:45,827 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:40:45,830 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf
# 2026-09-16 12:40:45,832 - jwst.extract_1d.extract_1d_step - INFO - Turning off residual fringe correction for MIRI MRS data because the input is not a single IFU band
# 2026-09-16 12:40:45,833 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:40:46,091 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:40:57,392 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:40:57,484 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_x1d.fits
# 2026-09-16 12:40:57,485 - stpipe.step - INFO - Step extract_1d done
# 2026-09-16 12:40:57,486 - jwst.pipeline.calwebb_spec2 - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02101_00001_mirifulong
# 2026-09-16 12:40:57,488 - jwst.pipeline.calwebb_spec2 - INFO - Ending calwebb_spec2
# 2026-09-16 12:40:57,488 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:40:57,780 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02101_00001_mirifulong_cal.fits
# 2026-09-16 12:40:57,781 - stpipe.step - INFO - Step Spec2Pipeline done
# 2026-09-16 12:40:57,781 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1
# /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-09-16 12:40:57,941 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:40:57,948 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:40:57,954 - CRDS - ERROR -  Error determining best reference for 'pars-targcentroidstep'  =   Unknown reference type 'pars-targcentroidstep'
# 2026-09-16 12:40:57,960 - stpipe.step - INFO - PARS-ADAPTIVETRACEMODELSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-adaptivetracemodelstep_0001.asdf
# 2026-09-16 12:40:57,966 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:40:57,973 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:40:57,979 - stpipe.pipeline - INFO - PARS-SPEC2PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec2pipeline_0005.asdf
# 2026-09-16 12:40:57,996 - stpipe.step - INFO - Spec2Pipeline instance created.
# 2026-09-16 12:40:57,997 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-16 12:40:57,998 - stpipe.step - INFO - BadpixSelfcalStep instance created.
# 2026-09-16 12:40:57,998 - stpipe.step - INFO - MSAFlagOpenStep instance created.
# 2026-09-16 12:40:57,999 - stpipe.step - INFO - CleanFlickerNoiseStep instance created.
# 2026-09-16 12:40:58,001 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-09-16 12:40:58,001 - stpipe.step - INFO - ImprintStep instance created.
# 2026-09-16 12:40:58,002 - stpipe.step - INFO - Extract2dStep instance created.
# 2026-09-16 12:40:58,005 - stpipe.step - INFO - MasterBackgroundMosStep instance created.
# 2026-09-16 12:40:58,006 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-16 12:40:58,006 - stpipe.step - INFO - PathLossStep instance created.
# 2026-09-16 12:40:58,007 - stpipe.step - INFO - BarShadowStep instance created.
# ...
# 2026-09-16 12:44:10,924 - stpipe.step - INFO - Step straylight done
# 2026-09-16 12:44:11,055 - stpipe.step - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:11,102 - stdatamodels.dynamicdq - WARNING - Keyword UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:44:11,106 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0822.fits
# 2026-09-16 12:44:11,107 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-09-16 12:44:11,108 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-09-16 12:44:11,109 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-09-16 12:44:11,177 - stpipe.step - INFO - Step flat_field done
# 2026-09-16 12:44:11,342 - stpipe.step - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:11,347 - jwst.fringe.fringe_step - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0073.fits
# 2026-09-16 12:44:11,374 - stdatamodels.dynamicdq - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:44:11,375 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:44:11,376 - stdatamodels.dynamicdq - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:44:11,391 - stpipe.step - INFO - Step fringe done
# 2026-09-16 12:44:11,530 - stpipe.step - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:11,531 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:44:11,764 - stpipe.step - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:11,765 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:44:11,957 - stpipe.step - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:11,967 - jwst.photom.photom_step - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0226.fits
# 2026-09-16 12:44:11,968 - jwst.photom.photom_step - INFO - Using area reference file: N/A
# 2026-09-16 12:44:11,969 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-09-16 12:44:11,971 - jwst.photom.photom - INFO -  detector: MIRIFUSHORT
# 2026-09-16 12:44:11,973 - jwst.photom.photom - INFO -  exp_type: MIR_MRS
# 2026-09-16 12:44:11,974 - jwst.photom.photom - INFO -  band: MEDIUM
# 2026-09-16 12:44:12,044 - stdatamodels.dynamicdq - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2026-09-16 12:44:12,049 - jwst.photom.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2026-09-16 12:44:12,049 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2026-09-16 12:44:12,058 - jwst.photom.photom - INFO - Applying MRS IFU time dependent correction.
# 2026-09-16 12:44:12,499 - stpipe.step - INFO - Step photom done
# 2026-09-16 12:44:12,637 - stpipe.step - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722007001_02102_00001_mirifushort_rate.fits>,).
# 2026-09-16 12:44:12,642 - jwst.residual_fringe.residual_fringe_step - INFO - Using FRINGEFREQ reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringefreq_0004.fits
# 2026-09-16 12:44:12,645 - jwst.residual_fringe.residual_fringe_step - INFO - Using MRS regions reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0141.asdf
# 2026-09-16 12:44:12,694 - jwst.residual_fringe.residual_fringe - INFO -  Using 8 throughput threshold.
# 2026-09-16 12:44:12,695 - jwst.residual_fringe.residual_fringe - INFO - Detector mirifushort [1, 2]
# 2026-09-16 12:44:13,127 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 1
# 2026-09-16 12:44:13,149 - jwst.residual_fringe.utils - INFO - Number of slices in channel 21
# 2026-09-16 12:44:13,273 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 101.0 =================================
# 2026-09-16 12:44:13,280 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 102.0 =================================
# 2026-09-16 12:44:13,288 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 103.0 =================================
# 2026-09-16 12:44:13,296 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 104.0 =================================
# 2026-09-16 12:44:13,303 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 105.0 =================================
# 2026-09-16 12:44:13,311 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 106.0 =================================
# 2026-09-16 12:44:13,320 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 107.0 =================================
# 2026-09-16 12:44:13,328 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 108.0 =================================
# 2026-09-16 12:44:13,336 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 109.0 =================================
# 2026-09-16 12:44:13,345 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 110.0 =================================
# 2026-09-16 12:44:13,356 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 111.0 =================================
# 2026-09-16 12:44:13,367 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 112.0 =================================
# 2026-09-16 12:44:13,377 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 113.0 =================================
# 2026-09-16 12:44:13,385 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 114.0 =================================
# 2026-09-16 12:44:13,393 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 115.0 =================================
# 2026-09-16 12:44:13,401 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 116.0 =================================
# 2026-09-16 12:44:13,410 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 117.0 =================================
# 2026-09-16 12:44:13,418 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 118.0 =================================
# 2026-09-16 12:44:13,427 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 119.0 =================================
# 2026-09-16 12:44:13,435 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 120.0 =================================
# 2026-09-16 12:44:13,443 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 121.0 =================================
# 2026-09-16 12:44:13,452 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:44:13,453 - jwst.residual_fringe.residual_fringe - INFO - Processing channel 2
# 2026-09-16 12:44:13,458 - jwst.residual_fringe.utils - INFO - Number of slices in channel 17
# 2026-09-16 12:44:13,535 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 201.0 =================================
# 2026-09-16 12:44:13,546 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 202.0 =================================
# 2026-09-16 12:44:13,557 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 203.0 =================================
# 2026-09-16 12:44:13,567 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 204.0 =================================
# 2026-09-16 12:44:13,576 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 205.0 =================================
# 2026-09-16 12:44:13,585 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 206.0 =================================
# 2026-09-16 12:44:13,594 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 207.0 =================================
# 2026-09-16 12:44:13,602 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 208.0 =================================
# 2026-09-16 12:44:13,612 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 209.0 =================================
# 2026-09-16 12:44:13,620 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 210.0 =================================
# 2026-09-16 12:44:13,629 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 211.0 =================================
# 2026-09-16 12:44:13,640 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 212.0 =================================
# 2026-09-16 12:44:13,652 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 213.0 =================================
# 2026-09-16 12:44:13,667 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 214.0 =================================
# 2026-09-16 12:44:13,683 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 215.0 =================================
# 2026-09-16 12:44:13,697 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 216.0 =================================
# 2026-09-16 12:44:13,716 - jwst.residual_fringe.residual_fringe - INFO -  Processing slice 217.0 =================================
# 2026-09-16 12:44:13,736 - jwst.residual_fringe.residual_fringe - INFO - Number of columns corrected for channel 0
# 2026-09-16 12:44:13,738 - jwst.residual_fringe.residual_fringe - INFO - Processing complete
# 2026-09-16 12:44:13,749 - stpipe.step - INFO - Step residual_fringe done
# 2026-09-16 12:44:14,291 - stpipe.step - INFO - Step adaptive_trace_model running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_cal.fits>,).
# 2026-09-16 12:44:14,294 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:44:14,526 - stpipe.step - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_cal.fits>,).
# 2026-09-16 12:44:14,527 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:44:14,791 - stpipe.step - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_cal.fits>,).
# 2026-09-16 12:44:14,792 - jwst.cube_build.cube_build_step - INFO - Starting IFU Cube Building Step
# 2026-09-16 12:44:14,794 - jwst.cube_build.cube_build_step - INFO - Input interpolation: drizzle
# 2026-09-16 12:44:14,795 - jwst.cube_build.cube_build_step - INFO - Coordinate system to use: skyalign
# 2026-09-16 12:44:14,795 - jwst.cube_build.cube_build_step - INFO - Setting output type to: multi
# 2026-09-16 12:44:14,817 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI Channels: ['1', '2']
# 2026-09-16 12:44:14,818 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['medium', 'medium']
# 2026-09-16 12:44:14,820 - jwst.cube_build.cube_build - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2026-09-16 12:44:15,018 - jwst.cube_build.cube_build - INFO - Output IFUcube are constructed from all the data
# 2026-09-16 12:44:15,019 - jwst.cube_build.cube_build_step - INFO - Number of IFU cubes produced by this run = 1
# 2026-09-16 12:44:15,021 - jwst.cube_build.ifu_cube - INFO - Increasing spatial region of interest default value set for 4 dithers nan
# 2026-09-16 12:44:15,023 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:44:15,024 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:44:15,024 - jwst.cube_build.ifu_cube - INFO - Axis 1    51  26.00 171.81189418   0.13000000  -3.31499988   3.31499988
# 2026-09-16 12:44:15,025 - jwst.cube_build.ifu_cube - INFO - Axis 2    51  26.00  42.47443412   0.13000000  -3.31499988   3.31499988
# 2026-09-16 12:44:15,025 - jwst.cube_build.ifu_cube - INFO - Non-linear wavelength dimension; CDELT3 variable
# 2026-09-16 12:44:15,026 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL     Min & Max (microns)
# 2026-09-16 12:44:15,027 - jwst.cube_build.ifu_cube - INFO - Axis 3  4243   1.00   5.65960693   5.65960693  10.13073730
# 2026-09-16 12:44:15,028 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 1, medium
# 2026-09-16 12:44:15,028 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 2, medium
# 2026-09-16 12:44:15,029 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['medium']
# 2026-09-16 12:44:15,029 - jwst.cube_build.ifu_cube - INFO - Output Name: ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_s3d.fits
# 2026-09-16 12:44:16,466 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength below 5.658884048461914
# 2026-09-16 12:44:21,178 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 2239 with wavelength above 10.13226318359375
# 2026-09-16 12:44:25,737 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:44:25,738 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:44:25,754 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 1
# 2026-09-16 12:44:26,245 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.810670184 42.473531339 171.810670184 42.475336894 171.813118169 42.475336894 171.813118169 42.473531339
# 2026-09-16 12:44:26,249 - stpipe.step - INFO - Step cube_build done
# 2026-09-16 12:44:26,417 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_s3d.fits
# 2026-09-16 12:44:26,617 - stpipe.step - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8ae391bf20>,).
# 2026-09-16 12:44:26,621 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:44:26,624 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf
# 2026-09-16 12:44:26,626 - jwst.extract_1d.extract_1d_step - INFO - Turning off residual fringe correction for MIRI MRS data because the input is not a single IFU band
# 2026-09-16 12:44:26,627 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:44:26,895 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:44:46,958 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:44:47,047 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_x1d.fits
# 2026-09-16 12:44:47,047 - stpipe.step - INFO - Step extract_1d done
# 2026-09-16 12:44:47,049 - jwst.pipeline.calwebb_spec2 - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/mrs_data/Obs007/stage1/jw03722007001_02102_00001_mirifushort
# 2026-09-16 12:44:47,052 - jwst.pipeline.calwebb_spec2 - INFO - Ending calwebb_spec2
# 2026-09-16 12:44:47,052 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1535.pmap
# 2026-09-16 12:44:47,440 - stpipe.step - INFO - Saved model in ./mrs_data/Obs007/stage2/jw03722007001_02102_00001_mirifushort_cal.fits
# 2026-09-16 12:44:47,441 - stpipe.step - INFO - Step Spec2Pipeline done
# 2026-09-16 12:44:47,442 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec2: {time1 - time_spec2} seconds")
# Out:
# Runtime so far: 1622.0206 seconds
# Runtime for Spec2: 988.3493636719995 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 7.<font color='white'>-</font>Spec3 Pipeline<a class="anchor" id="spec3"></a>
# ------------------
# In this section we'll run the Spec3 (calwebb_spec3) pipeline to produce a
# composite data cube and extracted spectrumfrom all dithered exposures.
# We will need to create an association file from all science (*cal.fits)
# and background (*x1d.fits) data in order for the pipeline to use them
# appropriately.<br>
#
# Note that the data cubes created by the JWST pipeline are in SURFACE
# BRIGHTNESS units (MJy/steradian), not flux units. ***What that means is
# that if you intend to sum spectra within an aperture you need to be sure
# to multiply by the pixel area in steradians first in order to get a
# spectrum in flux units.*** This correction is already build into the pipeline
# Extract1D algorithm.
# The nominal pixel area in steradians is provided in the
# <code>PIXAR_SR</code> keyword and can be found in the SCI
# extension header.<BR>
#
# Spectral extraction for point sources uses a conical aperture extraction whose radius increases with wavelength, with annular background subtraction and aperture correction.  Spectral extraction for extended sources sums the entire image at each wavelength plane (note this is different for each channel). <BR>
#
# See https://jwst-docs.stsci.edu/jwst-science-calibration-pipeline/stages-of-jwst-data-processing/calwebb_spec3
#
# <div class="alert alert-block alert-warning">
# If master background subtraction was selected above this will be applied
# during this stage.<BR><BR>
# To override certain steps and reference files use the examples below.
# </div>

# %%
time_spec3 = time.perf_counter()

# %%
# Set up a dictionary to define how the Spec3 pipeline should be configured

# Boilerplate dictionary setup
spec3dict = defaultdict(dict)

# old setup:
#spec3dict = {}
#spec3dict['assign_mtwcs'], spec3dict['master_background'], spec3dict['outlier_detection'], spec3dict['mrs_imatch'], spec3dict['cube_build'] = {}, {}, {}, {}, {}
#spec3dict['pixel_replace'], spec3dict['extract_1d'], spec3dict['spectral_leak'] = {}, {}, {}



# Overrides for whether or not certain steps should be skipped (example)
#spec3dict['outlier_detection']['skip'] = True

# Master background usage was set up above, propagate that here
if (master_bg is True):
    spec3dict['master_background']['skip'] = False
else:
    spec3dict['master_background']['skip'] = True

# Overrides for various reference files
# Files should be in the base local directory or provide full path
#spec3dict['cube_build']['override_cubepar'] = 'myfile.fits'  # Cube-building parameters
#spec3dict['extract_1d']['override_extract1d'] = 'myfile.asdf'  # Spectral extraction parameters (ASDF file)
#spec3dict['extract_1d']['override_apcorr'] = 'myfile.asdf'  # Aperture correction parameters (ASDF file)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Set certain parameters here to:
#
# * adjusting performance for the outlier detection step
# * adjust the cube building step
# * adjust the 1d spectral extraction
# </div>

# %%
# Options for adjusting performance for the outlier detection step
#spec3dict['outlier_detection']['kernel_size'] = '11 1'  # Dial this to adjust the detector kernel size
#spec3dict['outlier_detection']['threshold_percent'] = 99.5  # Dial this to be more/less aggressive in outlier flagging (values closer to 100% are less aggressive)

# Run adaptive trace model code if desired to mitigate resampling noise
#spec3dict['adaptive_trace_model']['skip'] = False

# Run pixel replacement code to extrapolate values for otherwise bad pixels
# This can help mitigate 5-10% negative dips in spectra of bright sources
# Use the 'mingrad' algorithm
spec3dict['pixel_replace']['skip'] = False
spec3dict['pixel_replace']['algorithm'] = 'mingrad'
#spec3dict['pixel_replace']['save_results'] = True # Enable if desired to write out these files for spot checking

# Options for adjusting the cube building step
#spec3dict['cube_build']['output_file'] = 'mycube'  # Custom output name
spec3dict['cube_build']['output_type'] = 'band'  # 'band', 'channel' (default), or 'multi' type cube output.  'band' is best for 1d residual fringe correction.
#spec3dict['cube_build']['channel'] = '1'  # Build everything from just channel 1 into a single cube (we could also choose '2','3','4', or 'ALL')
#spec3dict['cube_build']['weighting'] = 'drizzle'  # Algorithm used: 'emsm' or 'drizzle' (default)
#spec3dict['cube_build']['coord_system'] = 'ifualign'  # Cube rotation: 'ifualign', 'skyalign' (default), or 'internal_cal'
#spec3dict['cube_build']['scalexy'] = 0.5  # Output cube spaxel scale (arcsec) if setting it by hand
#spec3dict['cube_build']['scalew'] = 0.002  # Output cube voxel depth in wavelength (micron) if setting it by hand
#spec3dict['cube_build']['ra_center'] = 65.0  # Force cube to be centered at this R.A.
#spec3dict['cube_build']['dec_center'] = -35.0  # Force cube to be centered at this Decl.
#spec3dict['cube_build']['cube_pa'] = 45.0  # Force cube to have this position angle
#spec3dict['cube_build']['nspax_x'] = 61  # Force cube to have this number of spaxels in cube X direction
#spec3dict['cube_build']['nspax_y'] = 61  # Force cube to have this number of spaxels in cube Y direction
#spec3dict['cube_build']['wavemin'] = 4.8  # Custom minimum wavelength for the cube
#spec3dict['cube_build']['wavemax'] = 6.3  # Custom maximum wavelength for the cube

# Options for adjusting the 1d spectral extraction
#spec3dict['extract_1d']['ifu_set_srctype'] = 'POINT' # Force a certain type of spectral extraction ('POINT' or 'EXTENDED')
#spec3dict['extract_1d']['ifu_rscale'] = 2  # Number of FWHM to use for point-source conical aperture extraction radius (default is 2)
spec3dict['extract_1d']['ifu_autocen'] = True  # Enable auto-centering of the extraction aperture (default is True)
#spec3dict['extract_1d']['center_xy'] = (20,20)  # Override aperture location if desired

# %% [markdown]
# Define a function to create association files for Stage 3.

# %%
def writel3asn(scifiles, bgfiles, asnfile, prodname):
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)

    # Add background files to the association
    for file in bgfiles:
        asn['products'][0]['members'].append({'expname': file, 'exptype': 'background'})

    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# %% [markdown]
# Find and sort all of the input files, ensuring use of absolute paths

# %%
# Science Files need the cal.fits files
sstring = os.path.join(spec2_dir, 'jw*mirifu*_cal.fits')
calfiles = sorted(glob.glob(sstring))
for ii in range(0, len(calfiles)):
    calfiles[ii] = os.path.abspath(calfiles[ii])
calfiles = np.array(calfiles)
# Check that these are the band/channel to use
calfiles = select_ch_band_files(calfiles, use_ch, use_band)

# Background Files need the x1d.fits files for Master Background subtraction
sstring = os.path.join(spec2_bgdir, 'jw*mirifu*x1d.fits')
bgfiles = sorted(glob.glob(sstring))
for ii in range(0, len(bgfiles)):
    bgfiles[ii] = os.path.abspath(bgfiles[ii])
bgfiles = np.array(bgfiles)
# Check that these are the band/channel to use
bgfiles = select_ch_band_files(bgfiles, use_ch, use_band)

print('Found ' + str(len(calfiles)) + ' science files to process')
print('Found ' + str(len(bgfiles)) + ' background files to process')
# Out:
# Found 16 science files to process
# Found 4 background files to process

# %% [markdown]
# Make an association file that includes all of the different exposures. If using Master Background subtraction include the background data.
#
# <div class="alert alert-block alert-warning">
# Note that science data must be of type cal.fits and background exposures must be of type x1d.fits
# </div>

# %%
asnfile = os.path.join(sci_dir, 'l3asn.json')
if dospec3:
    writel3asn(calfiles, bgfiles, asnfile, 'Level3')
# Out:
# /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:232: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)

# %% [markdown]
# Run calwebb_spec3 using the call method.

# %%
if dospec3:
    Spec3Pipeline.call(asnfile, steps=spec3dict, save_results=True, output_dir=spec3_dir)
else:
    print('Skipping Spec3 processing')
# Out:
# 2026-09-16 12:44:48,047 - stpipe.step - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0052.asdf
# 2026-09-16 12:44:48,057 - stpipe.step - INFO - PARS-ADAPTIVETRACEMODELSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-adaptivetracemodelstep_0001.asdf
# 2026-09-16 12:44:48,065 - stpipe.step - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2026-09-16 12:44:48,072 - stpipe.step - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2026-09-16 12:44:48,080 - stpipe.pipeline - INFO - PARS-SPEC3PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec3pipeline_0009.asdf
# 2026-09-16 12:44:48,651 - stpipe.step - INFO - Spec3Pipeline instance created.
# 2026-09-16 12:44:48,653 - stpipe.step - INFO - AssignMTWcsStep instance created.
# 2026-09-16 12:44:48,653 - stpipe.step - INFO - MasterBackgroundStep instance created.
# 2026-09-16 12:44:48,655 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-09-16 12:44:48,656 - stpipe.step - INFO - AdaptiveTraceModelStep instance created.
# 2026-09-16 12:44:48,657 - stpipe.step - INFO - PixelReplaceStep instance created.
# 2026-09-16 12:44:48,658 - stpipe.step - INFO - ResampleSpecStep instance created.
# 2026-09-16 12:44:48,660 - stpipe.step - INFO - CubeBuildStep instance created.
# 2026-09-16 12:44:48,661 - stpipe.step - INFO - Extract1dStep instance created.
# 2026-09-16 12:44:48,662 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-16 12:44:48,664 - stpipe.step - INFO - Combine1dStep instance created.
# 2026-09-16 12:44:48,666 - stpipe.step - INFO - SpectralLeakStep instance created.
# 2026-09-16 12:44:48,770 - stpipe.step - INFO - Step Spec3Pipeline running with args ('./mrs_data/Obs003/l3asn.json',).
# 2026-09-16 12:44:48,788 - stpipe.step - INFO - Step Spec3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: ./mrs_data/Obs003/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     master_background:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_kernel: 1
#       user_background: None
#       save_background: False
#       force_subtract: False
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 11 1
#       threshold_percent: 99.5
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#       pixmap_stepsize: 1.0
#       pixmap_order: 1
#     adaptive_trace_model:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_threshold: 10.0
#       oversample: 3
#       slope_limit: 0.1
#       psf_optimal: False
#       save_intermediate_results: False
#     pixel_replace:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: mingrad
#       n_adjacent_cols: 3
#     resample_spec:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       propagate_dq: False
#     cube_build:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: s3d
#       search_output_file: False
#       input_dir: ''
#       pipeline: 3
#       channel: all
#       band: all
#       grating: all
#       filter: all
#       output_type: band
#       linear_wave: True
#       scalexy: 0.0
#       scalew: 0.0
#       weighting: drizzle
#       coord_system: skyalign
#       ra_center: None
#       dec_center: None
#       cube_pa: None
#       nspax_x: None
#       nspax_y: None
#       rois: 0.0
#       roiw: 0.0
#       weight_power: 2.0
#       wavemin: None
#       wavemax: None
#       single: False
#       skip_dqflagging: False
#       offset_file: None
#       debug_spaxel: -1 -1 -1
#     extract_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       subtract_background: None
#       apply_apcorr: True
#       extraction_type: box
#       use_source_posn: None
#       position_offset: 0.0
#       model_nod_pair: True
#       optimize_psf_location: True
#       smoothing_length: None
#       bkg_fit: None
#       bkg_order: None
#       log_increment: 50
#       save_profile: False
#       save_scene_model: False
#       save_residual_image: False
#       center_xy: None
#       ifu_autocen: True
#       bkg_sigma_clip: 3.0
#       ifu_rfcorr: True
#       ifu_set_srctype: None
#       ifu_rscale: None
#       ifu_covar_scale: 1.8
#       soss_atoca: True
#       soss_threshold: 0.01
#       soss_n_os: 2
#       soss_wave_grid_in: None
#       soss_wave_grid_out: None
#       soss_estimate: None
#       soss_rtol: 0.0001
#       soss_max_grid_size: 20000
#       soss_tikfac: None
#       soss_width: 40.0
#       soss_bad_pix: masking
#       soss_modelname: None
#       soss_order_3: True
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     combine_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       exptime_key: exposure_time
#       sigma_clip: None
#     spectral_leak:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2026-09-16 12:44:49,019 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'l3asn.json' reftypes = ['apcorr', 'area', 'cubepar', 'extract1d', 'mrsptcorr', 'pastasoss', 'photom', 'psf', 'speckernel', 'specprofile']
# 2026-09-16 12:44:49,022 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf'.
# 2026-09-16 12:44:49,023 - stpipe.pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2026-09-16 12:44:49,023 - stpipe.pipeline - INFO - Prefetch for CUBEPAR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits'.
# 2026-09-16 12:44:49,024 - stpipe.pipeline - INFO - Prefetch for EXTRACT1D reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf'.
# 2026-09-16 12:44:49,024 - stpipe.pipeline - INFO - Prefetch for MRSPTCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsptcorr_0002.fits'.
# 2026-09-16 12:44:49,025 - stpipe.pipeline - INFO - Prefetch for PASTASOSS reference file is 'N/A'.
# 2026-09-16 12:44:49,025 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0225.fits'.
# 2026-09-16 12:44:49,026 - stpipe.pipeline - INFO - Prefetch for PSF reference file is 'N/A'.
# 2026-09-16 12:44:49,026 - stpipe.pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2026-09-16 12:44:49,027 - stpipe.pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2026-09-16 12:44:49,028 - jwst.pipeline.calwebb_spec3 - INFO - Starting calwebb_spec3 ...
# 2026-09-16 12:45:01,387 - stpipe.step - INFO - Step master_background running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8aee229a90>,).
# 2026-09-16 12:45:01,389 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:45:02,062 - stpipe.step - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8aee138ec0>,).
# 2026-09-16 12:45:02,063 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: ifu
# 2026-09-16 12:45:02,063 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-09-16 12:45:02,064 - jwst.outlier_detection.ifu - INFO - Performing IFU outlier_detection for exptype MIR_MRS
# 2026-09-16 12:45:02,980 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:02,995 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,011 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,026 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,041 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,057 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,079 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,099 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3541 (0.34%)
# 2026-09-16 12:45:03,841 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,858 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,875 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,891 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,912 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,929 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,946 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:03,964 - jwst.outlier_detection.ifu - INFO - Total # pixels flagged as outliers: 3846 (0.36%)
# 2026-09-16 12:45:04,398 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00001_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:04,774 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00001_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:05,085 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00002_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:05,449 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00002_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:05,781 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00003_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:06,138 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00003_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:06,443 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00004_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:06,835 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_02101_00004_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:07,555 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00001_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:07,948 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00001_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:08,254 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00002_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:08,603 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00002_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:08,904 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00003_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:09,271 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00003_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:09,581 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00004_mirifulong_a3001_crf.fits
# 2026-09-16 12:45:09,934 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/jw03722003001_04101_00004_mirifushort_a3001_crf.fits
# 2026-09-16 12:45:09,940 - stpipe.step - INFO - Step outlier_detection done
# 2026-09-16 12:45:10,381 - stpipe.step - INFO - Step adaptive_trace_model running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8aee138ec0>,).
# 2026-09-16 12:45:10,382 - stpipe.step - INFO - Step skipped.
# 2026-09-16 12:45:11,026 - stpipe.step - INFO - Step pixel_replace running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8aee138ec0>,).
# 2026-09-16 12:45:11,036 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,157 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 11651 total pixels replaced.
# 2026-09-16 12:45:11,162 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,247 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14233 total pixels replaced.
# 2026-09-16 12:45:11,251 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,338 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 11661 total pixels replaced.
# 2026-09-16 12:45:11,342 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,425 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14214 total pixels replaced.
# 2026-09-16 12:45:11,429 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,522 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 11652 total pixels replaced.
# 2026-09-16 12:45:11,527 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,614 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14214 total pixels replaced.
# 2026-09-16 12:45:11,619 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,718 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 11652 total pixels replaced.
# 2026-09-16 12:45:11,727 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,836 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14214 total pixels replaced.
# 2026-09-16 12:45:11,841 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:11,942 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 12022 total pixels replaced.
# 2026-09-16 12:45:11,947 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,034 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14283 total pixels replaced.
# 2026-09-16 12:45:12,041 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,132 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 12022 total pixels replaced.
# 2026-09-16 12:45:12,137 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,231 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14283 total pixels replaced.
# 2026-09-16 12:45:12,237 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,345 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 12022 total pixels replaced.
# 2026-09-16 12:45:12,352 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,469 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14283 total pixels replaced.
# 2026-09-16 12:45:12,475 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,570 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 12023 total pixels replaced.
# 2026-09-16 12:45:12,576 - jwst.pixel_replace.pixel_replace - INFO - Using minimum gradient method.
# 2026-09-16 12:45:12,661 - jwst.pixel_replace.pixel_replace - INFO - Input MRS frame had 14282 total pixels replaced.
# 2026-09-16 12:45:12,790 - stpipe.step - INFO - Step pixel_replace done
# 2026-09-16 12:45:13,203 - stpipe.step - INFO - Step cube_build running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8aee138ec0>,).
# 2026-09-16 12:45:13,204 - jwst.cube_build.cube_build_step - INFO - Starting IFU Cube Building Step
# 2026-09-16 12:45:13,205 - jwst.cube_build.cube_build_step - INFO - Input interpolation: drizzle
# 2026-09-16 12:45:13,206 - jwst.cube_build.cube_build_step - INFO - Coordinate system to use: skyalign
# 2026-09-16 12:45:13,207 - jwst.cube_build.cube_build_step - INFO - Setting output type to: band
# 2026-09-16 12:45:13,363 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI Channels: ['1', '1', '2', '2', '3', '3', '4', '4']
# 2026-09-16 12:45:13,364 - jwst.cube_build.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['medium', 'long', 'medium', 'long', 'medium', 'long', 'medium', 'long']
# 2026-09-16 12:45:13,365 - jwst.cube_build.cube_build - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2026-09-16 12:45:13,594 - jwst.cube_build.cube_build - INFO - Output Cubes are single channel, single sub-channel IFU Cubes
# 2026-09-16 12:45:13,595 - jwst.cube_build.cube_build_step - INFO - Number of IFU cubes produced by this run = 8
# 2026-09-16 12:45:13,596 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:13,827 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:14,083 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:14,264 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:14,474 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:45:14,475 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:45:14,475 - jwst.cube_build.ifu_cube - INFO - Axis 1    45  23.00 171.81113447   0.13000000  -2.92499989   2.92499989
# 2026-09-16 12:45:14,476 - jwst.cube_build.ifu_cube - INFO - Axis 2    45  23.00  42.47315327   0.13000000  -2.92499989   2.92499989
# 2026-09-16 12:45:14,476 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:45:14,477 - jwst.cube_build.ifu_cube - INFO - Axis 3  1213   1.00   5.66039985   0.00080000   5.65999985   6.63039982
# 2026-09-16 12:45:14,478 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 1, medium
# 2026-09-16 12:45:14,478 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['medium']
# 2026-09-16 12:45:14,479 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch1-medium
# 2026-09-16 12:45:15,330 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3822 with wavelength below 5.658443867990825
# 2026-09-16 12:45:15,332 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 2910 with wavelength above 6.631955802319028
# 2026-09-16 12:45:19,543 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3822 with wavelength below 5.65844386799229
# 2026-09-16 12:45:19,544 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 2910 with wavelength above 6.631955802317563
# 2026-09-16 12:45:24,374 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3822 with wavelength below 5.658443867994488
# 2026-09-16 12:45:24,376 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 2910 with wavelength above 6.631955802315365
# 2026-09-16 12:45:28,563 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3822 with wavelength below 5.658443867995182
# 2026-09-16 12:45:28,564 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 2910 with wavelength above 6.631955802314671
# 2026-09-16 12:45:31,929 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:45:31,930 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:45:31,937 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:45:32,169 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:32,371 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:32,545 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:32,750 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:45:32,954 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:45:32,955 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:45:32,958 - jwst.cube_build.ifu_cube - INFO - Axis 1    45  23.00 171.81121048   0.13000000  -2.92499989   2.92499989
# 2026-09-16 12:45:32,960 - jwst.cube_build.ifu_cube - INFO - Axis 2    45  23.00  42.47309836   0.13000000  -2.92499989   2.92499989
# 2026-09-16 12:45:32,961 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:45:32,962 - jwst.cube_build.ifu_cube - INFO - Axis 3  1400   1.00   6.53040021   0.00080000   6.53000021   7.65000018
# 2026-09-16 12:45:32,963 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 1, long
# 2026-09-16 12:45:32,963 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['long']
# 2026-09-16 12:45:32,964 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch1-long
# 2026-09-16 12:45:33,758 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.52826861649648
# 2026-09-16 12:45:33,760 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774826639
# 2026-09-16 12:45:38,183 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616502298
# 2026-09-16 12:45:38,184 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774820822
# 2026-09-16 12:45:42,690 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.5282686165090045
# 2026-09-16 12:45:42,692 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774814115
# 2026-09-16 12:45:46,976 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616514867
# 2026-09-16 12:45:46,977 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774808252
# 2026-09-16 12:45:50,614 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:45:50,614 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:45:50,621 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:45:50,843 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:45:50,844 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:45:50,845 - jwst.cube_build.ifu_cube - INFO - Axis 1    41  21.00 171.81104958   0.17000000  -3.48500004   3.48500004
# 2026-09-16 12:45:50,845 - jwst.cube_build.ifu_cube - INFO - Axis 2    43  22.00  42.47327773   0.17000000  -3.65500004   3.65500004
# 2026-09-16 12:45:50,849 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:45:50,850 - jwst.cube_build.ifu_cube - INFO - Axis 3  1124   1.00   8.67065008   0.00130000   8.67000008  10.13120008
# 2026-09-16 12:45:50,851 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 2, medium
# 2026-09-16 12:45:50,851 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['medium']
# 2026-09-16 12:45:50,852 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch2-medium
# 2026-09-16 12:45:51,700 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1714 with wavelength below 8.667601555074322
# 2026-09-16 12:45:51,701 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1885 with wavelength above 10.133598601491434
# 2026-09-16 12:45:55,726 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1714 with wavelength below 8.667601555076539
# 2026-09-16 12:45:55,727 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1885 with wavelength above 10.133598601489217
# 2026-09-16 12:45:59,635 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1714 with wavelength below 8.667601555079862
# 2026-09-16 12:45:59,636 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1885 with wavelength above 10.133598601485893
# 2026-09-16 12:46:03,352 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1714 with wavelength below 8.667601555080912
# 2026-09-16 12:46:03,353 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1885 with wavelength above 10.133598601484843
# 2026-09-16 12:46:06,486 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:46:06,487 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:46:06,492 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:46:06,695 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:46:06,696 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:46:06,697 - jwst.cube_build.ifu_cube - INFO - Axis 1    41  21.00 171.81102442   0.17000000  -3.48500004   3.48500004
# 2026-09-16 12:46:06,698 - jwst.cube_build.ifu_cube - INFO - Axis 2    41  21.00  42.47322548   0.17000000  -3.48500004   3.48500004
# 2026-09-16 12:46:06,698 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:46:06,699 - jwst.cube_build.ifu_cube - INFO - Axis 3  1300   1.00  10.01065023   0.00130000  10.01000023  11.70000023
# 2026-09-16 12:46:06,700 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 2, long
# 2026-09-16 12:46:06,700 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['long']
# 2026-09-16 12:46:06,701 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch2-long
# 2026-09-16 12:46:07,543 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842400448
# 2026-09-16 12:46:07,544 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619963957
# 2026-09-16 12:46:11,731 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842409284
# 2026-09-16 12:46:11,732 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619955122
# 2026-09-16 12:46:15,905 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.00732784241947
# 2026-09-16 12:46:15,906 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619944936
# 2026-09-16 12:46:20,083 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842428374
# 2026-09-16 12:46:20,084 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619936031
# 2026-09-16 12:46:23,466 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:46:23,466 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:46:23,471 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:46:23,660 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:23,834 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:24,025 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:24,198 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:24,381 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:46:24,381 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:46:24,382 - jwst.cube_build.ifu_cube - INFO - Axis 1    47  24.00 171.81127407   0.20000000  -4.70000007   4.70000007
# 2026-09-16 12:46:24,383 - jwst.cube_build.ifu_cube - INFO - Axis 2    45  23.00  42.47333639   0.20000000  -4.50000007   4.50000007
# 2026-09-16 12:46:24,384 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:46:24,385 - jwst.cube_build.ifu_cube - INFO - Axis 3   892   1.00  13.34125015   0.00250000  13.34000015  15.57000010
# 2026-09-16 12:46:24,385 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 3, medium
# 2026-09-16 12:46:24,386 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['medium']
# 2026-09-16 12:46:24,387 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch3-medium
# 2026-09-16 12:46:25,176 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1123 with wavelength below 13.33608567389222
# 2026-09-16 12:46:25,177 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 227 with wavelength above 15.573914581439176
# 2026-09-16 12:46:29,603 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1123 with wavelength below 13.3360856738956
# 2026-09-16 12:46:29,605 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 227 with wavelength above 15.573914581435798
# 2026-09-16 12:46:33,386 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1123 with wavelength below 13.336085673900664
# 2026-09-16 12:46:33,387 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 227 with wavelength above 15.573914581430733
# 2026-09-16 12:46:37,336 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 1123 with wavelength below 13.336085673903954
# 2026-09-16 12:46:37,339 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 227 with wavelength above 15.573914581427443
# 2026-09-16 12:46:40,512 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:46:40,513 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:46:40,517 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:46:40,718 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:40,881 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:41,059 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:41,237 - jwst.cube_build.ifu_cube - INFO - Mapping all pixels to output to determine IFU foot print
# 2026-09-16 12:46:41,406 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:46:41,407 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:46:41,407 - jwst.cube_build.ifu_cube - INFO - Axis 1    47  24.00 171.81125166   0.20000000  -4.70000007   4.70000007
# 2026-09-16 12:46:41,408 - jwst.cube_build.ifu_cube - INFO - Axis 2    45  23.00  42.47330423   0.20000000  -4.50000007   4.50000007
# 2026-09-16 12:46:41,409 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:46:41,410 - jwst.cube_build.ifu_cube - INFO - Axis 3  1028   1.00  15.41124985   0.00250000  15.40999985  17.97999979
# 2026-09-16 12:46:41,410 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 3, long
# 2026-09-16 12:46:41,411 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['long']
# 2026-09-16 12:46:41,412 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch3-long
# 2026-09-16 12:46:42,140 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374188633
# 2026-09-16 12:46:42,141 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.98431826319161
# 2026-09-16 12:46:46,118 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374203986
# 2026-09-16 12:46:46,119 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263176256
# 2026-09-16 12:46:50,190 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374219439
# 2026-09-16 12:46:50,191 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.9843182631608
# 2026-09-16 12:46:54,209 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.40568137423295
# 2026-09-16 12:46:54,211 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263147294
# 2026-09-16 12:46:57,617 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:46:57,618 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:46:57,623 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:46:57,833 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:46:57,834 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:46:57,834 - jwst.cube_build.ifu_cube - INFO - Axis 1    33  17.00 171.81094908   0.34999999  -5.77499990   5.77499990
# 2026-09-16 12:46:57,835 - jwst.cube_build.ifu_cube - INFO - Axis 2    35  18.00  42.47314436   0.34999999  -6.12499990   6.12499990
# 2026-09-16 12:46:57,836 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:46:57,836 - jwst.cube_build.ifu_cube - INFO - Axis 3   632   1.00  20.69300053   0.00600000  20.69000053  24.48200057
# 2026-09-16 12:46:57,837 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 4, medium
# 2026-09-16 12:46:57,837 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['medium']
# 2026-09-16 12:46:57,838 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch4-medium
# 2026-09-16 12:46:58,515 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 402 with wavelength below 20.682599025870516
# 2026-09-16 12:47:01,435 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 402 with wavelength below 20.682599025876094
# 2026-09-16 12:47:03,923 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 402 with wavelength below 20.68259902588446
# 2026-09-16 12:47:06,375 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 402 with wavelength below 20.682599025889896
# 2026-09-16 12:47:08,253 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:47:08,254 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:47:08,257 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:47:08,439 - jwst.cube_build.ifu_cube - INFO - Cube Geometry:
# 2026-09-16 12:47:08,439 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL       CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2026-09-16 12:47:08,440 - jwst.cube_build.ifu_cube - INFO - Axis 1    33  17.00 171.81090918   0.34999999  -5.77499990   5.77499990
# 2026-09-16 12:47:08,440 - jwst.cube_build.ifu_cube - INFO - Axis 2    35  18.00  42.47315466   0.34999999  -6.12499990   6.12499990
# 2026-09-16 12:47:08,441 - jwst.cube_build.ifu_cube - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2026-09-16 12:47:08,441 - jwst.cube_build.ifu_cube - INFO - Axis 3   717   1.00  24.40299962   0.00600000  24.39999962  28.70199966
# 2026-09-16 12:47:08,442 - jwst.cube_build.ifu_cube - INFO - Cube covers channel, subchannel: 4, long
# 2026-09-16 12:47:08,443 - jwst.cube_build.ifu_cube - INFO - Subchannel listing: ['long']
# 2026-09-16 12:47:08,443 - jwst.cube_build.ifu_cube - INFO - Output Name: Level3_ch4-long
# 2026-09-16 12:47:09,055 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933814725
# 2026-09-16 12:47:11,563 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933840304
# 2026-09-16 12:47:14,068 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.39188693386605
# 2026-09-16 12:47:16,622 - jwst.cube_build.ifu_cube - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933888564
# 2026-09-16 12:47:18,474 - jwst.cube_build.ifu_cube - INFO - Average # of holes/wavelength plane is < 1
# 2026-09-16 12:47:18,475 - jwst.cube_build.ifu_cube - INFO - Total # of holes for IFU cube is : 0
# 2026-09-16 12:47:18,479 - jwst.cube_build.ifu_cube - INFO - Number of spectral tear planes adjusted: 0
# 2026-09-16 12:47:18,646 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.810057385 42.472358825 171.810057385 42.473947714 171.812211564 42.473947714 171.812211564 42.472358825
# 2026-09-16 12:47:18,648 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.810133396 42.472303909 171.810133396 42.473892798 171.812287573 42.473892798 171.812287573 42.472303909
# 2026-09-16 12:47:18,650 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809769114 42.472286059 171.809769114 42.474269392 171.812330040 42.474269392 171.812330040 42.472286059
# 2026-09-16 12:47:18,652 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809743964 42.472281030 171.809743964 42.474169919 171.812304886 42.474169919 171.812304886 42.472281030
# 2026-09-16 12:47:18,653 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809541670 42.472114159 171.809541670 42.474558604 171.813006467 42.474558604 171.813006467 42.472114159
# 2026-09-16 12:47:18,655 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.809519258 42.472081991 171.809519258 42.474526435 171.812984053 42.474526435 171.812984053 42.472081991
# 2026-09-16 12:47:18,657 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.808840066 42.471491560 171.808840066 42.474797115 171.813058096 42.474797115 171.813058096 42.471491560
# 2026-09-16 12:47:18,658 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  171.808800162 42.471501863 171.808800162 42.474807419 171.813018193 42.474807419 171.813018193 42.471501863
# 2026-09-16 12:47:18,835 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch1-medium_s3d.fits
# 2026-09-16 12:47:19,007 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch1-long_s3d.fits
# 2026-09-16 12:47:19,158 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch2-medium_s3d.fits
# 2026-09-16 12:47:19,313 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch2-long_s3d.fits
# 2026-09-16 12:47:19,465 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch3-medium_s3d.fits
# 2026-09-16 12:47:19,619 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch3-long_s3d.fits
# 2026-09-16 12:47:19,763 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch4-medium_s3d.fits
# 2026-09-16 12:47:19,912 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch4-long_s3d.fits
# 2026-09-16 12:47:19,913 - stpipe.step - INFO - Step cube_build done
# 2026-09-16 12:47:20,361 - stpipe.step - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8ae9e74170>,).
# 2026-09-16 12:47:20,423 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:20,427 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0007.asdf
# 2026-09-16 12:47:20,433 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:20,715 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:47:27,242 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:47:27,740 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:47:27,774 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:27,780 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0007.asdf
# 2026-09-16 12:47:27,784 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:28,096 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:47:36,752 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:47:37,439 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:47:37,474 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:37,478 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0005.asdf
# 2026-09-16 12:47:37,482 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:37,755 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:47:43,612 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:47:44,110 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:47:44,144 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:44,149 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0005.asdf
# 2026-09-16 12:47:44,153 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:44,439 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:47:50,982 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:47:51,614 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:47:51,647 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:51,654 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0006.asdf
# 2026-09-16 12:47:51,658 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:51,932 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:47:56,873 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:47:57,437 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:47:57,470 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:47:57,474 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0006.asdf
# 2026-09-16 12:47:57,478 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:47:57,757 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:48:03,480 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:48:04,230 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:48:04,755 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:48:04,761 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf
# 2026-09-16 12:48:04,765 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:48:05,045 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:48:07,969 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:48:08,401 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:48:08,441 - jwst.extract_1d.extract_1d_step - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2026-09-16 12:48:08,446 - jwst.extract_1d.extract_1d_step - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf
# 2026-09-16 12:48:08,450 - jwst.extract_1d.ifu - INFO - Source type = EXTENDED
# 2026-09-16 12:48:08,719 - jwst.extract_1d.ifu - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2026-09-16 12:48:11,919 - jwst.extract_1d.ifu - INFO - Applying 1d residual fringe correction.
# 2026-09-16 12:48:12,313 - jwst.extract_1d.ifu - INFO - Applying ERR covariance prefactor of 1.8
# 2026-09-16 12:48:12,377 - stpipe.step - INFO - Step extract_1d done
# 2026-09-16 12:48:12,802 - stpipe.step - INFO - Step spectral_leak running with args (<jwst.datamodels.container.ModelContainer object at 0x7f8ae9e6f7a0>,).
# 2026-09-16 12:48:12,829 - jwst.spectral_leak.spectral_leak_step - WARNING - No spectral leak correction for extended source data
# 2026-09-16 12:48:12,915 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch1-medium_x1d.fits
# 2026-09-16 12:48:12,976 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch1-long_x1d.fits
# 2026-09-16 12:48:13,037 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch2-medium_x1d.fits
# 2026-09-16 12:48:13,097 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch2-long_x1d.fits
# 2026-09-16 12:48:13,157 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch3-medium_x1d.fits
# 2026-09-16 12:48:13,216 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch3-long_x1d.fits
# 2026-09-16 12:48:13,275 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch4-medium_x1d.fits
# 2026-09-16 12:48:13,332 - stpipe.step - INFO - Saved model in ./mrs_data/Obs003/stage3/Level3_ch4-long_x1d.fits
# 2026-09-16 12:48:13,333 - stpipe.step - INFO - Step spectral_leak done
# 2026-09-16 12:48:13,337 - jwst.pipeline.calwebb_spec3 - INFO - Ending calwebb_spec3
# 2026-09-16 12:48:13,349 - stpipe.step - INFO - Step Spec3Pipeline done
# 2026-09-16 12:48:13,350 - jwst.stpipe.core - INFO - Results used jwst version: 2.0.1

# %%
# Print out the time benchmark
time1 = time.perf_counter()
print(f"Runtime so far: {time1 - time0:0.4f} seconds")
print(f"Runtime for Spec3: {time1 - time_spec3} seconds")
# Out:
# Runtime so far: 1824.7797 seconds
# Runtime for Spec3: 202.7539575360006 seconds

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# 8.<font color='white'>-</font>Plot the spectra<a class="anchor" id="plots"></a>
# ------------------
# Here we'll plot the spectra to see what our source looks like.

# %%
if doviz:
    # Find and sort all of the input files

    # Science Files
    # Use the final extracted spectra (x1d.fits)
    sstring = sorted(glob.glob(os.path.join(spec3_dir, '*x1d.fits')))
    x1dfiles = np.array(sorted(sstring))

# %%
if doviz:
    # Make normal plots
    # %matplotlib inline
    # Interactive plots
    #%matplotlib notebook

    rc('axes', linewidth=2)
    fig, ax = plt.subplots(1, 1, figsize=(10, 3), dpi=150)

    if (len(x1dfiles) > 0):
        hdu = fits.open(x1dfiles[0])
        objname = hdu[0].header['TARGPROP']
        hdu.close()
    else:
        objname = 'Unknown'

    ymin, ymax = np.nan, np.nan
    for file in x1dfiles:
        x1d = fits.open(file)
        x1ddata = x1d[1].data
        wave = x1ddata['WAVELENGTH']
        # MRS x1d files have both regular ('flux') and residual-fringe (RF) corrected ('rf_flux') spectra.
        # The RF-corrected spectra will have NaN values if RF correction was disabled or failed to converge.
        # Plot the RF corrected spectrum if available, otherwise plot the regular spectrum.
        if (np.nansum(x1ddata['RF_FLUX']) != 0):
            flux = x1ddata['RF_FLUX']
        else:
            flux = x1ddata['FLUX']
        ymin = np.nanmin([ymin, np.nanpercentile(flux, 2)])
        ymax = np.nanmax([ymax, np.nanpercentile(flux, 99.5)])

        # labels
        label = x1d[0].header['CHANNEL'] + x1d[0].header['BAND']

        plt.plot(wave, flux, label=label)

        x1d.close()

    plt.xlabel(r'Wavelength ($\mu$m)')
    plt.ylabel('Flux (Jy)')
    plt.title(objname)
    plt.ylim(ymin, ymax)
    plt.legend(fontsize=8, loc='center left', bbox_to_anchor=(1, 0.5))
    plt.grid()
    plt.tight_layout()
    plt.savefig('mrs_example_plot.png')

# %%
# # Another attempt at creating continuous spectra from all the cubes
# # That was a miserable attempt using AI, Ill try to do it myself now 01:53
# import numpy as np
# import matplotlib.pyplot as plt
# 
# from astropy.io import fits
# from astropy.wcs import WCS
# from astropy import units as u
# from astropy.wcs.utils import proj_plane_pixel_area
# from spectral_cube import SpectralCube
# from regions import Regions
# import glob
# import os
# 
# 
# # Import the region file CRTF
# region_file = "/home/fatih/G165_main/G165_miri_bg_subtraction/data/carta_regions/science_footprints"
# regions = Regions.read(region_file)
# # print(regions)
# 
# # Define directory to find cubes
# cube_dir = spec3_dir
# cube_files = sorted(glob.glob(os.path.join(cube_dir, "*s3d.fits")))
# # print(cube_files)
# 
# 
# # Extracting spectra from a region in from the CRTF file
# def extract_region_spectrum(cube_path, regions):
#     """
#     Load a MIRI cube and extract a region-integrated spectrum 
#     defined by one or more CRTF regions.
#     Returns wavelength and flux arrays.
#     """
# 
#     # Load cube
#     cube = SpectralCube.read(cube_path, hdu="SCI")
#     wcs = cube.wcs
#     # pixel area in steradians
#     pix_area_sr = proj_plane_pixel_area(cube.wcs) * u.sr
# 
#     # convert MJy/sr → Jy
#     cube = (cube * pix_area_sr).to(u.Jy)    
#     # Convert cube to Jy (JWST cubes usually already are)
#     
# 
#     # Initialize final mask = False everywhere
#     full_mask = np.zeros(cube.shape[1:], dtype=bool)
# 
#     # Create masks for all regions and OR them together
#     for reg in regions:
#         pixel_reg = reg.to_pixel(wcs)
#         mask = reg.to_mask(mode='center')
#         # In 'center' mode, a pixel is considered to be inside the region if
#         # its central position falls within the region's boundaries. This results
#         #  in a mask where pixel values are either 0 (outside) or 1 (inside), representing a binary mask.
#         
#         # Convert region mask to full image coordinates
#         region_mask = mask.to_image(full_mask.shape)
#         full_mask |= region_mask.astype(bool)
# 
#     # Apply mask to each wavelength slice and integrate
#     wavelengths = cube.spectral_axis.to_value('micron') # smart package converting to micron
#     flux = []
# 
#     for i in range(len(wavelengths)):
#         slice2d = cube.unmasked_data[i, :, :]     # 2D slice at wavelength i
#         masked = slice2d[full_mask]               # apply region mask
#         flux.append(np.nansum(masked))            # integrate flux in region
# 
#     flux = np.array(flux)
# 
#     return wavelengths, flux
# 
# 
# # Looping through all cubes
# all_waves = []
# all_fluxes = []
# 
# for cube_path in cube_files:
#     wave, flux = extract_region_spectrum(cube_path, regions)
#     all_waves.append(wave)
#     all_fluxes.append(flux)
# 
# 
# # Combine all spectra into single arrays
# wave_all = np.concatenate(all_waves)
# flux_all = np.concatenate(all_fluxes)
# 
# # Sort by wavelength
# order = np.argsort(wave_all) # np.argsort returns the indices you would sort an array
# wave_all = wave_all[order]
# flux_all = flux_all[order]
# 
# 
# # Plotting 
# plt.figure(figsize=(12,4))
# plt.plot(wave_all, flux_all, linewidth=1.2)
# 
# plt.xlabel("Wavelength (µm)")
# plt.ylabel("Flux (Jy)")
# plt.title("Region-Integrated Spectrum")
# plt.grid(alpha=0.3)
# plt.tight_layout()
# plt.show()
# 
# 
#

# %% [markdown]
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# <img style="float: center;" src="https://github.com/spacetelescope/jwst-pipeline-notebooks/raw/main/_static/stsci_footer.png" alt="stsci_logo" width="200px"/>
