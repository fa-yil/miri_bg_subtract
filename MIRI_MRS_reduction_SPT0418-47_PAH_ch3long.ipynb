# %% [markdown]
# # SPT0418-47 MIRI MRS Reduction Notebook

# %% [markdown]
# By the TEMPLATES ERS team, last updated 2023 June 1
#
# J. Spilker, K. A. Phadke, D. Law
#
# Mostly cobbled together from STScI and D. Law notebooks with additional custom processing steps.
#
# This notebook demonstrates how to reduce IFU data from the MIRI MRS instrument beginning from the raw exposure files through to a fully science-ready data cube. In particular we show how the TEMPLATES team is currently addressing the so-called 'cosmic ray shower' artifacts that limit the achievable depth of MRS observations. We expect (and hope!) that the pipeline will eventually be mature enough to deal with these artifacts, but as of early 2023 the method we demonstrate here worked better for our use case.
#
# This notebook was primarily developed to support the analysis in [Spilker et al. (2023)](https://www.nature.com/articles/s41586-023-05998-6). If you find this notebook useful, please cite the paper! If you have suggestions for better data processing, please contact us! We're interested in getting current best practices distributed widely throughout the community.
#
# Requirements:
# - Common scientific python packages: numpy, matplotlib, astropy
# - Working installed version of the JWST pipeline
# - The [miricoord](https://github.com/STScI-MIRI/miricoord/) package for MRS coordinate transforms
# - The [photutils](https://photutils.readthedocs.io/en/stable/) package for cosmic ray shower artifact removal
#
# This notebook is organized into a few different stages:
# 1. [Data and Processing Overview](#Data-and-Processing-Overview)
# 2. [Imports and Prep](#Imports-and-Prep)
# 3. [Stage 1 Detector Pipeline Processing](#Stage-1-Detector-Pipeline-Processing)
# 4. [Refine Bad Pixel Mask](#Refine-Bad-Pixel-Mask)
# 5. [Stage 2 Pipeline Processing](#Stage-2-Pipeline-Processing)
# 6. [Stage 3 Pipeline Processing](#Stage-3-Pipeline-Processing)
# 7. [Post-pipeline Cube Stripe Removal](#Post-pipeline-Cube-Stripe-Removal)
# 8. [Cube Analysis and Spectral Extraction](#Cube-Analysis-and-Spectral-Extraction)
# 9. [Lessons Learned and Future Improvements](#Lessons-Learned-and-Future-Improvements)

# %% [markdown]
# ## Data and Processing Overview

# %% [markdown]
# In this notebook we will demonstrate the reduction of MIRI MRS data acquired as part of the TEMPLATES ERS program (#1355). The target galaxy is SPT0418-47, an IR-selected dusty galaxy at z=4.22 gravitationally lensed by a foreground galaxy at z=0.26. The goal of the observations was to detect and spatially resolve emission from the 3.3um polycyclic aromatic hydrocarbon (PAH) feature. This feature is normally faint and is intrinsically broad, with FWHM~3000km/s, much larger than the line width of the gas-phase emission lines in the galaxy. This makes the data analysis challenging, because the emission we care about is extended both spatially and spectrally, and is quite faint.
#
# The data were taken on 8 August 2022. The PAH feature is redshifted into Channel 3 of the LONG ('C') grating, so the data cover the 4 separate wavelength ranges of the LONG grating (see the [MRS documentation](https://jwst-docs.stsci.edu/jwst-mid-infrared-instrument/miri-observing-modes/miri-medium-resolution-spectroscopy#MIRIMediumResolutionSpectroscopy-wavelengthMRSwavelengthcoverage) for details). In Channel 3 the MRS field of view is about 5.2" x 6.1" with a spectral resolving power R~2600. We used the SLOWR1 detector readout pattern (note that current best practice is to use FAST readout). We observed with a standard 4-point dither pattern for a total on-source exposure time of 3440s. The science observations were accompanied by dedicated background exposures with the same 4-point dither pattern and exposure time. There were also simultaneous exposures taken with the MIRI imager during the on-source MRS exposures, but we ignore those here.

# %% [markdown]
# ## Imports and Prep

# %% [markdown]
# We start by importing required packages and organizing our directory structure. You will need to download the raw (level 0) IFU exposures from MAST and place them in the `uncal_files` folder.
#
# Here is a direct link to the MRS exposures: [SPT0418-47 MIRI/MRS LONG](https://mast.stsci.edu/portal/Mashup/Clients/Mast/Portal.html?searchQuery=%7B%22service%22%3A%22CAOMFILTERED%22%2C%22inputText%22%3A%5B%7B%22paramName%22%3A%22obs_collection%22%2C%22niceName%22%3A%22obs_collection%22%2C%22values%22%3A%5B%22JWST%22%5D%2C%22valString%22%3A%22JWST%22%2C%22isDate%22%3Afalse%2C%22separator%22%3A%22%3B%22%2C%22facetType%22%3A%22discrete%22%2C%22displayString%22%3A%22JWST%22%7D%2C%7B%22paramName%22%3A%22instrument_name%22%2C%22niceName%22%3A%22instrument_name%22%2C%22values%22%3A%5B%22MIRI%22%5D%2C%22valString%22%3A%22MIRI%22%2C%22isDate%22%3Afalse%2C%22facetType%22%3A%22discrete%22%2C%22displayString%22%3A%22MIRI%22%7D%2C%7B%22paramName%22%3A%22filters%22%2C%22niceName%22%3A%22filters%22%2C%22values%22%3A%5B%22MRS%22%5D%2C%22valString%22%3A%22MRS%22%2C%22isDate%22%3Afalse%2C%22separator%22%3A%22%3B%22%2C%22facetType%22%3A%22discrete%22%2C%22displayString%22%3A%22MRS%22%7D%2C%7B%22paramName%22%3A%22proposal_id%22%2C%22niceName%22%3A%22proposal_id%22%2C%22values%22%3A%5B%5D%2C%22valString%22%3A%221355%22%2C%22isDate%22%3Afalse%2C%22freeText%22%3A%221355%22%2C%22displayString%22%3A%221355%22%7D%2C%7B%22paramName%22%3A%22t_min%22%2C%22niceName%22%3A%22t_min%22%2C%22values%22%3A%5B%7B%22min%22%3A59792.041666667%2C%22max%22%3A59822.041666667%7D%5D%2C%22valString%22%3A%22%5B59792.041666667%2C%2059822.041666667%5D%22%2C%22isDate%22%3Afalse%2C%22facetType%22%3A%22numeric%22%2C%22min%22%3A59792.041666667%2C%22max%22%3A59822.041666667%2C%22displayString%22%3A%22%5B59792.041666667%2C%2059822.041666667%5D%22%7D%5D%2C%22position%22%3A%22undefined%2C%20undefined%2C%20undefined%22%2C%22paramsService%22%3A%22Mast.Caom.Filtered%22%2C%22title%22%3A%22MAST%3A%20%20Advanced%20Search%202%22%2C%22tooltip%22%3A%22JWST%3B%20MIRI%3B%20MRS%3B%201355%3B%20%5B59792.041666667%2C%2059822.041666667%5D%3B%20%22%2C%22columns%22%3A%22*%22%2C%22columnsConfig%22%3A%22Mast.Caom.Cone%22%7D)
#
# To download the data products, click the checkbox on the left-hand side of the search results list to select all rows, and then click the 'Add to download basket' button along the top-right of the results window. Because we want to start with the raw uncalibrated data, in the download manager popup window that appears, *uncheck* the box for 'Minimum Recommended Products'. That will allow you to download data products at any other stage of processing. Scroll down to the 'Group' filter and check the box for UNCAL exposures - there should be 16: two MIRI detector exposures at 4 dither positions for each of the on- and off-source exposures. Download all 16 of these files and place the .fits files into a folder named `uncal_files`.
#
# Explanation of uncal file naming, example `jw01355017001_02101_00001_mirifulong_uncal.fits`:
# - `jw`    = JWST
# - `01355` = TEMPLATES program ID number
# - `017`   = Observation number
# - `001`   = Visit number
# - `02101` = The `02` exposures are on-source, the `04` exposures are backgrounds.
# - `00001` = Exposure number, 1 to 4 for each dither position at both on- and off-source
# - `mirifulong` = Long- (or short-) wavelength MRS detector. Note this is not the same as the SHORT/MEDIUM/LONG grating specifications (it's confusing!). Channels 1 and 2 are always on the short detector, 3 and 4 always on the long detector, regardless of the grating setting.
# - `uncal` = We are starting on the raw uncalibrated exposures
# - `fits`  = This file is in the "Flexible Image Transport System" format, perhaps you've heard of it?

# %%
# If you want plots to render in this notebook:
# %matplotlib inline
from IPython.display import Image

# Standard imports
import os, sys, glob, yaml
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits


# This is here to connect to the CRDS server and download the necessary calibration files.
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds.stsci.edu"
os.environ["CRDS_PATH"] = "/home/fatih/crds_cache"
os.environ.pop("CRDS_SERVERLESS_MODE", None)

# JWST-specific imports
import jwst
import stcal

# We will make our own JWST pipeline objects, so import those separately
from jwst.pipeline import Detector1Pipeline, Spec2Pipeline, Spec3Pipeline

# Additional pipeline utilities
from jwst import datamodels                                         # work with 'data models'
from jwst.datamodels import dqflags                                 # Work with data quality (DQ) arrays
from jwst.associations import asn_from_list as afl                  # Helper for pipeline association files
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase  # Create a new custom Lvl2 association file
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base # Create a new custom Lvl3 association file

# Utilities for MIRI coordinate transforms and mappings, see:
# https://github.com/STScI-MIRI/miricoord/
import miricoord
import miricoord.mrs.mrs_tools as mrstools

# These are used to estimate and remove the residual CR shower striping
# from the pipe-processed cubes.

from photutils.aperture import CircularAperture, CircularAnnulus, SkyCircularAperture, SkyCircularAnnulus, aperture_photometry
from photutils.background import Background2D, MedianBackground

"""
The following two lines gave an error 'ImportError: cannot import name 'CircularAperture' from 'photutils'...'. 
The upper two lines worked. ChatGPT said "If that works, it means photutils does not export these at the top-level 
__init__.py but only from the submodules." Long story short, these modules are under the aperture module and not the 
top-level main photutils module.
"""
#from photutils import CircularAperture, CircularAnnulus, SkyCircularAperture, SkyCircularAnnulus, aperture_photometry
#from photutils.background import Background2D, MedianBackground

# For useful future reference, keep track of the current JWST and STCAL versions
print('# JWST pipe version = {0:s}'.format(jwst.__version__))
print('# STCAL version = {0:s}'.format(stcal.__version__))
# Out:
# # JWST pipe version = 1.18.1
# # STCAL version = 1.12.0

# %%
# Arrange our directory structure. 
# All 16 uncal files should be in the `uncal_files' folder.
# We will place the outputs of each pipeline stage in new folders, easier to keep track of.
here       = os.getcwd()
uncal      = 'uncal_files/'
stage1     = 'stage1/'
stage2     = 'stage2/'
stage3     = 'stage3/'
poststage3 = 'poststage3/'   # For post-pipeline processing

# Create above folders if they don't already exist
for folder in [uncal,stage1,stage2,stage3,poststage3]:
    if not os.path.exists(folder): os.makedirs(folder)

# %%
# Flags to decide which pipeline processing steps to run. Briefly:
#  dodet1   = Run Detector1 pipeline, basic raw exposures to rate files (remove bias, darks, cosmic ray caused stuff)
#  dobadpix = Use the background exposures to ID and flag bad pixels in the sci frames
#  dospec2  = Run Detector2 pipeline, rate files to background-subtracted cal files 
#  dospec3  = Run Detector3 pipeline, cal files to nearly science-ready cubes
#  dopost   = Run post-pipeline processing steps (CR shower de-striping)
#  doanalyze= Make continuum and PAH pseudo-NB images, get a spectrum
dodet1    = True  
dobadpix  = False
dospec2   = True
dospec3   = True
dopost    = True
doanalyze = False

# %% [markdown]
# ## Stage 1 Detector Pipeline Processing

# %% [markdown]
# We start by running the Stage 1 detector pipeline on all the uncalibrated exposures, on- and off-source. We will define a function that creates a new `Detector1Pipeline` object and sets any and all non-default options.
#
# We make changes to two of the pipeline processing steps to try to alleviate the issues caused by CR hits and showers. In the `jump` step, we lower the thresholds required to flag pixels as CR hits. The current pipeline versions also include an early treatment of the CR shower artifacts, also included in the `jump` step. The best sub-option parameters for this are very much a work in progress. You can read more about these options from the [JWST pipeline documentation](https://jwst-pipeline.readthedocs.io/en/stable/jwst/jump/index.html).

# %%
############ STAGE 1 DETECTOR PIPELINE

# Define a function to call the detector1 pipeline with desired parameters.
# Individual steps not enumerated. Options can be set as the commented overrides.

def rundet1(filename, outdir):
    """
    Create a Detector1Pipeline object and set all the desired stage 1
    pipeline processing arguments.
    
    Arguments:
      * filename  :  _uncal.fits exposure file name
      * outdir    :  Directory for the stage 1 output files
    
    Returns:
      * None
      
    Outputs:
      * Writes a _rate.fits and _rateints.fits file to `outdir`.
    """
    
    print('Running Detector1Pipeline on {0:s}...'.format(filename))
    
    det1 = Detector1Pipeline() # Instantiate the pipeline
    det1.output_dir = outdir   # Specify where the output should go
    
    # Overrides for whether or not certain steps should be skipped
    #det1.dq_init.skip = False
    #det1.saturation.skip = False
    #det1.firstframe.skip = False
    #det1.lastframe.skip = False
    #det1.reset.skip = False
    #det1.linearity.skip = False
    #det1.rscd.skip = False
    #det1.dark_current.skip = False
    #det1.refpix.skip = False
    #det1.jump.skip = False
    #det1.ramp_fit.skip = False
    #det1.gain_scale.skip = False
    
    # Trun on multiprocessing for jump and ramp fitting steps
    det1.jump.maximum_cores = 'half'
    det1.ramp_fit.maximum_cores = 'half'
    
    # Bad pixel mask overrides
    #det1.dq_init.override_mask = 'myfile.fits'

    # Saturation overrides
    #et1.saturation.override_saturation = 'myfile.fits'
    
    # Reset overrides
    #det1.reset.override_reset = 'myfile.fits'
        
    # Linearity overrides
    #det1.linearity.override_linearity = 'myfile.fits'

    # RSCD overrides
    #det1.rscd.override_rscd = 'myfile.fits'
        
    # DARK overrides
    #det1.dark_current.override_dark = 'myfile.fits'
        
    # GAIN overrides
    #det1.jump.override_gain = 'myfile.fits'
    #det1.ramp_fit.override_gain = 'myfile.fits'
                
    # READNOISE overrides
    #det1.jump.override_readnoise = 'myfile.fits'
    #det1.ramp_fit.override_readnoise = 'myfile.fits'
    
    # JUMP overrides. 
    # Currently pipeline is not flagging lower-level jumps
    # like we might want it to, so lower thresholds for more
    # aggressive flagging.
    #det1.jump.save_results = True
    det1.jump.rejection_threshold = 3.5         # default 4.0sigma
    det1.jump.min_jump_to_flag_neighbors = 8.0  # default 10sigma
    
    # Additional JUMP overrides related to CR shower flagging. See
    # JWST pipeline documentation page for details of parameters.
    # https://jwst-pipeline.readthedocs.io/en/stable/jwst/jump/index.html
    det1.jump.expand_large_events   = True   # Turn on shower flagging
    det1.jump.use_ellipses          = True   # True for MIRI; approximate showers as elliptical
    det1.jump.min_jump_area         = 12     # Min # of contiguous pixels to trigger expanded flagging
    det1.jump.sat_required_snowball = False  # Do not require pixels to be saturated to flag
    det1.jump.expand_factor         = 3.0    # expands showers beyond ID'd jumps; default 2.0
    
    det1.jump.after_jump_flag_dn1   = 10     # These 4 related to how long after a jump is identified
    det1.jump.after_jump_flag_time1 = 20     #  we should keep flagging the following integrations
    det1.jump.after_jump_flag_dn2   = 1000
    det1.jump.after_jump_flag_time2 = 3000
    
    
    # Ramp_fit overrides.
    #det1.ramp_fit.save_opt = True
    #det1.ramp_fit.save_results = True
        
    det1.save_results = True # Save the final resulting _rate.fits files
    
    det1(filename)           # Run the pipeline on an input list of files

# %%
from crds import client

print("Server URL:", client.get_crds_server())
print("Latest context:", client.get_default_context("jwst"))
# Out:
# CRDS - INFO -  Calibration SW Found: jwst 1.18.1 (/home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst-1.18.1.dist-info)
# Server URL: https://jwst-crds.stsci.edu
# Latest context: jwst_1364.pmap

# %%
# Run the Detector1 pipeline on each uncal exposure.

# grab a list of all uncal files from the folder defined above
files_uncal = sorted(glob.glob(uncal+'*uncal.fits'))

if dodet1:
    for exposure in files_uncal: rundet1(filename=exposure, outdir=stage1)
# Out:
# 2025-06-16 19:19:31,219 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2025-06-16 19:19:31,220 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-06-16 19:19:31,221 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-06-16 19:19:31,222 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-06-16 19:19:31,223 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-06-16 19:19:31,224 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-06-16 19:19:31,225 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-06-16 19:19:31,226 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-06-16 19:19:31,227 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-06-16 19:19:31,227 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-06-16 19:19:31,228 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-06-16 19:19:31,229 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-06-16 19:19:31,231 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-06-16 19:19:31,232 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2025-06-16 19:19:31,233 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-06-16 19:19:31,234 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-06-16 19:19:31,235 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2025-06-16 19:19:31,236 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-06-16 19:19:31,237 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-06-16 19:19:31,239 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-06-16 19:19:31,240 - stpipe - WARNING - /tmp/ipykernel_1018/3499085749.py:100: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   det1(filename)           # Run the pipeline on an input list of files
#
# 2025-06-16 19:19:31,240 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-06-16 19:19:31,513 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('uncal_files/jw03722003001_02101_00001_mirifulong_uncal.fits',).
# Running Detector1Pipeline on uncal_files/jw03722003001_02101_00001_mirifulong_uncal.fits...
# 2025-06-16 19:19:31,525 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: sequential
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       type: baseline
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: None
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 3.5
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 8.0
#       after_jump_flag_dn1: 10
#       after_jump_flag_time1: 20
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: True
#       min_sat_area: 1.0
#       min_jump_area: 12
#       expand_factor: 3.0
#       use_ellipses: True
#       sat_required_snowball: False
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: half
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-06-16 19:19:31,795 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifulong_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-06-16 19:19:31,798 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0110.fits'.
# 2025-06-16 19:19:31,798 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits'.
# 2025-06-16 19:19:31,799 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits'.
# 2025-06-16 19:19:31,799 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits'.
# 2025-06-16 19:19:31,800 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits'.
# 2025-06-16 19:19:31,801 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-06-16 19:19:31,801 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits'.
# 2025-06-16 19:19:31,802 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-06-16 19:19:31,802 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits'.
# 2025-06-16 19:19:31,803 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0016.fits'.
# 2025-06-16 19:19:31,803 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits'.
# 2025-06-16 19:19:31,804 - stpipe.Detector1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-06-16 19:19:31,804 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-06-16 19:19:31,805 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-06-16 19:19:31,805 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-06-16 19:19:31,806 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2025-06-16 19:19:32,234 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:32,239 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-06-16 19:19:32,240 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-06-16 19:19:32,241 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-06-16 19:19:32,307 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:32,317 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0062.fits
# 2025-06-16 19:19:32,703 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-06-16 19:19:32,767 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:32,768 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-06-16 19:19:32,837 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:32,847 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0035.fits
# 2025-06-16 19:19:32,880 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:32,890 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:32,955 - stpipe.Detector1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-06-16 19:19:33,441 - stpipe.Detector1Pipeline.saturation - INFO - Detected 513 saturated pixels
# 2025-06-16 19:19:33,471 - stpipe.Detector1Pipeline.saturation - INFO - Detected 71 A/D floor pixels
# 2025-06-16 19:19:33,475 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-06-16 19:19:33,542 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:33,553 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits
# 2025-06-16 19:19:34,265 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2025-06-16 19:19:34,334 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:34,403 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-06-16 19:19:34,474 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:34,547 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-06-16 19:19:34,612 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:34,623 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0056.fits
# 2025-06-16 19:19:34,704 - stpipe.Detector1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:34,713 - stpipe.Detector1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:34,899 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-06-16 19:19:34,968 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:34,978 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0035.fits
# 2025-06-16 19:19:35,003 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:35,012 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:35,400 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-06-16 19:19:35,471 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:35,481 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0016.fits
# 2025-06-16 19:19:35,618 - stpipe.Detector1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-06-16 19:19:35,620 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-06-16 19:19:35,688 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:35,697 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0110.fits
# 2025-06-16 19:19:37,200 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2025-06-16 19:19:37,201 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-06-16 19:19:37,543 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-06-16 19:19:37,612 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:37,709 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2025-06-16 19:19:37,710 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2025-06-16 19:19:37,710 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2025-06-16 19:19:37,711 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2025-06-16 19:19:37,711 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2025-06-16 19:19:37,711 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2025-06-16 19:19:37,712 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2025-06-16 19:19:37,713 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2025-06-16 19:19:37,714 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2025-06-16 19:19:38,187 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2025-06-16 19:19:38,251 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2025-06-16 19:19:38,317 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:38,318 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2025-06-16 19:19:38,386 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:38,391 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 3.5 sigma
# 2025-06-16 19:19:38,392 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2025-06-16 19:19:38,484 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2025-06-16 19:19:38,491 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2025-06-16 19:19:40,923 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2025-06-16 19:19:40,924 - stpipe.Detector1Pipeline.jump - INFO - Creating 8 processes for jump detection
# 2025-06-16 19:19:43,488 - stpipe.Detector1Pipeline.jump - INFO - Flagging Snowballs
# 2025-06-16 19:19:45,670 - stpipe.Detector1Pipeline.jump - INFO - Total snowballs = 5537
# 2025-06-16 19:19:45,671 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 4.74685 sec
# 2025-06-16 19:19:45,742 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 7.350634
# 2025-06-16 19:19:45,744 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2025-06-16 19:19:45,826 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:45,827 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-06-16 19:19:45,895 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:46,020 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0064.fits
# 2025-06-16 19:19:46,020 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0033.fits
# 2025-06-16 19:19:46,042 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = OLS_C
# 2025-06-16 19:19:46,042 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2025-06-16 19:19:46,671 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of multiprocessing slices: 8
# 2025-06-16 19:19:46,677 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2025-06-16 19:19:46,678 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-06-16 19:19:46,679 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 8
# 2025-06-16 19:19:48,446 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2025-06-16 19:19:48,515 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:48,537 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-06-16 19:19:48,538 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-06-16 19:19:48,541 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-06-16 19:19:48,614 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from jw03722003001_02101_00001_mirifulong_uncal.fits>,).
# 2025-06-16 19:19:48,634 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-06-16 19:19:48,634 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-06-16 19:19:48,636 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-06-16 19:19:48,698 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw03722003001_02101_00001_mirifulong_rateints.fits
# 2025-06-16 19:19:48,699 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2025-06-16 19:19:48,699 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:19:48,747 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw03722003001_02101_00001_mirifulong_rate.fits
# 2025-06-16 19:19:48,748 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2025-06-16 19:19:48,748 - stpipe - INFO - Results used jwst version: 1.18.1
# 2025-06-16 19:19:48,756 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2025-06-16 19:19:48,757 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2025-06-16 19:19:48,758 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2025-06-16 19:19:48,759 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2025-06-16 19:19:48,760 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2025-06-16 19:19:48,761 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2025-06-16 19:19:48,762 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2025-06-16 19:19:48,764 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2025-06-16 19:19:48,765 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2025-06-16 19:19:48,767 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2025-06-16 19:19:48,768 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2025-06-16 19:19:48,769 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2025-06-16 19:19:48,769 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2025-06-16 19:19:48,770 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2025-06-16 19:19:48,771 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2025-06-16 19:19:48,772 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2025-06-16 19:19:48,774 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2025-06-16 19:19:48,775 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2025-06-16 19:19:48,776 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2025-06-16 19:19:48,776 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2025-06-16 19:19:48,777 - stpipe - WARNING - /tmp/ipykernel_1018/3499085749.py:100: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   det1(filename)           # Run the pipeline on an input list of files
#
# 2025-06-16 19:19:48,777 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-06-16 19:19:48,849 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('uncal_files/jw03722003001_02101_00001_mirifushort_uncal.fits',).
# 2025-06-16 19:19:48,861 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: stage1/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: False
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: sequential
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#       fit_ints_separately: False
#       user_supplied_reffile: None
#       save_intermediate_results: False
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#       refpix_algorithm: median
#       sigreject: 4.0
#       gaussmooth: 1.0
#       halfwidth: 30
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       type: baseline
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: False
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: None
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 3.5
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000.0
#       min_jump_to_flag_neighbors: 8.0
#       after_jump_flag_dn1: 10
#       after_jump_flag_time1: 20
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: True
#       min_sat_area: 1.0
#       min_jump_area: 12
#       expand_factor: 3.0
#       use_ellipses: True
#       sat_required_snowball: False
#       min_sat_radius_extend: 2.5
#       sat_expand: 2
#       edge_size: 25
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       max_shower_amplitude: 4.0
#       extend_snr_threshold: 1.2
#       extend_min_area: 90
#       extend_inner_radius: 1.0
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 15.0
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: half
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# Running Detector1Pipeline on uncal_files/jw03722003001_02101_00001_mirifushort_uncal.fits...
# 2025-06-16 19:19:49,079 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-06-16 19:19:49,081 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0109.fits'.
# 2025-06-16 19:19:49,082 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2025-06-16 19:19:49,082 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits'.
# 2025-06-16 19:19:49,083 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2025-06-16 19:19:49,083 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2025-06-16 19:19:49,084 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-06-16 19:19:49,084 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2025-06-16 19:19:49,084 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-06-16 19:19:49,085 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2025-06-16 19:19:49,085 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits'.
# 2025-06-16 19:19:49,085 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2025-06-16 19:19:49,086 - stpipe.Detector1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-06-16 19:19:49,086 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-06-16 19:19:49,087 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-06-16 19:19:49,087 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-06-16 19:19:49,088 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2025-06-16 19:19:49,387 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:49,392 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-06-16 19:19:49,392 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-06-16 19:19:49,393 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-06-16 19:19:49,458 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:49,469 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2025-06-16 19:19:49,655 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-06-16 19:19:49,719 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:49,720 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-06-16 19:19:49,784 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:49,794 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2025-06-16 19:19:49,815 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:49,823 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:49,890 - stpipe.Detector1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-06-16 19:19:50,350 - stpipe.Detector1Pipeline.saturation - INFO - Detected 5666 saturated pixels
# 2025-06-16 19:19:50,379 - stpipe.Detector1Pipeline.saturation - INFO - Detected 94 A/D floor pixels
# 2025-06-16 19:19:50,382 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-06-16 19:19:50,444 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:50,454 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits
# 2025-06-16 19:19:51,136 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2025-06-16 19:19:51,204 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:51,272 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-06-16 19:19:51,341 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:51,408 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-06-16 19:19:51,472 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:51,481 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2025-06-16 19:19:51,558 - stpipe.Detector1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:51,568 - stpipe.Detector1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:51,693 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-06-16 19:19:51,756 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:51,766 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2025-06-16 19:19:51,789 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:51,797 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:19:52,175 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-06-16 19:19:52,238 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:52,248 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits
# 2025-06-16 19:19:52,328 - stpipe.Detector1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-06-16 19:19:52,331 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-06-16 19:19:52,395 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:52,405 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0109.fits
# 2025-06-16 19:19:53,955 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=40, nframes=1, groupgap=0
# 2025-06-16 19:19:53,956 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-06-16 19:19:54,315 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-06-16 19:19:54,388 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 40, 1024, 1032) from jw03722003001_02101_00001_mirifushort_uncal.fits>,).
# 2025-06-16 19:19:54,477 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2025-06-16 19:19:54,477 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2025-06-16 19:19:54,478 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2025-06-16 19:19:54,478 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2025-06-16 19:19:54,479 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2025-06-16 19:19:54,479 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2025-06-16 19:19:54,479 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2025-06-16 19:19:54,480 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2025-06-16 19:19:54,482 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2025-06-16 19:19:54,912 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2025-06-16 19:19:54,984 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# ...
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       apply_flat_field: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: False
#       opt_name: ''
#       suppress_one_group: True
#       firstgroup: None
#       lastgroup: None
#       maximum_cores: half
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-06-16 19:22:14,823 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_04101_00004_mirifushort_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'sirskernel', 'superbias', 'trapdensity', 'trappars']
# 2025-06-16 19:22:14,825 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0109.fits'.
# 2025-06-16 19:22:14,825 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2025-06-16 19:22:14,826 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits'.
# 2025-06-16 19:22:14,826 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits'.
# 2025-06-16 19:22:14,826 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits'.
# 2025-06-16 19:22:14,827 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2025-06-16 19:22:14,827 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits'.
# 2025-06-16 19:22:14,828 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2025-06-16 19:22:14,828 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits'.
# 2025-06-16 19:22:14,829 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits'.
# 2025-06-16 19:22:14,829 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits'.
# 2025-06-16 19:22:14,830 - stpipe.Detector1Pipeline - INFO - Prefetch for SIRSKERNEL reference file is 'N/A'.
# 2025-06-16 19:22:14,830 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2025-06-16 19:22:14,831 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2025-06-16 19:22:14,831 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2025-06-16 19:22:14,832 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# Running Detector1Pipeline on uncal_files/jw03722003001_04101_00004_mirifushort_uncal.fits...
# 2025-06-16 19:22:14,997 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,002 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2025-06-16 19:22:15,003 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2025-06-16 19:22:15,004 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2025-06-16 19:22:15,072 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,081 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mask_0061.fits
# 2025-06-16 19:22:15,173 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2025-06-16 19:22:15,241 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,242 - stpipe.Detector1Pipeline.emicorr - INFO - Step skipped.
# 2025-06-16 19:22:15,308 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,318 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_saturation_0033.fits
# 2025-06-16 19:22:15,338 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:15,348 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:15,371 - stpipe.Detector1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2025-06-16 19:22:15,485 - stpipe.Detector1Pipeline.saturation - INFO - Detected 2120 saturated pixels
# 2025-06-16 19:22:15,492 - stpipe.Detector1Pipeline.saturation - INFO - Detected 28 A/D floor pixels
# 2025-06-16 19:22:15,495 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2025-06-16 19:22:15,561 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,570 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_ipc_0011.fits
# 2025-06-16 19:22:15,717 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2025-06-16 19:22:15,786 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,809 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2025-06-16 19:22:15,874 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,892 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2025-06-16 19:22:15,959 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:15,968 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_reset_0051.fits
# 2025-06-16 19:22:16,056 - stpipe.Detector1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:16,065 - stpipe.Detector1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:16,125 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2025-06-16 19:22:16,193 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:16,203 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_linearity_0030.fits
# 2025-06-16 19:22:16,223 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:16,232 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:22:16,336 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2025-06-16 19:22:16,403 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:16,413 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_rscd_0018.fits
# 2025-06-16 19:22:16,454 - stpipe.Detector1Pipeline.rscd - INFO - Number of groups to skip for integrations 2 and higher: 0
# 2025-06-16 19:22:16,456 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2025-06-16 19:22:16,523 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:16,533 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_dark_0109.fits
# 2025-06-16 19:22:17,264 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=1, ngroups=20, nframes=1, groupgap=0
# 2025-06-16 19:22:17,265 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=85, nframes=1, groupgap=0
# 2025-06-16 19:22:17,506 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2025-06-16 19:22:17,573 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:17,597 - stpipe.Detector1Pipeline.refpix - INFO - MIRI full frame data
# 2025-06-16 19:22:17,598 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2025-06-16 19:22:17,598 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2025-06-16 19:22:17,598 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2025-06-16 19:22:17,599 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = False
# 2025-06-16 19:22:17,599 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = False
# 2025-06-16 19:22:17,599 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = False
# 2025-06-16 19:22:17,600 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = False
# 2025-06-16 19:22:17,601 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2025-06-16 19:22:17,696 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2025-06-16 19:22:17,716 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2025-06-16 19:22:17,782 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:17,783 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2025-06-16 19:22:17,851 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:17,855 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 3.5 sigma
# 2025-06-16 19:22:17,856 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2025-06-16 19:22:17,879 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2025-06-16 19:22:17,884 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2025-06-16 19:22:17,926 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2025-06-16 19:22:17,927 - stpipe.Detector1Pipeline.jump - INFO - Creating 8 processes for jump detection
# 2025-06-16 19:22:18,877 - stpipe.Detector1Pipeline.jump - INFO - Flagging Snowballs
# 2025-06-16 19:22:19,249 - stpipe.Detector1Pipeline.jump - INFO - Total snowballs = 1075
# 2025-06-16 19:22:19,250 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 1.32347 sec
# 2025-06-16 19:22:19,264 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 1.408350
# 2025-06-16 19:22:19,266 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2025-06-16 19:22:19,334 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:19,335 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2025-06-16 19:22:19,399 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(1, 20, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:19,431 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_readnoise_0050.fits
# 2025-06-16 19:22:19,432 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2025-06-16 19:22:19,448 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = OLS_C
# 2025-06-16 19:22:19,449 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2025-06-16 19:22:19,591 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of multiprocessing slices: 8
# 2025-06-16 19:22:19,594 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2025-06-16 19:22:19,594 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2025-06-16 19:22:19,595 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 8
# 2025-06-16 19:22:20,238 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2025-06-16 19:22:20,302 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:20,318 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-06-16 19:22:20,319 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-06-16 19:22:20,320 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-06-16 19:22:20,388 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(1, 1024, 1032) from jw03722003001_04101_00004_mirifushort_uncal.fits>,).
# 2025-06-16 19:22:20,405 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2025-06-16 19:22:20,405 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2025-06-16 19:22:20,406 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2025-06-16 19:22:20,447 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw03722003001_04101_00004_mirifushort_rateints.fits
# 2025-06-16 19:22:20,448 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2025-06-16 19:22:20,448 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:22:20,490 - stpipe.Detector1Pipeline - INFO - Saved model in stage1/jw03722003001_04101_00004_mirifushort_rate.fits
# 2025-06-16 19:22:20,491 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2025-06-16 19:22:20,491 - stpipe - INFO - Results used jwst version: 1.18.1

# %% [markdown]
# ## Refine Bad Pixel Mask

# %% [markdown]
# Now that the Detector1 pipeline has been run, we will try to identify additional bad pixels that are not flagged in the current (Feb. 2023) versions of the bad pixel map reference files. We identify these pixels using the off-source background exposures and then flag them in both the science and background exposures. This stage requires the [miricoord](https://github.com/STScI-MIRI/miricoord/) package. We have to identify the bad pixels for each of the 4 channels separately because the telescope background is much brighter at longer wavelengths (i.e. we can't just cut on some fixed pixel value for all channels). To do that we need to know which pixels map to which channel, which `miricoord` will do for us.
#
# This step was primarily developed by MRS GOAT David Law (STScI).
#
# There are a few things in this stage that are hard-coded that you may want/need to edit yourself:
# - First is the paths to the MRS detector slice mask images, which are from the `miricoord` package. I (JS) have tried to construct the path where they are supposed to be, but this should be double checked - you are looking for the big long `MIRI_FM_...` fits files within miricoord's data directory.
# - More importantly, in the below I hard-coded pixel threshold cutoff values that identify which pixels are bad. This code will make some plots of the distribution of pixel values across the median'd background exposure, which I used to identify which pixel values are 'suspicious' enough to be flagged as bad pixels. For other data you will likely need to do the same. The variables you are looking for have `lowcut` and `hicut` in the names for ctrl+f'ing, there are 3 pairs of these.
#
# Given the above this code could use some refinement with e.g. a sigma-clipping pixel threshold identification. Hopefully the CRDS bad pixel mask calibration files will eventually be updated so this step is no longer needed.

# %%
# Bad pixel mask refinement. Apologies that this code is not the most
# well-organized or prettiest....

if dobadpix:
    # This is a long command that sets... wait for it... dnubit = 1.
    dnubit = dqflags.interpret_bit_flags('DO_NOT_USE',mnemonic_map=datamodels.dqflags.pixel)
    
    # We will start with the LONG detector. Grab the background exposures.
    longrates = sorted(glob.glob(stage1+'jw*04101*mirifulong*rate.fits'))
    nlong = len(longrates)
    
    # Assemble background exposures
    longstack = np.zeros([nlong,1024,1032])
    for i,exposure in enumerate(longrates):
        hdu = fits.open(exposure)
        longstack[i,:,:] = hdu['SCI'].data
        hdu.close()
    
    # Take the median of the exposures, then fix any pixels where the median is nan
    longmedian = np.median(longstack,axis=0)
    fillvalue  = np.nanmedian(longmedian)
    print('Long stack fill value = {0:.3f}'.format(fillvalue))
    
    dqlong = (fits.open(longrates[0]))['DQ'].data
    bad = np.where((dqlong & dnubit) != 0)
    longmedian[bad] = fillvalue
    
    # Now write our median'd background to disk.
    hdu = fits.PrimaryHDU(longmedian)
    hdu.writeto(stage1+'background_median_mirifulong.fits',overwrite=True)
    
    
    # And the SHORT detector
    shortrates = sorted(glob.glob(stage1+'jw*04101*mirifushort*rate.fits'))
    nshort = len(shortrates)
    
    # Assemble background exposures
    shortstack = np.zeros([nshort,1024,1032])
    for i,exposure in enumerate(shortrates):
        hdu = fits.open(exposure)
        shortstack[i,:,:] = hdu['SCI'].data
        hdu.close()
    
    # Take the median of the exposures, then fix any pixels where the median is nan
    shortmedian = np.median(shortstack,axis=0)
    fillvalue  = np.nanmedian(shortmedian)
    print('Short stack fill value = {0:.3f}'.format(fillvalue))
    
    dqshort = (fits.open(shortrates[0]))['DQ'].data
    bad = np.where((dqshort & dnubit) != 0)
    shortmedian[bad] = fillvalue
    
    # Now write our median'd background to disk.
    hdu = fits.PrimaryHDU(shortmedian)
    hdu.writeto(stage1+'background_median_mirifushort.fits',overwrite=True)    
    

    # Now we have to identify the bad pixels based on their percentile value, but
    # since each channel has different pixel distributions (e.g. Ch4 has very low
    # throughput), we need to ID which pixels belong to which channel. This uses
    # the distortion files from the miricoord package.

    # Start again with the long exposures...
    # Note in this folder
    # MIRIFULONG vs MIRIFUSHORT = the two different detectors
    # 12SHORT / 12MEDIUM / 12LONG = channels 1 & 2 for band A=short B=medium C=long
    # 34SHORT / 34MEDIUM / 34LONG = channels 3 & 4 for band A=short B=medium C=long
    # so really having "34" and MIRIFULONG in the names is redundant, but whatever...
    miricoordpath = '/'.join(miricoord.__file__.split('/')[:-2])
    longslicemask  = miricoordpath + '/data/fits/flt3/MIRI_FM_MIRIFULONG_34LONG_DISTORTION_9B.05.07.fits'
    longslicemask  = (fits.open(longslicemask))['SLICE_NUMBER'].data[0,:,:]
    shortslicemask = miricoordpath + '/data/fits/flt3/MIRI_FM_MIRIFUSHORT_12LONG_DISTORTION_9B.05.07.fits'
    shortslicemask = (fits.open(shortslicemask))['SLICE_NUMBER'].data[0,:,:]
    ch1 = (shortslicemask >= 100) & (shortslicemask <= 130)
    ch2 = (shortslicemask >= 200) & (shortslicemask <= 230)
    ch3 = (longslicemask >= 300) & (longslicemask <= 330)
    ch4 = (longslicemask >= 400) & (longslicemask <= 430)
    
    # Get wavelength map for channel 4C. Since throughput falls so rapidly
    # towards the longer Ch4 wavelengths, we will calculate the background median
    # in wavelength chunks. Ch3 is way less affected by this so we just do it in
    # one fell swoop.
    wave4c = mrstools.waveimage('4C')
    
    # Subtract Ch3 average from Ch3 pixels
    ch3pix = np.where(ch3)
    ch3med = np.nanmedian(longmedian[ch3pix])
    longmedian[ch3pix] = longmedian[ch3pix] - ch3med
    print('For Ch3, median value was {0:.3f}'.format(ch3med))
    
    # The background in Ch4 varies strongly with wavelength so we have to subdivide it.
    # Ch4C spans from 23.942 - 28.785 um (unclear why this is different than the 
    #  jdox page on MRS, 23.22 - 28.10 um.....). 
    # Let's split it into ~0.33um spans, subtract a wave-dependent background.
    #mins = [ 1.0, 24.5, 25.0, 25.5, 26.0, 26.5, 27.0, 27.5, 28.0]
    mins = [1.0, 24.33, 24.67, 25.0, 25.33, 25.67, 26.0, 26.33, 26.67, 27.0, 27.33, 27.67, 28.0, 28.33]
    maxs = mins[1:] + [50.0]
    for i,lowave in enumerate(mins):
        hiwave = maxs[i]
        ch4pix = np.where(ch4 & (wave4c > lowave) & (wave4c <= hiwave))
        ch4med = np.nanmedian(longmedian[ch4pix])
        longmedian[ch4pix] = longmedian[ch4pix] - ch4med
        print('For wavelength range {0:.1f} - {1:.1f}um, found {2:.0f} pixels.'.format(lowave,hiwave,ch4pix[0].size))
        print('  Median value was {0:.3f}'.format(ch4med))
    
    # Update the median image with a new fill value, write to disk again...
    bad = np.where((dqlong & dnubit) != 0)
    fillvalue = np.nanmedian(longmedian)
    longmedian[bad] = fillvalue
    print('Long stack re-fill value = {0:.3f}'.format(fillvalue))
    hdu = fits.PrimaryHDU(longmedian)
    hdu.writeto(stage1+'background_median_refill_mirifulong.fits',overwrite=True)    
    
    # Now we start ID'ing pixels to mask, starting with channel 3
    longdqflags = np.zeros_like(dqlong)
    
    good = np.where(ch3 & (longdqflags == 0) & (np.isfinite(longmedian)))
    f = plt.figure()
    ax = f.add_subplot(111)
    ax.plot(longmedian[good],'.',ms=0.5)
    ax.set_ylim(-1,1)
    ax.set_title('Channel 3 pixel values')
    
    # these values were identified 'by hand'; an alternative would be to
    # make some kind of percentile-based or sigma-clipped threshold value
    ch3lowcut, ch3hicut = -0.35, +0.15
    
    ax.axhline(ch3lowcut,color='k',ls='--')
    ax.axhline(ch3hicut, color='k',ls='--')
    plt.show()
    plt.close(f)
    
    tomask = np.where(ch3 & (longmedian < ch3lowcut))
    longdqflags[tomask] = 1
    tomask = np.where(ch3 & (longmedian > ch3hicut))
    longdqflags[tomask] = 1
    
    # Now do the same thing for Ch4
    good = np.where(ch4 & (longdqflags == 0) & (np.isfinite(longmedian)))
    f = plt.figure()
    ax = f.add_subplot(111)
    ax.plot(longmedian[good],'.',ms=0.5)
    ax.set_ylim(-1,1)
    ax.set_title('Channel 4 pixel values')
    
    # again ID'd cutoffs by hand from plot above
    ch4lowcut, ch4hicut = -0.21, +0.23
    
    ax.axhline(ch4lowcut,color='k',ls='--')
    ax.axhline(ch4hicut, color='k',ls='--')
    plt.show()
    plt.close(f)
    
    tomask = np.where(ch4 & (longmedian < ch4lowcut))
    longdqflags[tomask] = 1
    tomask = np.where(ch4 & (longmedian > ch4hicut))
    longdqflags[tomask] = 1
    
    longmedian_clean = longmedian.copy()
    bad = np.where(longdqflags == 1)
    longmedian_clean[bad] = fillvalue
    
    # Save the final 'clean' background to disk for long-wave detector
    hdu = fits.PrimaryHDU(longmedian_clean)
    hdu.writeto(stage1+'background_median_clean_mirifulong.fits',overwrite=True)
    
    # Now apply correction to our bg + sci files.
    longrates = sorted(glob.glob(stage1+'jw*mirifulong_rate.fits'))
    for i,rate in enumerate(longrates):
        hdu = fits.open(rate)
        outfile = rate.replace('rate','ratemod')
        dq = hdu['DQ'].data
        dq[bad] = np.bitwise_or(dq[bad], dnubit)
        hdu['DQ'].data = dq
        hdu.writeto(outfile,overwrite=True)
    


    # Now we repeat the above, but for Ch1 & 2 on the short-wave detector
    # Because the background in Chs 1 & 2 is much lower and more uniform
    # than 3&4, we don't need to process them separately and can just ID
    # one set of bad pixel threshold cuts.
    
    # Subtract Ch1 average from Ch1 pixels
    ch1pix = np.where(ch1)
    ch1med = np.nanmedian(shortmedian[ch1pix])
    shortmedian[ch1pix] = shortmedian[ch1pix] - ch1med
    print('For Ch1, median value was {0:.3f}'.format(ch1med))
    
    # Subtract Ch2 average from Ch2 pixels
    ch2pix = np.where(ch2)
    ch2med = np.nanmedian(shortmedian[ch2pix])
    shortmedian[ch2pix] = shortmedian[ch2pix] - ch2med
    print('For Ch2, median value was {0:.3f}'.format(ch2med))
    
    # Update the median image with a new fill value, write to disk again...
    bad = np.where((dqshort & dnubit) != 0)
    fillvalue = np.nanmedian(shortmedian)
    shortmedian[bad] = fillvalue
    print('Short stack re-fill value = {0:.3f}'.format(fillvalue))
    hdu = fits.PrimaryHDU(shortmedian)
    hdu.writeto(stage1+'background_median_refill_mirifushort.fits',overwrite=True)    
    
    # Now we start ID'ing pixels to mask
    shortdqflags = np.zeros_like(dqshort)
    
    good = np.where((shortdqflags == 0) & (np.isfinite(shortmedian)))
    
    f = plt.figure()
    ax = f.add_subplot(111)
    ax.plot(shortmedian[good],'.',ms=0.5)
    ax.set_ylim(-1,1)
    ax.set_title('Channels 1&2 pixel values')

    lowcut, hicut = -0.08, +0.07
    
    ax.axhline(lowcut,color='k',ls='--')
    ax.axhline(hicut, color='k',ls='--')
    plt.show()
    plt.close(f)
    
    tomask = np.where((shortmedian < lowcut))
    shortdqflags[tomask] = 1
    tomask = np.where((longmedian > hicut))
    shortdqflags[tomask] = 1

    shortmedian_clean = shortmedian.copy()
    bad = np.where(shortdqflags == 1)
    shortmedian_clean[bad] = fillvalue
    
    hdu = fits.PrimaryHDU(shortmedian_clean)
    hdu.writeto(stage1+'background_median_clean_mirifushort.fits',overwrite=True)
    
    # Now apply correction to our bg + sci files.
    shortrates = sorted(glob.glob(stage1+'jw*mirifushort_rate.fits'))
    for i,rate in enumerate(shortrates):
        hdu = fits.open(rate)
        outfile = rate.replace('rate','ratemod')
        dq = hdu['DQ'].data
        dq[bad] = np.bitwise_or(dq[bad], dnubit)
        hdu['DQ'].data = dq
        hdu.writeto(outfile,overwrite=True)

# %% [markdown]
# ## Stage 2 Pipeline Processing

# %% [markdown]
# We will now run the rate files through the Spec2 pipeline - whether the bad pixel masks above were used or not. Like Stage 1, we will define a function where we set all the Spec2 pipeline options. *Unlike* Stage 1, we will perform a pixel-by-pixel 2D background subtraction in this step, which means we need to assemble an "association file" that tells the pipeline which exposures are science and which are background.
#
# The background subtraction step will create a median combination of the 4 background dithered exposures and subtract this from the science exposures. Because it can still be useful to run the background exposures through the Spec2 pipeline alone, we will do that as well, with a slightly different association file setup.
#
# The final 2D combined background will be saved in `stage2/..._combinedbackground.fits` (the pipeline creates one copy of this for each on-source exposure but the contents are the same for each dither position).
#
# Note this treatment of the background subtraction is different than the recommended best practices from shortly after launch but is now the default. Previously, the pipeline would by default create a 'master' 1D background spectrum from the background exposures, but this neglected all residual flatfield and 2D detector-level artifacts.
#
# Both association file writing functions below specify some metadata for our program - observation 017 and program ID 1355 - but I (Justin) don't think this information is essential and doesn't need to be edited for other programs except for aesthetic reasons. You might also get some scare-text about how association files aren't supposed to be used with absolute file paths but this seems to be harmless. Why would anyone /only/ allow relative paths anyway??? Sounds like a recipe for problems to me.

# %%
def writel2asn_sci(scifiles, bgfiles, asnfile, prodname):
    """
    Write a .json association file that specifies a list of
    science and background exposures to be processed by Spec2.
    
    Arguments:
      * scifiles  :  List of on-source rate files to be processed.
      * bgfiles   :  List of background rate files to be processed.
      * asnfile   :  Output .json file path/name
      * prodname  :  Either 'Level2short' or 'Level2long', but this doesn't
                      really matter for much.
    
    Returns:
      * None
      
    Outputs:
      * Writes a .json association file to the location in `asnfile'
    """
    
    asn = afl.asn_from_list(scifiles, rule=DMSLevel2bBase, product_name=prodname)
    asn['asn_type'] = 'spec2'
    asn['asn_id']   = 'o017'
    asn['program']  = '01355'
    
    # Add background files to the association specified as exptype = background
    for bgfile in bgfiles:
        for i in range(len(scifiles)):
            asn['products'][i]['members'].append({'expname':bgfile, 'exptype': 'background'})
    
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)


def writel2asn_bkg(bgfiles, asnfile, prodname):
    """
    Write a .json association file that specifies a list of
    background exposures **ONLY** to be processed by Spec2.
    This can be useful to inspect the _cal.fits images of the
    background exposures to look for remaining artifacts.
    
    Arguments:
      * bgfiles   :  List of background rate files to be processed.
      * asnfile   :  Output .json file path/name
      * prodname  :  Either 'Level2short' or 'Level2long', but this doesn't
                      really matter for much.

    Returns:
      * None
      
    Outputs:
      * Writes a .json association file to the location in `asnfile'
    """
    
    asn = afl.asn_from_list(bgfiles, rule=DMSLevel2bBase, product_name=prodname)
    asn['asn_type'] = 'spec2'
    asn['asn_id']   = 'o017'
    asn['program']  = '01355'
    
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)

# Similar to Stage 1, this function is where we specify how the Spec2 pipeline
# should be run.
def runspec2(asnfile, outdir, nocubes=False):
    """
    Run the Spec2 file using the given association file. The association
    file must contain the information needed - sci and bg exposures - to
    run the pipeline.
    
    Arguments:
      * asnfile   :  Input .json file path/name that specifies the sci+bg exposures
      * outdir    :  Directory for the stage2 output files
      * nocubes   :  By default Spec2 builds a datacube from each exposure,
                      but this is time-consuming and imo not really needed.
                      If nocubes=True, will not build exposures cubes.
    
    Returns:
      * None
      
    Outputs:
      * Writes _cal.fits files for each exposure to `outdir'. Also saves
          median-combined background images to `outdir'. Additionally if
          nocubes=False, writes a 3D data cube built from each exposure
          to `outdir'.
    """
    
    
    # This initial setup is just to make sure that we get the latest parameter reference files
    # pulled in for our files.  This is a temporary workaround to get around an issue with
    # how this pipeline calling method works.
    crds_config = Spec2Pipeline.get_config_from_reference(asnfile)
    spec2 = Spec2Pipeline.from_config_section(crds_config)
    spec2.output_dir = outdir
    
    # Assign_wcs overrides
    #spec2.assign_wcs.override_distortion = 'myfile.asdf'
    #spec2.assign_wcs.override_regions = 'myfile.asdf'
    #spec2.assign_wcs.override_specwcs = 'myfile.asdf'
    #spec2.assign_wcs.override_wavelengthrange = 'myfile.asdf'

    # Flatfield overrides
    #spec2.flat.override_flat = 'myfile.fits'
        
    # Straylight overrides
    #spec2.straylight.override_mrsxartcorr = 'myfile.fits'
        
    # Fringe overrides
    #spec2.fringe.override_fringe = 'myfile.fits'
    
    # Photom overrides
    #spec2.photom.override_photom = 'myfile.fits'

    # Cubepar overrides
    #spec2.cube_build.override_cubepar = 'myfile.fits'
        
    # Extract1D overrides
    #spec2.extract1d.override_extract1d = 'myfile.asdf'
    #spec2.extract1d.override_apcorr = 'myfile.asdf'
        
    # Overrides for whether or not certain steps should be skipped
    # We do NOT want to skip background subtraction (although if this
    # is called on a bkg-only exposure it still gets processed correctly).
    #spec2.assign_wcs.skip = False
    spec2.bkg_subtract.skip = False
    #spec2.flat_field.skip = False
    #spec2.srctype.skip = False
    #spec2.straylight.skip = False
    #spec2.fringe.skip = False
    #spec2.photom.skip = False
    #spec2.cube_build.skip = False
    #spec2.extract_1d.skip = False
    
    # Pipeline now does 2D image background subtraction in stage 2.
    # Save the combined background image it makes (it will save 4 copies
    # of the same background, one for each sci dither exposure...).
    spec2.bkg_subtract.save_combined_background = True
    
    # We can skip cube-building for the individual science frames if desired.
    # Useful in cases where we want don't need the cubes of each science frame.
    if nocubes:
        spec2.cube_build.skip = True
        spec2.extract_1d.skip = True
    
    # By default the ResidualFringeStep is turned off even in the new dev version
    # Cal files don't seem to show much obvious fringing at least in the long detector
    # so I will leave this off.
    # spec2.residual_fringe.skip = False
    
    # Some cube building options
    #spec2.cube_build.weighting='drizzle'
    spec2.cube_build.coord_system='ifualign' # If aligning cubes with IFU axes instead of sky
      
    spec2.save_results = True
    spec2(asnfile)

# %%
# Run through the destriped versions of the rate files.
if dobadpix:
    short_files_on  = sorted(glob.glob(here+'/'+stage1+'jw*02101*mirifushort*ratemod.fits'))
    short_files_sky = sorted(glob.glob(here+'/'+stage1+'jw*04101*mirifushort*ratemod.fits'))
    long_files_on   = sorted(glob.glob(here+'/'+stage1+'jw*02101*mirifulong*ratemod.fits'))
    long_files_sky  = sorted(glob.glob(here+'/'+stage1+'jw*04101*mirifulong*ratemod.fits'))
else:
    short_files_on  = sorted(glob.glob(here+'/'+stage1+'jw*02101*mirifushort*rate.fits'))
    short_files_sky = sorted(glob.glob(here+'/'+stage1+'jw*04101*mirifushort*rate.fits'))
    long_files_on   = sorted(glob.glob(here+'/'+stage1+'jw*02101*mirifulong*rate.fits'))
    long_files_sky  = sorted(glob.glob(here+'/'+stage1+'jw*04101*mirifulong*rate.fits'))


if dospec2:
    asnshort = os.path.join(stage2, 'level2_short_asn.json')
    asnlong  = os.path.join(stage2, 'level2_long_asn.json')
    bkgshort = os.path.join(stage2, 'level2_short_asn_bkg.json')
    bkglong  = os.path.join(stage2, 'level2_long_asn_bkg.json')
    writel2asn_sci(short_files_on, short_files_sky, asnshort, 'Level2short')
    writel2asn_sci(long_files_on,  long_files_sky,  asnlong,  'Level2long')
    writel2asn_bkg(short_files_sky, bkgshort, 'Level2short')
    writel2asn_bkg(long_files_sky,  bkglong,  'Level2long')
    runspec2(asnshort, outdir=stage2, nocubes=True)
    runspec2(asnlong,  outdir=stage2, nocubes=True)
    runspec2(bkgshort, outdir=stage2, nocubes=True)
    runspec2(bkglong,  outdir=stage2, nocubes=True)
# Out:
# 2025-06-16 19:23:45,143 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:23:45,255 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf      965 bytes  (1 / 1 files) (0 / 965 bytes)
# 2025-06-16 19:23:45,588 - stpipe - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2025-06-16 19:23:45,598 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf      987 bytes  (1 / 1 files) (0 / 987 bytes)
# 2025-06-16 19:23:45,874 - stpipe - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2025-06-16 19:23:45,889 - stpipe - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2025-06-16 19:23:45,895 - stpipe - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2025-06-16 19:23:45,903 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec2pipeline_0005.asdf    2.0 K bytes  (1 / 1 files) (0 / 2.0 K bytes)
# 2025-06-16 19:23:46,178 - stpipe - INFO - PARS-SPEC2PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec2pipeline_0005.asdf
# 2025-06-16 19:23:46,195 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2025-06-16 19:23:46,196 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2025-06-16 19:23:46,198 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - BadpixSelfcalStep instance created.
# 2025-06-16 19:23:46,198 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2025-06-16 19:23:46,200 - stpipe.Spec2Pipeline.nsclean - INFO - NSCleanStep instance created.
# 2025-06-16 19:23:46,201 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2025-06-16 19:23:46,202 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2025-06-16 19:23:46,203 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2025-06-16 19:23:46,206 - stpipe.Spec2Pipeline.master_background_mos - INFO - MasterBackgroundMosStep instance created.
# 2025-06-16 19:23:46,207 - stpipe.Spec2Pipeline.master_background_mos.flat_field - INFO - FlatFieldStep instance created.
# 2025-06-16 19:23:46,207 - stpipe.Spec2Pipeline.master_background_mos.pathloss - INFO - PathLossStep instance created.
# 2025-06-16 19:23:46,208 - stpipe.Spec2Pipeline.master_background_mos.barshadow - INFO - BarShadowStep instance created.
# 2025-06-16 19:23:46,209 - stpipe.Spec2Pipeline.master_background_mos.photom - INFO - PhotomStep instance created.
# 2025-06-16 19:23:46,210 - stpipe.Spec2Pipeline.master_background_mos.pixel_replace - INFO - PixelReplaceStep instance created.
# 2025-06-16 19:23:46,211 - stpipe.Spec2Pipeline.master_background_mos.resample_spec - INFO - ResampleSpecStep instance created.
# 2025-06-16 19:23:46,213 - stpipe.Spec2Pipeline.master_background_mos.extract_1d - INFO - Extract1dStep instance created.
# 2025-06-16 19:23:46,214 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2025-06-16 19:23:46,214 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2025-06-16 19:23:46,216 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2025-06-16 19:23:46,217 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2025-06-16 19:23:46,217 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2025-06-16 19:23:46,218 - stpipe.Spec2Pipeline.residual_fringe - INFO - ResidualFringeStep instance created.
# 2025-06-16 19:23:46,219 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2025-06-16 19:23:46,220 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2025-06-16 19:23:46,221 - stpipe.Spec2Pipeline.wfss_contam - INFO - WfssContamStep instance created.
# 2025-06-16 19:23:46,222 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2025-06-16 19:23:46,223 - stpipe.Spec2Pipeline.pixel_replace - INFO - PixelReplaceStep instance created.
# 2025-06-16 19:23:46,224 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2025-06-16 19:23:46,225 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2025-06-16 19:23:46,227 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2025-06-16 19:23:46,227 - stpipe - WARNING - /tmp/ipykernel_1018/2737917643.py:158: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   spec2(asnfile)
#
# 2025-06-16 19:23:46,228 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-06-16 19:23:46,305 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('stage2/level2_short_asn.json',).
# 2025-06-16 19:23:46,322 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: stage2/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   fail_on_exception: True
#   save_wfss_esec: False
#   steps:
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#     badpix_selfcal:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       flagfrac_lower: 0.001
#       flagfrac_upper: 0.001
#       kernel_size: 15
#       force_single: False
#       save_flagged_bkg: False
#     msa_flagging:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     nsclean:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: fft
#       fit_by_channel: False
#       background_method: None
#       background_box_size: None
#       mask_spectral_regions: True
#       n_sigma: 5.0
#       fit_histogram: False
#       single_mask: False
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_combined_background: True
#       sigma: 3.0
#       maxiters: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     imprint_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     extract_2d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       slit_names: None
#       source_ids: None
#       extract_orders: None
#       grism_objects: None
#       tsgrism_extract_height: None
#       wfss_extract_half_height: 5
#       wfss_mmag_extract: None
#       wfss_nbright: 1000
#     master_background_mos:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sigma_clip: 3.0
#       median_kernel: 1
#       force_subtract: False
#       save_background: False
#       user_background: None
#       inverse: False
#       steps:
#         flat_field:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           save_interpolated_flat: False
#           user_supplied_flat: None
#           inverse: False
#         pathloss:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           user_slit_loc: None
#         barshadow:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#         photom:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           inverse: False
#           source_type: None
#           mrs_time_correction: True
#         pixel_replace:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: True
#           output_use_index: True
#           save_results: False
#           skip: True
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           algorithm: fit_profile
#           n_adjacent_cols: 3
#         resample_spec:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           pixfrac: 1.0
#           kernel: square
#           fillval: NAN
#           weight_type: exptime
#           output_shape: None
#           pixel_scale_ratio: 1.0
#           pixel_scale: None
#           output_wcs: ''
#           single: False
#           blendheaders: True
#           in_memory: True
#         extract_1d:
#           pre_hooks: []
#           post_hooks: []
#           output_file: None
#           output_dir: None
#           output_ext: .fits
#           output_use_model: False
#           output_use_index: True
#           save_results: False
#           skip: False
#           suffix: None
#           search_output_file: True
#           input_dir: ''
#           subtract_background: None
#           apply_apcorr: True
#           extraction_type: box
#           use_source_posn: None
#           position_offset: 0.0
#           model_nod_pair: True
#           optimize_psf_location: True
#           smoothing_length: None
#           bkg_fit: None
#           bkg_order: None
#           log_increment: 50
#           save_profile: False
#           save_scene_model: False
#           save_residual_image: False
#           center_xy: None
#           ifu_autocen: True
#           bkg_sigma_clip: 3.0
#           ifu_rfcorr: True
#           ifu_set_srctype: None
#           ifu_rscale: None
#           ifu_covar_scale: 1.8
#           soss_atoca: True
#           soss_threshold: 0.01
#           soss_n_os: 2
#           soss_wave_grid_in: None
#           soss_wave_grid_out: None
#           soss_estimate: None
#           soss_rtol: 0.0001
#           soss_max_grid_size: 20000
#           soss_tikfac: None
#           soss_width: 40.0
#           soss_bad_pix: masking
#           soss_modelname: None
#     wavecorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     srctype:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       source_type: None
#     straylight:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       clean_showers: False
#       shower_plane: 3
#       shower_x_stddev: 18.0
#       shower_y_stddev: 5.0
#       shower_low_reject: 0.1
#       shower_high_reject: 99.9
#     fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     residual_fringe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: residual_fringe
#       search_output_file: False
#       input_dir: ''
#       save_intermediate_results: False
#       ignore_region_min: None
#       ignore_region_max: None
#     pathloss:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       user_slit_loc: None
#     barshadow:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#     wfss_contam:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_simulated_image: False
#       save_contam_images: False
#       maximum_cores: none
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     pixel_replace:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: fit_profile
#       n_adjacent_cols: 3
#     resample_spec:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#     cube_build:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: s3d
#       search_output_file: False
#       input_dir: ''
#       channel: all
#       band: all
#       grating: all
#       filter: all
#       output_type: None
#       scalexy: 0.0
#       scalew: 0.0
#       weighting: drizzle
#       coord_system: ifualign
#       ra_center: None
#       dec_center: None
#       cube_pa: None
#       nspax_x: None
#       nspax_y: None
#       rois: 0.0
#       roiw: 0.0
#       weight_power: 2.0
#       wavemin: None
#       wavemax: None
#       single: False
#       skip_dqflagging: False
#       offset_file: None
#       debug_spaxel: -1 -1 -1
#     extract_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       subtract_background: None
#       apply_apcorr: True
#       extraction_type: box
#       use_source_posn: None
#       position_offset: 0.0
#       model_nod_pair: True
#       optimize_psf_location: True
#       smoothing_length: None
#       bkg_fit: None
#       bkg_order: None
#       log_increment: 50
#       save_profile: False
#       save_scene_model: False
#       save_residual_image: False
#       center_xy: None
#       ifu_autocen: True
#       bkg_sigma_clip: 3.0
#       ifu_rfcorr: True
#       ifu_set_srctype: None
#       ifu_rscale: None
#       ifu_covar_scale: 1.8
#       soss_atoca: True
#       soss_threshold: 0.01
#       soss_n_os: 2
#       soss_wave_grid_in: None
#       soss_wave_grid_out: None
#       soss_estimate: None
#       soss_rtol: 0.0001
#       soss_max_grid_size: 20000
#       soss_tikfac: None
#       soss_width: 40.0
#       soss_bad_pix: masking
#       soss_modelname: None
# 2025-06-16 19:23:46,329 - stpipe.Spec2Pipeline - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:23:46,359 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifushort_rate.fits' reftypes = ['area', 'barshadow', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'mrsxartcorr', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2025-06-16 19:23:46,365 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0136.asdf  165.2 K bytes  (1 / 8 files) (0 / 106.4 M bytes)
# 2025-06-16 19:23:46,910 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0819.fits   21.2 M bytes  (2 / 8 files) (165.2 K / 106.4 M bytes)
# 2025-06-16 19:23:48,661 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0071.fits   12.7 M bytes  (3 / 8 files) (21.3 M / 106.4 M bytes)
# 2025-06-16 19:23:50,265 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits  383.0 K bytes  (4 / 8 files) (34.0 M / 106.4 M bytes)
# 2025-06-16 19:23:50,827 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0212.fits   33.9 M bytes  (5 / 8 files) (34.4 M / 106.4 M bytes)
# 2025-06-16 19:23:53,109 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0139.asdf   38.0 M bytes  (6 / 8 files) (68.3 M / 106.4 M bytes)
# 2025-06-16 19:23:55,343 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0117.asdf   52.5 K bytes  (7 / 8 files) (106.3 M / 106.4 M bytes)
# 2025-06-16 19:23:55,736 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0010.asdf    2.6 K bytes  (8 / 8 files) (106.4 M / 106.4 M bytes)
# 2025-06-16 19:23:55,985 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2025-06-16 19:23:55,985 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2025-06-16 19:23:55,986 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2025-06-16 19:23:55,986 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2025-06-16 19:23:55,986 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2025-06-16 19:23:55,986 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2025-06-16 19:23:55,987 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0136.asdf'.
# 2025-06-16 19:23:55,988 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2025-06-16 19:23:55,988 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2025-06-16 19:23:55,989 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0819.fits'.
# 2025-06-16 19:23:55,989 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2025-06-16 19:23:55,990 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2025-06-16 19:23:55,990 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0071.fits'.
# 2025-06-16 19:23:55,991 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2025-06-16 19:23:55,991 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2025-06-16 19:23:55,992 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2025-06-16 19:23:55,992 - stpipe.Spec2Pipeline - INFO - Prefetch for MRSXARTCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits'.
# 2025-06-16 19:23:55,993 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2025-06-16 19:23:55,993 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2025-06-16 19:23:55,993 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2025-06-16 19:23:55,994 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2025-06-16 19:23:55,994 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0212.fits'.
# 2025-06-16 19:23:55,995 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0139.asdf'.
# 2025-06-16 19:23:55,995 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2025-06-16 19:23:55,996 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0117.asdf'.
# 2025-06-16 19:23:55,996 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2025-06-16 19:23:55,996 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0010.asdf'.
# 2025-06-16 19:23:55,997 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2025-06-16 19:23:55,998 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2025-06-16 19:23:56,005 - stpipe.Spec2Pipeline - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:23:56,006 - stpipe.Spec2Pipeline - INFO - Processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_02101_00001_mirifushort
# 2025-06-16 19:23:56,006 - stpipe.Spec2Pipeline - INFO - Working on input /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_02101_00001_mirifushort_rate.fits ...
# 2025-06-16 19:23:56,095 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:23:56,624 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999201347899301
# 2025-06-16 19:23:57,420 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0136.asdf', 'filteroffset': None, 'specwcs': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0117.asdf', 'regions': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0139.asdf', 'wavelengthrange': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0010.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-06-16 19:23:58,086 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  171.809850312 42.472364876 171.812125058 42.472364876 171.812125058 42.474034979 171.809850312 42.474034979
# 2025-06-16 19:23:58,087 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-06-16 19:23:58,090 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-06-16 19:23:58,185 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step badpix_selfcal running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>, [], ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits']).
# 2025-06-16 19:23:58,187 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step skipped.
# 2025-06-16 19:23:58,269 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:23:58,270 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2025-06-16 19:23:58,351 - stpipe.Spec2Pipeline.nsclean - INFO - Step nsclean running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:23:58,352 - stpipe.Spec2Pipeline.nsclean - INFO - Step skipped.
# 2025-06-16 19:23:58,435 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>, []).
# 2025-06-16 19:23:58,436 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:23:58,519 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', []).
# 2025-06-16 19:23:58,520 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:23:58,606 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', []).
# 2025-06-16 19:23:58,606 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:23:58,690 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', []).
# 2025-06-16 19:23:58,690 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:23:58,774 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits', []).
# 2025-06-16 19:23:58,775 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:23:58,854 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits']).
# 2025-06-16 19:23:58,870 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits
# 2025-06-16 19:23:58,918 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits
# 2025-06-16 19:23:58,963 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits
# 2025-06-16 19:23:58,997 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits
# 2025-06-16 19:23:59,031 - stpipe.Spec2Pipeline.bkg_subtract - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/stats/sigma_clipping.py:326: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn(
#
# 2025-06-16 19:23:59,156 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Subtracting avg bkg from jw03722003001_02101_00001_mirifushort_rate.fits
# 2025-06-16 19:23:59,584 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Saved model in stage2/jw03722003001_02101_00001_mirifushort_combinedbackground.fits
# 2025-06-16 19:23:59,584 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Combined background written to "stage2/jw03722003001_02101_00001_mirifushort_combinedbackground.fits".
# 2025-06-16 19:23:59,586 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2025-06-16 19:23:59,696 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:23:59,701 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2025-06-16 19:23:59,702 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2025-06-16 19:23:59,702 - stpipe.Spec2Pipeline.srctype - INFO - Using input source type = EXTENDED
# 2025-06-16 19:23:59,703 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2025-06-16 19:23:59,807 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:00,131 - stpipe.Spec2Pipeline.straylight - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2025-06-16 19:24:00,190 - stpipe.Spec2Pipeline.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# 2025-06-16 19:24:13,199 - stpipe.Spec2Pipeline.straylight - INFO - Found parameters for right detector half, applying Cross-Artifact correction.
# 2025-06-16 19:24:28,933 - stpipe.Spec2Pipeline.straylight - INFO - Derived pedestal correction -0.0014878083163720824 DN/s
# 2025-06-16 19:24:28,933 - stpipe.Spec2Pipeline.straylight - INFO - Cross-artifact model complete.
# 2025-06-16 19:24:28,935 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2025-06-16 19:24:29,051 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:29,103 - stpipe.Spec2Pipeline.flat_field - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0819.fits
# 2025-06-16 19:24:29,103 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-06-16 19:24:29,104 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-06-16 19:24:29,104 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-06-16 19:24:29,429 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2025-06-16 19:24:29,564 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:29,576 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0071.fits
# 2025-06-16 19:24:29,594 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:24:29,595 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:24:29,595 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:24:29,891 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2025-06-16 19:24:29,892 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2025-06-16 19:24:30,032 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:30,033 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2025-06-16 19:24:30,155 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:30,156 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2025-06-16 19:24:30,275 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:30,292 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0212.fits
# 2025-06-16 19:24:30,292 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2025-06-16 19:24:30,579 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2025-06-16 19:24:30,580 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2025-06-16 19:24:30,580 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2025-06-16 19:24:30,581 - stpipe.Spec2Pipeline.photom - INFO -  band: LONG
# 2025-06-16 19:24:30,630 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:24:30,631 - stpipe.Spec2Pipeline.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2025-06-16 19:24:30,631 - stpipe.Spec2Pipeline.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2025-06-16 19:24:30,640 - stpipe.Spec2Pipeline.photom - INFO - Applying MRS IFU time dependent correction.
# 2025-06-16 19:24:31,075 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2025-06-16 19:24:31,228 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00001_mirifushort_rate.fits>,).
# 2025-06-16 19:24:31,229 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2025-06-16 19:24:31,671 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_02101_00001_mirifushort_cal.fits>,).
# 2025-06-16 19:24:31,672 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step skipped.
# 2025-06-16 19:24:31,788 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_02101_00001_mirifushort_cal.fits>,).
# 2025-06-16 19:24:31,789 - stpipe.Spec2Pipeline.cube_build - INFO - Step skipped.
# 2025-06-16 19:24:32,235 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_02101_00001_mirifushort_cal.fits>,).
# 2025-06-16 19:24:32,236 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2025-06-16 19:24:32,237 - stpipe.Spec2Pipeline - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_02101_00001_mirifushort
# 2025-06-16 19:24:32,238 - stpipe.Spec2Pipeline - INFO - Processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_02101_00002_mirifushort
# 2025-06-16 19:24:32,239 - stpipe.Spec2Pipeline - INFO - Working on input /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_02101_00002_mirifushort_rate.fits ...
# 2025-06-16 19:24:32,497 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>,).
# 2025-06-16 19:24:33,051 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999201304209384
# 2025-06-16 19:24:33,805 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0136.asdf', 'filteroffset': None, 'specwcs': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0117.asdf', 'regions': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0139.asdf', 'wavelengthrange': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0010.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-06-16 19:24:34,421 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  171.809848243 42.472474278 171.812122994 42.472474278 171.812122994 42.474144380 171.809848243 42.474144380
# 2025-06-16 19:24:34,425 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-06-16 19:24:34,430 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-06-16 19:24:34,595 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step badpix_selfcal running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>, [], ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits']).
# 2025-06-16 19:24:34,596 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step skipped.
# 2025-06-16 19:24:34,709 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>,).
# 2025-06-16 19:24:34,710 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2025-06-16 19:24:34,824 - stpipe.Spec2Pipeline.nsclean - INFO - Step nsclean running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>,).
# 2025-06-16 19:24:34,825 - stpipe.Spec2Pipeline.nsclean - INFO - Step skipped.
# 2025-06-16 19:24:34,940 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>, []).
# 2025-06-16 19:24:34,940 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:24:35,055 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', []).
# 2025-06-16 19:24:35,056 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:24:35,168 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', []).
# 2025-06-16 19:24:35,169 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:24:35,283 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', []).
# 2025-06-16 19:24:35,284 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:24:35,391 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits', []).
# 2025-06-16 19:24:35,392 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:24:35,512 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>, ['/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits', '/home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits']).
# 2025-06-16 19:24:35,539 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00001_mirifushort_rate.fits
# 2025-06-16 19:24:35,574 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00002_mirifushort_rate.fits
# 2025-06-16 19:24:35,610 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifushort_rate.fits
# 2025-06-16 19:24:35,643 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifushort_rate.fits
# 2025-06-16 19:24:35,680 - stpipe.Spec2Pipeline.bkg_subtract - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/stats/sigma_clipping.py:326: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn(
#
# 2025-06-16 19:24:35,798 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Subtracting avg bkg from jw03722003001_02101_00002_mirifushort_rate.fits
# 2025-06-16 19:24:36,147 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Saved model in stage2/jw03722003001_02101_00002_mirifushort_combinedbackground.fits
# 2025-06-16 19:24:36,148 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Combined background written to "stage2/jw03722003001_02101_00002_mirifushort_combinedbackground.fits".
# 2025-06-16 19:24:36,149 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2025-06-16 19:24:36,301 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>,).
# 2025-06-16 19:24:36,305 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2025-06-16 19:24:36,306 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2025-06-16 19:24:36,307 - stpipe.Spec2Pipeline.srctype - INFO - Using input source type = EXTENDED
# 2025-06-16 19:24:36,308 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2025-06-16 19:24:36,449 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722003001_02101_00002_mirifushort_rate.fits>,).
# 2025-06-16 19:24:36,806 - stpipe.Spec2Pipeline.straylight - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2025-06-16 19:24:36,865 - stpipe.Spec2Pipeline.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# ...
# 2025-06-16 19:33:37,291 - stpipe.Spec2Pipeline.straylight - INFO - Derived pedestal correction -0.040875041857361794 DN/s
# 2025-06-16 19:33:37,292 - stpipe.Spec2Pipeline.straylight - INFO - Cross-artifact model complete.
# 2025-06-16 19:33:37,294 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2025-06-16 19:33:37,458 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:37,505 - stpipe.Spec2Pipeline.flat_field - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0823.fits
# 2025-06-16 19:33:37,506 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-06-16 19:33:37,506 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-06-16 19:33:37,507 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-06-16 19:33:37,768 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2025-06-16 19:33:37,961 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:37,971 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0075.fits
# 2025-06-16 19:33:37,988 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:33:37,989 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:33:37,990 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:33:38,227 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2025-06-16 19:33:38,230 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2025-06-16 19:33:38,422 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:38,423 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2025-06-16 19:33:38,584 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:38,585 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2025-06-16 19:33:38,748 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:38,762 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0213.fits
# 2025-06-16 19:33:38,763 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2025-06-16 19:33:38,998 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2025-06-16 19:33:38,998 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFULONG
# 2025-06-16 19:33:38,999 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2025-06-16 19:33:38,999 - stpipe.Spec2Pipeline.photom - INFO -  band: MEDIUM
# 2025-06-16 19:33:39,034 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:33:39,035 - stpipe.Spec2Pipeline.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2025-06-16 19:33:39,036 - stpipe.Spec2Pipeline.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2025-06-16 19:33:39,044 - stpipe.Spec2Pipeline.photom - INFO - Applying MRS IFU time dependent correction.
# 2025-06-16 19:33:39,478 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2025-06-16 19:33:39,673 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00003_mirifulong_rate.fits>,).
# 2025-06-16 19:33:39,674 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2025-06-16 19:33:40,096 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00003_mirifulong_cal.fits>,).
# 2025-06-16 19:33:40,097 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step skipped.
# 2025-06-16 19:33:40,277 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00003_mirifulong_cal.fits>,).
# 2025-06-16 19:33:40,278 - stpipe.Spec2Pipeline.cube_build - INFO - Step skipped.
# 2025-06-16 19:33:40,722 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00003_mirifulong_cal.fits>,).
# 2025-06-16 19:33:40,722 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2025-06-16 19:33:40,723 - stpipe.Spec2Pipeline - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00003_mirifulong
# 2025-06-16 19:33:40,724 - stpipe.Spec2Pipeline - INFO - Processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifulong
# 2025-06-16 19:33:40,725 - stpipe.Spec2Pipeline - INFO - Working on input /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifulong_rate.fits ...
# 2025-06-16 19:33:41,052 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:33:41,409 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999201134452382
# 2025-06-16 19:33:42,072 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_distortion_0139.asdf', 'filteroffset': None, 'specwcs': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_specwcs_0135.asdf', 'regions': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_regions_0140.asdf', 'wavelengthrange': '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0010.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2025-06-16 19:33:42,583 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  171.808959181 42.471747644 171.812714349 42.471747644 171.812714349 42.474590256 171.808959181 42.474590256
# 2025-06-16 19:33:42,589 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2025-06-16 19:33:42,595 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2025-06-16 19:33:42,799 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step badpix_selfcal running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>, [], []).
# 2025-06-16 19:33:42,800 - stpipe.Spec2Pipeline.badpix_selfcal - INFO - Step skipped.
# 2025-06-16 19:33:42,957 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:33:42,958 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2025-06-16 19:33:43,115 - stpipe.Spec2Pipeline.nsclean - INFO - Step nsclean running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:33:43,116 - stpipe.Spec2Pipeline.nsclean - INFO - Step skipped.
# 2025-06-16 19:33:43,278 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>, []).
# 2025-06-16 19:33:43,279 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2025-06-16 19:33:43,437 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>, []).
# 2025-06-16 19:33:43,438 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2025-06-16 19:33:43,596 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:33:43,600 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2025-06-16 19:33:43,601 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = EXTENDED
# 2025-06-16 19:33:43,601 - stpipe.Spec2Pipeline.srctype - INFO - Using input source type = EXTENDED
# 2025-06-16 19:33:43,603 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2025-06-16 19:33:43,769 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:33:44,008 - stpipe.Spec2Pipeline.straylight - INFO - Using mrsxartcorr reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsxartcorr_0001.fits
# 2025-06-16 19:33:44,063 - stpipe.Spec2Pipeline.straylight - INFO - Found parameters for left detector half, applying Cross-Artifact correction.
# 2025-06-16 19:33:57,482 - stpipe.Spec2Pipeline.straylight - INFO - Found parameters for right detector half, applying Cross-Artifact correction.
# 2025-06-16 19:34:12,947 - stpipe.Spec2Pipeline.straylight - INFO - Derived pedestal correction -0.05956726521253586 DN/s
# 2025-06-16 19:34:12,947 - stpipe.Spec2Pipeline.straylight - INFO - Cross-artifact model complete.
# 2025-06-16 19:34:12,950 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2025-06-16 19:34:13,142 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:13,188 - stpipe.Spec2Pipeline.flat_field - INFO - Using FLAT reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_flat_0823.fits
# 2025-06-16 19:34:13,189 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type FFLAT
# 2025-06-16 19:34:13,189 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type SFLAT
# 2025-06-16 19:34:13,189 - stpipe.Spec2Pipeline.flat_field - INFO - No reference found for type DFLAT
# 2025-06-16 19:34:13,449 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2025-06-16 19:34:13,665 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:13,675 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_fringe_0075.fits
# 2025-06-16 19:34:13,692 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:34:13,692 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:34:13,693 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:34:13,936 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2025-06-16 19:34:13,938 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2025-06-16 19:34:14,149 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:14,150 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2025-06-16 19:34:14,330 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:14,331 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2025-06-16 19:34:14,515 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:14,529 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0213.fits
# 2025-06-16 19:34:14,529 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2025-06-16 19:34:14,756 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2025-06-16 19:34:14,757 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFULONG
# 2025-06-16 19:34:14,757 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2025-06-16 19:34:14,758 - stpipe.Spec2Pipeline.photom - INFO -  band: MEDIUM
# 2025-06-16 19:34:14,793 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2025-06-16 19:34:14,794 - stpipe.Spec2Pipeline.photom - INFO - Attempting to obtain PIXAR_SR and PIXAR_A2 values from PHOTOM reference file.
# 2025-06-16 19:34:14,795 - stpipe.Spec2Pipeline.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from PHOTOM reference file.
# 2025-06-16 19:34:14,802 - stpipe.Spec2Pipeline.photom - INFO - Applying MRS IFU time dependent correction.
# 2025-06-16 19:34:15,209 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2025-06-16 19:34:15,433 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<IFUImageModel(1024, 1032) from jw03722003001_04101_00004_mirifulong_rate.fits>,).
# 2025-06-16 19:34:15,434 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2025-06-16 19:34:15,869 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00004_mirifulong_cal.fits>,).
# 2025-06-16 19:34:15,870 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step skipped.
# 2025-06-16 19:34:16,073 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00004_mirifulong_cal.fits>,).
# 2025-06-16 19:34:16,074 - stpipe.Spec2Pipeline.cube_build - INFO - Step skipped.
# 2025-06-16 19:34:16,527 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<IFUImageModel(1024, 1032) from stage2/jw03722003001_04101_00004_mirifulong_cal.fits>,).
# 2025-06-16 19:34:16,528 - stpipe.Spec2Pipeline.extract_1d - INFO - Step skipped.
# 2025-06-16 19:34:16,529 - stpipe.Spec2Pipeline - INFO - Finished processing product /home/fatih/G165_main/G165_miri_bg_subtraction/miri_notebook/stage1/jw03722003001_04101_00004_mirifulong
# 2025-06-16 19:34:16,530 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2025-06-16 19:34:16,531 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:34:16,534 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:34:16,537 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:34:16,539 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1364.pmap
# 2025-06-16 19:34:16,795 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw03722003001_04101_00001_mirifulong_cal.fits
# 2025-06-16 19:34:17,054 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw03722003001_04101_00002_mirifulong_cal.fits
# 2025-06-16 19:34:17,316 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw03722003001_04101_00003_mirifulong_cal.fits
# 2025-06-16 19:34:17,594 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw03722003001_04101_00004_mirifulong_cal.fits
# 2025-06-16 19:34:17,594 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2025-06-16 19:34:17,595 - stpipe - INFO - Results used jwst version: 1.18.1

# %% [markdown]
# ## Stage 3 Pipeline Processing

# %% [markdown]
# Now we will assemble the calibrated 2D images into 3D data cubes. By default here I output one cube per channel, so we will have 4 cubes in total. Like before, we write an association file to tell the pipeline which exposures are science vs. background, and then a function that specifies how the Spec3 pipeline should run.
#
# One can optionally do 1D master background subtraction here in Stage 3, if 2D pixel-by-pixel background subtraction was skipped above. The functions here are defined for that to be possible, but by default the pipeline will not "double-subtract" the background if 2D subtraction was already done.

# %%
def writel3asn(scifiles, bgfiles, asnfile, prodname='Level3'):
    """
    Write a .json association file that specifies a list of
    science and background exposures to be processed by Spec3.
    
    Arguments:
      * scifiles  :  List of on-source cal files to be processed.
      * bgfiles   :  List of background cal files to be processed.
      * asnfile   :  Output .json file path/name
      * prodname  :  AFAIK should just be 'Level3' always but prob
                      doesn't actually affect anything but metadata.
    
    Returns:
      * None
      
    Outputs:
      * Writes a .json association file to the location in `asnfile'    
    """
    
    # Define the basic association of science files
    asn = afl.asn_from_list(scifiles, rule=DMS_Level3_Base, product_name=prodname)
    asn['asn_type'] = 'spec3'
    asn['asn_id']   = 'o017'
    asn['program']  = '01355'
        
    # Add background files to the association
    for bgfile in bgfiles:
        asn['products'][0]['members'].append({'expname':bgfile, 'exptype': 'background'})
        
    # Write the association to a json file
    _, serialized = asn.dump()
    with open(asnfile, 'w') as outfile:
        outfile.write(serialized)


def runspec3(asnfile, outdir):
    """
    Run the Spec3 pipeline using the given association file. The association
    file must contain the information needed - sci and bg cal files - to
    run the pipeline.
    
    Arguments:
      * asnfile   :  Input .json file path/name that specifies the sci+bg exposures
      * outdir    :  Directory for the stage2 output files
    
    Returns:
      * None
      
    Outputs:
      * Writes _cal.fits files for each exposure to `outdir'. Also saves
          median-combined background images to `outdir'. Additionally if
          nocubes=False, writes a 3D data cube built from each exposure
          to `outdir'.
    """    
    
    
    
    # This initial setup is just to make sure that we get the latest parameter reference files
    # pulled in for our files.  This is a temporary workaround to get around an issue with
    # how this pipeline calling method works.
    crds_config = Spec3Pipeline.get_config_from_reference(asnfile)
    spec3 = Spec3Pipeline.from_config_section(crds_config)
    
    spec3.output_dir = stage3
    #spec3.save_results = True
    
    # Overrides for whether or not certain steps should be skipped
    #spec3.assign_mtwcs.skip = False
    #spec3.master_background.skip = True
    #spec3.outlier_detection.skip = True
    spec3.mrs_imatch.skip = False
    #spec3.cube_build.skip = False
    #spec3.extract_1d.skip = False
    
    # Grow out from outlying pixels (default was 1)
    spec3.outlier_detection.grow = 3
    
    # Cube building configuration options
    # The following was the set of parameters used to build the cubes
    #  used for Spilker et al. (2023). They were default at the time
    #  but the defaults have since been updated.
    # spec3.cube_build.channel = '3'    # Only build the Ch3 cube
    # spec3.cube_build.band    = 'long' # Only build from the long detector (seems redundant w/ Ch3)
    # spec3.cube_build.scale2  = 0.003  # Create cube with 0.003um wavelength channels (old default)
    # spec3.cube_build.output_file = 'bandcube' # Custom output name
    # spec3.cube_build.output_type = 'band' # 'band', 'channel', or 'multi' type cube output
    # spec3.cube_build.weighting = 'drizzle' # 'emsm' or 'drizzle'
    
    # Instead of building a cube with N=up, this will build it aligned
    # with the actual along/across slice directions on the detector.
    # Needs to be this way in order for subsequent de-striping to work.
    spec3.cube_build.coord_system = 'ifualign' # 'ifualign', 'skyalign', or 'internal_cal'

    # Extract1D overrides
    #spec3.extract1d.override_extract1d = 'myfile.asdf'
    #spec3.extract1d.override_apcorr = 'myfile.asdf'

    spec3(asnfile)

# %%
# Grab our lists of sci & background exposures.
# Note that since we did 2D bkg subtraction earlier we don't actually
# need these 1D backgrounds (they will be skipped by the Spec3 pipeline),
# but if you modified Spec2 above to *not* do 2D subtraction, this would
# be how you would use them for a 1D master background subtraction here.
scifiles = sorted(glob.glob(here+'/'+stage2+'jw*02101*cal.fits'))
bgfiles  = sorted(glob.glob(here+'/'+stage2+'jw*04101*x1d.fits'))

# Make an association file that includes all of the different exposures
asnfile=os.path.join(stage3, 'level3_asn.json')
if dospec3:
    writel3asn(scifiles, bgfiles, asnfile, 'Level3')
    runspec3(asnfile, outdir=stage3)
# Out:
# 2025-06-16 19:53:52,806 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:53:54,643 - CRDS - INFO -  Calibration SW Found: jwst 1.18.1 (/home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst-1.18.1.dist-info)
# 2025-06-16 19:53:55,210 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0052.asdf    1.2 K bytes  (1 / 1 files) (0 / 1.2 K bytes)
# 2025-06-16 19:53:55,478 - stpipe - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0052.asdf
# 2025-06-16 19:53:55,503 - stpipe - INFO - PARS-RESAMPLESPECSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-resamplespecstep_0001.asdf
# 2025-06-16 19:53:55,513 - stpipe - INFO - PARS-EXTRACT1DSTEP parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-extract1dstep_0001.asdf
# 2025-06-16 19:53:55,526 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec3pipeline_0008.asdf    2.7 K bytes  (1 / 1 files) (0 / 2.7 K bytes)
# 2025-06-16 19:53:55,791 - stpipe - INFO - PARS-SPEC3PIPELINE parameters found: /home/fatih/crds_cache/references/jwst/miri/jwst_miri_pars-spec3pipeline_0008.asdf
# 2025-06-16 19:53:55,881 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2025-06-16 19:53:55,881 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2025-06-16 19:53:55,882 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2025-06-16 19:53:55,884 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2025-06-16 19:53:55,885 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2025-06-16 19:53:55,886 - stpipe.Spec3Pipeline.pixel_replace - INFO - PixelReplaceStep instance created.
# 2025-06-16 19:53:55,887 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2025-06-16 19:53:55,888 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2025-06-16 19:53:55,890 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2025-06-16 19:53:55,891 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2025-06-16 19:53:55,892 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2025-06-16 19:53:55,893 - stpipe.Spec3Pipeline.spectral_leak - INFO - SpectralLeakStep instance created.
# 2025-06-16 19:53:55,893 - stpipe - WARNING - /tmp/ipykernel_980/2229314268.py:98: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended. See https://jwst-pipeline.readthedocs.io/en/latest/jwst/user_documentation/running_pipeline_python.html#advanced-use-pipeline-run-vs-pipeline-call for more details.
#   spec3(asnfile)
#
# 2025-06-16 19:53:55,894 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/stpipe/step.py:580: UserWarning: Step.__call__ is deprecated. It is equivalent to Step.run and is not recommended.
#   warnings.warn(
#
# 2025-06-16 19:53:55,979 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('stage3/level3_asn.json',).
# 2025-06-16 19:53:55,988 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: stage3/
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     master_background:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       median_kernel: 1
#       user_background: None
#       save_background: False
#       force_subtract: False
#     mrs_imatch:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_degree: 1
#       subtract: False
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: ivm
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 5.0 4.0
#       scale: 1.2 0.7
#       backg: 0.0
#       kernel_size: 11 1
#       threshold_percent: 99.5
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE
#       in_memory: True
#     pixel_replace:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: mingrad
#       n_adjacent_cols: 3
#     resample_spec:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#     cube_build:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: s3d
#       search_output_file: False
#       input_dir: ''
#       channel: all
#       band: all
#       grating: all
#       filter: all
#       output_type: band
#       scalexy: 0.0
#       scalew: 0.0
#       weighting: drizzle
#       coord_system: ifualign
#       ra_center: None
#       dec_center: None
#       cube_pa: None
#       nspax_x: None
#       nspax_y: None
#       rois: 0.0
#       roiw: 0.0
#       weight_power: 2.0
#       wavemin: None
#       wavemax: None
#       single: False
#       skip_dqflagging: False
#       offset_file: None
#       debug_spaxel: -1 -1 -1
#     extract_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       subtract_background: None
#       apply_apcorr: True
#       extraction_type: box
#       use_source_posn: None
#       position_offset: 0.0
#       model_nod_pair: True
#       optimize_psf_location: True
#       smoothing_length: None
#       bkg_fit: None
#       bkg_order: None
#       log_increment: 50
#       save_profile: False
#       save_scene_model: False
#       save_residual_image: False
#       center_xy: None
#       ifu_autocen: True
#       bkg_sigma_clip: 3.0
#       ifu_rfcorr: True
#       ifu_set_srctype: None
#       ifu_rscale: None
#       ifu_covar_scale: 1.8
#       soss_atoca: True
#       soss_threshold: 0.01
#       soss_n_os: 2
#       soss_wave_grid_in: None
#       soss_wave_grid_out: None
#       soss_estimate: None
#       soss_rtol: 0.0001
#       soss_max_grid_size: 20000
#       soss_tikfac: None
#       soss_width: 40.0
#       soss_bad_pix: masking
#       soss_modelname: None
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       mrs_time_correction: True
#     combine_1d:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       exptime_key: exposure_time
#       sigma_clip: None
#     spectral_leak:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2025-06-16 19:53:55,994 - stpipe.Spec3Pipeline - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:53:56,559 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw03722003001_02101_00001_mirifulong_cal.fits' reftypes = ['apcorr', 'area', 'cubepar', 'extract1d', 'mrsptcorr', 'pastasoss', 'photom', 'psf', 'speckernel', 'specprofile']
# 2025-06-16 19:53:56,563 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf  810.3 K bytes  (1 / 4 files) (0 / 1.7 M bytes)
# 2025-06-16 19:53:57,214 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits  555.8 K bytes  (2 / 4 files) (810.3 K / 1.7 M bytes)
# 2025-06-16 19:53:57,863 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf  250.9 K bytes  (3 / 4 files) (1.4 M / 1.7 M bytes)
# 2025-06-16 19:53:58,418 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsptcorr_0002.fits   49.0 K bytes  (4 / 4 files) (1.6 M / 1.7 M bytes)
# 2025-06-16 19:53:58,834 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0008.asdf'.
# 2025-06-16 19:53:58,835 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2025-06-16 19:53:58,835 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits'.
# 2025-06-16 19:53:58,836 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf'.
# 2025-06-16 19:53:58,836 - stpipe.Spec3Pipeline - INFO - Prefetch for MRSPTCORR reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_mrsptcorr_0002.fits'.
# 2025-06-16 19:53:58,837 - stpipe.Spec3Pipeline - INFO - Prefetch for PASTASOSS reference file is 'N/A'.
# 2025-06-16 19:53:58,838 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/fatih/crds_cache/references/jwst/miri/jwst_miri_photom_0211.fits'.
# 2025-06-16 19:53:58,838 - stpipe.Spec3Pipeline - INFO - Prefetch for PSF reference file is 'N/A'.
# 2025-06-16 19:53:58,839 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2025-06-16 19:53:58,839 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2025-06-16 19:53:58,840 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2025-06-16 19:53:58,846 - stpipe.Spec3Pipeline - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/associations/association.py:215: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning)
#
# 2025-06-16 19:54:07,267 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec5cca8b00>,).
# 2025-06-16 19:54:07,268 - stpipe.Spec3Pipeline.mrs_imatch - WARNING - mrs_imatch is deprecated
# 2025-06-16 19:54:07,335 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2025-06-16 19:54:07,336 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2025-06-16 19:54:07,336 - stpipe.CubeBuildStep - INFO - Input interpolation: drizzle
# 2025-06-16 19:54:07,336 - stpipe.CubeBuildStep - INFO - Coordinate system to use: skyalign
# 2025-06-16 19:54:07,337 - stpipe.CubeBuildStep - INFO - Cube Type: Single cubes
# 2025-06-16 19:54:07,372 - stpipe.CubeBuildStep - INFO - Setting output type to: channel
# 2025-06-16 19:54:07,435 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI Channels: ['1']
# 2025-06-16 19:54:07,436 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI subchannels: ['long']
# 2025-06-16 19:54:07,437 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2025-06-16 19:54:07,614 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Output cubes are single channel and all subchannels in data
# 2025-06-16 19:54:07,615 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:54:07,831 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:54:08,020 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:54:08,220 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:54:08,427 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2025-06-16 19:54:08,428 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:54:08,432 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    45  23.00 171.81117238   0.13000000  -2.92499989   2.92499989
# 2025-06-16 19:54:08,433 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    45  23.00  42.47312750   0.13000000  -2.92499989   2.92499989
# 2025-06-16 19:54:08,434 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:54:08,434 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3  1400   1.00   6.53040021   0.00080000   6.53000021   7.65000018
# 2025-06-16 19:54:08,434 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 1, long
# 2025-06-16 19:54:09,305 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.52826861649648
# 2025-06-16 19:54:09,306 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774826639
# 2025-06-16 19:54:12,399 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:13,429 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616502298
# 2025-06-16 19:54:13,430 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774820822
# 2025-06-16 19:54:16,505 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:17,528 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.5282686165090045
# 2025-06-16 19:54:17,529 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774814115
# 2025-06-16 19:54:21,768 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:22,744 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616514867
# 2025-06-16 19:54:22,749 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774808252
# 2025-06-16 19:54:25,907 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:26,065 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 4
# 2025-06-16 19:54:26,067 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.810095291 42.472333055 171.810095291 42.473921944 171.812249469 42.473921944 171.812249469 42.472333055
# 2025-06-16 19:54:26,068 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.810095291 42.472333055 171.810095291 42.473921944 171.812249469 42.473921944 171.812249469 42.472333055
# 2025-06-16 19:54:26,069 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.810095291 42.472333055 171.810095291 42.473921944 171.812249469 42.473921944 171.812249469 42.472333055
# 2025-06-16 19:54:26,071 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.810095291 42.472333055 171.810095291 42.473921944 171.812249469 42.473921944 171.812249469 42.472333055
# 2025-06-16 19:54:40,999 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2025-06-16 19:54:40,999 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2025-06-16 19:54:41,000 - stpipe.CubeBuildStep - INFO - Input interpolation: drizzle
# 2025-06-16 19:54:41,000 - stpipe.CubeBuildStep - INFO - Coordinate system to use: skyalign
# 2025-06-16 19:54:41,001 - stpipe.CubeBuildStep - INFO - Cube Type: Single cubes
# 2025-06-16 19:54:41,040 - stpipe.CubeBuildStep - INFO - Setting output type to: channel
# 2025-06-16 19:54:41,101 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI Channels: ['2']
# 2025-06-16 19:54:41,102 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI subchannels: ['long']
# 2025-06-16 19:54:41,102 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2025-06-16 19:54:41,277 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Output cubes are single channel and all subchannels in data
# 2025-06-16 19:54:41,280 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2025-06-16 19:54:41,280 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:54:41,281 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    41  21.00 171.81098632   0.17000000  -3.48500004   3.48500004
# 2025-06-16 19:54:41,281 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    41  21.00  42.47325463   0.17000000  -3.48500004   3.48500004
# 2025-06-16 19:54:41,282 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:54:41,283 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3  1300   1.00  10.01065023   0.00130000  10.01000023  11.70000023
# 2025-06-16 19:54:41,283 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 2, long
# 2025-06-16 19:54:42,023 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842400448
# 2025-06-16 19:54:42,025 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619963957
# 2025-06-16 19:54:44,815 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:45,681 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842409284
# 2025-06-16 19:54:45,681 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619955122
# 2025-06-16 19:54:48,495 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:49,381 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.00732784241947
# 2025-06-16 19:54:49,382 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619944936
# 2025-06-16 19:54:52,227 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:54,506 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842428374
# 2025-06-16 19:54:54,507 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619936031
# 2025-06-16 19:54:57,432 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:54:57,587 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 4
# 2025-06-16 19:54:57,588 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809705860 42.472310176 171.809705860 42.474199065 171.812266782 42.474199065 171.812266782 42.472310176
# 2025-06-16 19:54:57,590 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809705860 42.472310176 171.809705860 42.474199065 171.812266782 42.474199065 171.812266782 42.472310176
# 2025-06-16 19:54:57,591 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809705860 42.472310176 171.809705860 42.474199065 171.812266782 42.474199065 171.812266782 42.472310176
# 2025-06-16 19:54:57,593 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809705860 42.472310176 171.809705860 42.474199065 171.812266782 42.474199065 171.812266782 42.472310176
# 2025-06-16 19:55:09,347 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2025-06-16 19:55:09,348 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2025-06-16 19:55:09,348 - stpipe.CubeBuildStep - INFO - Input interpolation: drizzle
# 2025-06-16 19:55:09,348 - stpipe.CubeBuildStep - INFO - Coordinate system to use: skyalign
# 2025-06-16 19:55:09,349 - stpipe.CubeBuildStep - INFO - Cube Type: Single cubes
# 2025-06-16 19:55:09,383 - stpipe.CubeBuildStep - INFO - Setting output type to: channel
# 2025-06-16 19:55:09,438 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI Channels: ['3']
# 2025-06-16 19:55:09,439 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI subchannels: ['long']
# 2025-06-16 19:55:09,439 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2025-06-16 19:55:09,607 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Output cubes are single channel and all subchannels in data
# 2025-06-16 19:55:09,608 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:55:09,772 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:55:09,960 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:55:10,121 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:55:10,301 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2025-06-16 19:55:10,303 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:55:10,303 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    47  24.00 171.81121355   0.20000000  -4.70000007   4.70000007
# 2025-06-16 19:55:10,304 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    45  23.00  42.47333337   0.20000000  -4.50000007   4.50000007
# 2025-06-16 19:55:10,304 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:55:10,306 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3  1028   1.00  15.41124985   0.00250000  15.40999985  17.97999979
# 2025-06-16 19:55:10,307 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 3, long
# 2025-06-16 19:55:11,017 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374190578
# 2025-06-16 19:55:11,018 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263189664
# 2025-06-16 19:55:13,816 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:14,679 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374203986
# 2025-06-16 19:55:14,679 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263176256
# 2025-06-16 19:55:17,554 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:18,407 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374219439
# 2025-06-16 19:55:18,409 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.9843182631608
# 2025-06-16 19:55:21,281 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:22,160 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.40568137423295
# 2025-06-16 19:55:22,161 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263147294
# 2025-06-16 19:55:24,978 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:25,128 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 4
# 2025-06-16 19:55:25,130 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809481153 42.472111137 171.809481153 42.474555581 171.812945950 42.474555581 171.812945950 42.472111137
# 2025-06-16 19:55:25,131 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809481153 42.472111137 171.809481153 42.474555581 171.812945950 42.474555581 171.812945950 42.472111137
# 2025-06-16 19:55:25,132 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809481153 42.472111137 171.809481153 42.474555581 171.812945950 42.474555581 171.812945950 42.472111137
# 2025-06-16 19:55:25,134 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.809481153 42.472111137 171.809481153 42.474555581 171.812945950 42.474555581 171.812945950 42.472111137
# 2025-06-16 19:55:38,447 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2025-06-16 19:55:38,448 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2025-06-16 19:55:38,448 - stpipe.CubeBuildStep - INFO - Input interpolation: drizzle
# 2025-06-16 19:55:38,449 - stpipe.CubeBuildStep - INFO - Coordinate system to use: skyalign
# 2025-06-16 19:55:38,449 - stpipe.CubeBuildStep - INFO - Cube Type: Single cubes
# 2025-06-16 19:55:38,480 - stpipe.CubeBuildStep - INFO - Setting output type to: channel
# 2025-06-16 19:55:38,527 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI Channels: ['4']
# 2025-06-16 19:55:38,528 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes cover the MIRI subchannels: ['long']
# 2025-06-16 19:55:38,528 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2025-06-16 19:55:38,703 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Output cubes are single channel and all subchannels in data
# 2025-06-16 19:55:38,705 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2025-06-16 19:55:38,706 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:55:38,706 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    33  17.00 171.81087107   0.34999999  -5.77499990   5.77499990
# 2025-06-16 19:55:38,707 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    35  18.00  42.47318381   0.34999999  -6.12499990   6.12499990
# 2025-06-16 19:55:38,707 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:55:38,707 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3   717   1.00  24.40299962   0.00600000  24.39999962  28.70199966
# 2025-06-16 19:55:38,708 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 4, long
# 2025-06-16 19:55:39,287 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933817965
# 2025-06-16 19:55:40,768 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:41,474 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933840304
# 2025-06-16 19:55:43,017 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:43,774 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.39188693386605
# 2025-06-16 19:55:45,362 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:46,079 - stpipe.Spec3Pipeline.mrs_imatch - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933888564
# 2025-06-16 19:55:47,676 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:55:47,817 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 4
# 2025-06-16 19:55:47,818 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.808762057 42.471531009 171.808762057 42.474836565 171.812980090 42.474836565 171.812980090 42.471531009
# 2025-06-16 19:55:47,820 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.808762057 42.471531009 171.808762057 42.474836565 171.812980090 42.474836565 171.812980090 42.471531009
# 2025-06-16 19:55:47,821 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.808762057 42.471531009 171.808762057 42.474836565 171.812980090 42.474836565 171.812980090 42.471531009
# 2025-06-16 19:55:47,822 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Update S_REGION to POLYGON ICRS  171.808762057 42.471531009 171.808762057 42.474836565 171.812980090 42.474836565 171.812980090 42.471531009
# 2025-06-16 19:55:52,125 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch done
# 2025-06-16 19:55:52,346 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec5cca8b00>,).
# 2025-06-16 19:55:52,347 - stpipe.Spec3Pipeline.outlier_detection - INFO - Outlier Detection mode: ifu
# 2025-06-16 19:55:52,347 - stpipe.Spec3Pipeline.outlier_detection - INFO - Outlier Detection asn_id: o017
# 2025-06-16 19:55:52,348 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing IFU outlier_detection for exptype MIR_MRS
# 2025-06-16 19:55:52,394 - stpipe.Spec3Pipeline.outlier_detection - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/outlier_detection/ifu.py:225: RuntimeWarning: All-NaN slice encountered
#   combdiff = np.nanmin(comb, axis=0)
#
# 2025-06-16 19:55:52,434 - stpipe.Spec3Pipeline.outlier_detection - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst/outlier_detection/ifu.py:230: RuntimeWarning: All-NaN slice encountered
#   minarr = np.nanmin(diffarr, axis=0)
#
# 2025-06-16 19:55:52,716 - stpipe.Spec3Pipeline.outlier_detection - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/stcal/outlier_detection/utils.py:51: RuntimeWarning: All-NaN slice encountered
#   return np.nanmedian(windows, axis=np.arange(-len(kern_size), 0))
#
# 2025-06-16 19:55:52,881 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3197 (0.30%)
# 2025-06-16 19:55:52,897 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3197 (0.30%)
# 2025-06-16 19:55:52,913 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3197 (0.30%)
# 2025-06-16 19:55:52,929 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3197 (0.30%)
# 2025-06-16 19:55:53,400 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3434 (0.32%)
# 2025-06-16 19:55:53,418 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3434 (0.32%)
# 2025-06-16 19:55:53,435 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3434 (0.32%)
# 2025-06-16 19:55:53,453 - stpipe.Spec3Pipeline.outlier_detection - INFO - Total #  pixels flagged as outliers: 3434 (0.32%)
# 2025-06-16 19:55:53,800 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00001_mirifulong_o017_crf.fits
# 2025-06-16 19:55:54,153 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00001_mirifushort_o017_crf.fits
# 2025-06-16 19:55:54,454 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00002_mirifulong_o017_crf.fits
# 2025-06-16 19:55:54,811 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00002_mirifushort_o017_crf.fits
# 2025-06-16 19:55:55,097 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00003_mirifulong_o017_crf.fits
# 2025-06-16 19:55:55,635 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00003_mirifushort_o017_crf.fits
# 2025-06-16 19:55:55,926 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00004_mirifulong_o017_crf.fits
# 2025-06-16 19:55:56,289 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw03722003001_02101_00004_mirifushort_o017_crf.fits
# 2025-06-16 19:55:56,294 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2025-06-16 19:55:56,482 - stpipe.Spec3Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec5cca8b00>,).
# 2025-06-16 19:55:56,783 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:03,237 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 12866 total pixels replaced.
# 2025-06-16 19:56:03,791 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:08,545 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 15531 total pixels replaced.
# 2025-06-16 19:56:08,810 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:13,672 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 12866 total pixels replaced.
# 2025-06-16 19:56:14,259 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:19,023 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 15530 total pixels replaced.
# 2025-06-16 19:56:19,270 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:24,827 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 12867 total pixels replaced.
# 2025-06-16 19:56:25,142 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:29,721 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 15530 total pixels replaced.
# 2025-06-16 19:56:29,965 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:36,860 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 12866 total pixels replaced.
# 2025-06-16 19:56:37,181 - stpipe.Spec3Pipeline.pixel_replace - INFO - Using minimum gradient method.
# 2025-06-16 19:56:41,855 - stpipe.Spec3Pipeline.pixel_replace - INFO - Input MRS frame had 15530 total pixels replaced.
# 2025-06-16 19:56:41,860 - stpipe.Spec3Pipeline.pixel_replace - INFO - Step pixel_replace done
# 2025-06-16 19:56:42,231 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec5076b650>,).
# 2025-06-16 19:56:42,232 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2025-06-16 19:56:42,233 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: drizzle
# 2025-06-16 19:56:42,233 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: ifualign
# 2025-06-16 19:56:42,262 - stpipe.Spec3Pipeline.cube_build - INFO - Setting output type to: band
# 2025-06-16 19:56:42,404 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes cover the MIRI Channels: ['1', '2', '3', '4']
# 2025-06-16 19:56:42,404 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['long', 'long', 'long', 'long']
# 2025-06-16 19:56:42,405 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_cubepar_0014.fits
# 2025-06-16 19:56:42,584 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single channel, single sub-channel IFU Cubes
# 2025-06-16 19:56:42,584 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 4
# 2025-06-16 19:56:42,585 - stpipe.Spec3Pipeline.cube_build - INFO - Defining rotation between ra-dec and IFU plane using 1, long
# 2025-06-16 19:56:42,668 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between ifu and sky: -47.61388185820999
# 2025-06-16 19:56:42,669 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:42,834 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:43,012 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:43,187 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:43,367 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2025-06-16 19:56:43,370 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:56:43,371 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    31  16.00 171.81117238   0.13000000  -2.01499993   2.01499993
# 2025-06-16 19:56:43,372 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    33  17.00  42.47312750   0.13000000  -2.14499992   2.14499992
# 2025-06-16 19:56:43,372 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:56:43,372 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1400   1.00   6.53040021   0.00080000   6.53000021   7.65000018
# 2025-06-16 19:56:43,373 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between Ra-Dec and Slicer-Plane -47.61388186
# 2025-06-16 19:56:43,373 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1, long
# 2025-06-16 19:56:43,373 - stpipe.Spec3Pipeline.cube_build - INFO - Subchannel listing: ['long']
# 2025-06-16 19:56:43,373 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: Level3_ch1-long
# 2025-06-16 19:56:44,751 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.52826861649648
# 2025-06-16 19:56:44,752 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774826639
# 2025-06-16 19:56:48,671 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616502298
# 2025-06-16 19:56:48,672 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774820822
# 2025-06-16 19:56:52,568 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.5282686165090045
# 2025-06-16 19:56:52,569 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774814115
# 2025-06-16 19:56:56,696 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3181 with wavelength below 6.528268616514867
# 2025-06-16 19:56:56,697 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 3966 with wavelength above 7.651731774808252
# 2025-06-16 19:56:59,259 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2025-06-16 19:56:59,260 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2025-06-16 19:56:59,264 - stpipe.Spec3Pipeline.cube_build - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:56:59,412 - stpipe.Spec3Pipeline.cube_build - INFO - Defining rotation between ra-dec and IFU plane using 2, long
# 2025-06-16 19:56:59,487 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between ifu and sky: -47.74233880183479
# 2025-06-16 19:56:59,488 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:59,640 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:59,816 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:56:59,990 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:00,200 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2025-06-16 19:57:00,201 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:57:00,201 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    29  15.00 171.81098632   0.17000000  -2.46500003   2.46500003
# 2025-06-16 19:57:00,202 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    33  17.00  42.47325463   0.17000000  -2.80500003   2.80500003
# 2025-06-16 19:57:00,203 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:57:00,203 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1300   1.00  10.01065023   0.00130000  10.01000023  11.70000023
# 2025-06-16 19:57:00,204 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between Ra-Dec and Slicer-Plane -47.74233880
# 2025-06-16 19:57:00,205 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2, long
# 2025-06-16 19:57:00,205 - stpipe.Spec3Pipeline.cube_build - INFO - Subchannel listing: ['long']
# 2025-06-16 19:57:00,206 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: Level3_ch2-long
# 2025-06-16 19:57:01,443 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842400448
# 2025-06-16 19:57:01,443 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619963957
# 2025-06-16 19:57:04,992 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842409284
# 2025-06-16 19:57:04,993 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619955122
# 2025-06-16 19:57:09,754 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.00732784241947
# 2025-06-16 19:57:09,755 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619944936
# 2025-06-16 19:57:13,346 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1141 with wavelength below 10.007327842428374
# 2025-06-16 19:57:13,348 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 1841 with wavelength above 11.702672619936031
# 2025-06-16 19:57:15,738 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2025-06-16 19:57:15,739 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2025-06-16 19:57:15,742 - stpipe.Spec3Pipeline.cube_build - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:57:15,891 - stpipe.Spec3Pipeline.cube_build - INFO - Defining rotation between ra-dec and IFU plane using 3, long
# 2025-06-16 19:57:15,964 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between ifu and sky: -48.30740907926949
# 2025-06-16 19:57:15,965 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:16,129 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:16,330 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:16,491 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:16,657 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2025-06-16 19:57:16,661 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:57:16,661 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    35  18.00 171.81121355   0.20000000  -3.50000005   3.50000005
# 2025-06-16 19:57:16,661 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    35  18.00  42.47333337   0.20000000  -3.50000005   3.50000005
# 2025-06-16 19:57:16,662 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:57:16,662 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1028   1.00  15.41124985   0.00250000  15.40999985  17.97999979
# 2025-06-16 19:57:16,662 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between Ra-Dec and Slicer-Plane -48.30740908
# 2025-06-16 19:57:16,663 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 3, long
# 2025-06-16 19:57:16,663 - stpipe.Spec3Pipeline.cube_build - INFO - Subchannel listing: ['long']
# 2025-06-16 19:57:16,663 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: Level3_ch3-long
# 2025-06-16 19:57:17,770 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374190578
# 2025-06-16 19:57:17,771 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263189664
# 2025-06-16 19:57:21,497 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374203986
# 2025-06-16 19:57:21,498 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263176256
# 2025-06-16 19:57:24,924 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.405681374219439
# 2025-06-16 19:57:24,925 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.9843182631608
# 2025-06-16 19:57:28,384 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 917 with wavelength below 15.40568137423295
# 2025-06-16 19:57:28,385 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 742 with wavelength above 17.984318263147294
# 2025-06-16 19:57:30,715 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2025-06-16 19:57:30,715 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2025-06-16 19:57:30,719 - stpipe.Spec3Pipeline.cube_build - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:57:30,870 - stpipe.Spec3Pipeline.cube_build - INFO - Defining rotation between ra-dec and IFU plane using 4, long
# 2025-06-16 19:57:30,932 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between ifu and sky: -47.80877631702592
# 2025-06-16 19:57:30,933 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:31,069 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:31,220 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:31,381 - stpipe.Spec3Pipeline.cube_build - INFO - Mapping all pixels to output to determine IFU foot print
# 2025-06-16 19:57:31,558 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2025-06-16 19:57:31,561 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2025-06-16 19:57:31,561 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    25  13.00 171.81085415   0.34999999  -4.37499993   4.37499993
# 2025-06-16 19:57:31,561 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    27  14.00  42.47318381   0.34999999  -4.72499992   4.72499992
# 2025-06-16 19:57:31,562 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2025-06-16 19:57:31,562 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3   717   1.00  24.40299962   0.00600000  24.39999962  28.70199966
# 2025-06-16 19:57:31,562 - stpipe.Spec3Pipeline.cube_build - INFO - Rotation angle between Ra-Dec and Slicer-Plane -47.80877632
# 2025-06-16 19:57:31,562 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 4, long
# 2025-06-16 19:57:31,563 - stpipe.Spec3Pipeline.cube_build - INFO - Subchannel listing: ['long']
# 2025-06-16 19:57:31,563 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: Level3_ch4-long
# 2025-06-16 19:57:32,620 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933817965
# 2025-06-16 19:57:34,955 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933840304
# 2025-06-16 19:57:37,907 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.39188693386605
# 2025-06-16 19:57:40,272 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 13197 with wavelength below 24.391886933888564
# 2025-06-16 19:57:43,031 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2025-06-16 19:57:43,031 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2025-06-16 19:57:43,034 - stpipe.Spec3Pipeline.cube_build - INFO - Number of spectral tear planes adjusted: 0
# 2025-06-16 19:57:43,184 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  171.810098745 42.472337926 171.810098745 42.473917083 171.812246017 42.473917083 171.812246017 42.472337926
# 2025-06-16 19:57:43,186 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  171.809625430 42.472257235 171.809625430 42.474252020 171.812347211 42.474252020 171.812347211 42.472257235
# 2025-06-16 19:57:43,188 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  171.809405749 42.471999951 171.809405749 42.474666794 171.813021358 42.474666794 171.813021358 42.471999951
# 2025-06-16 19:57:43,189 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  171.808522286 42.471470578 171.808522286 42.474897035 171.813186010 42.474897035 171.813186010 42.471470578
# 2025-06-16 19:57:43,192 - CRDS - INFO -  Calibration SW Found: jwst 1.18.1 (/home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/jwst-1.18.1.dist-info)
# 2025-06-16 19:57:43,641 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/Level3_ch1-long_s3d.fits
# 2025-06-16 19:57:43,780 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/Level3_ch2-long_s3d.fits
# 2025-06-16 19:57:43,920 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/Level3_ch3-long_s3d.fits
# 2025-06-16 19:57:44,048 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in stage3/Level3_ch4-long_s3d.fits
# 2025-06-16 19:57:44,049 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2025-06-16 19:57:44,542 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec468db830>,).
# 2025-06-16 19:57:44,603 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2025-06-16 19:57:44,610 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0007.asdf  810.3 K bytes  (1 / 1 files) (0 / 810.3 K bytes)
# 2025-06-16 19:57:45,325 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0007.asdf
# 2025-06-16 19:57:45,332 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2025-06-16 19:57:45,616 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2025-06-16 19:57:51,226 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2025-06-16 19:57:51,672 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying ERR covariance prefactor of 1.8
# 2025-06-16 19:57:51,706 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2025-06-16 19:57:51,712 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0005.asdf  810.3 K bytes  (1 / 1 files) (0 / 810.3 K bytes)
# 2025-06-16 19:57:52,375 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0005.asdf
# 2025-06-16 19:57:52,382 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2025-06-16 19:57:52,630 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2025-06-16 19:57:57,809 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2025-06-16 19:58:00,331 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying ERR covariance prefactor of 1.8
# 2025-06-16 19:58:00,363 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2025-06-16 19:58:00,369 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0006.asdf  810.3 K bytes  (1 / 1 files) (0 / 810.3 K bytes)
# 2025-06-16 19:58:01,032 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0006.asdf
# 2025-06-16 19:58:01,038 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2025-06-16 19:58:01,273 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2025-06-16 19:58:05,580 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2025-06-16 19:58:08,092 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying ERR covariance prefactor of 1.8
# 2025-06-16 19:58:08,125 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_extract1d_0004.asdf
# 2025-06-16 19:58:08,131 - CRDS - INFO -  Fetching  /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf  810.2 K bytes  (1 / 1 files) (0 / 810.2 K bytes)
# 2025-06-16 19:58:08,833 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /home/fatih/crds_cache/references/jwst/miri/jwst_miri_apcorr_0004.asdf
# 2025-06-16 19:58:08,840 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2025-06-16 19:58:09,081 - stpipe.Spec3Pipeline.extract_1d - INFO - Input model does not break out variance information. Passing only generalized errors.
# 2025-06-16 19:58:11,709 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying 1d residual fringe correction.
# 2025-06-16 19:58:12,302 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying ERR covariance prefactor of 1.8
# 2025-06-16 19:58:12,337 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2025-06-16 19:58:12,677 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak running with args (<jwst.datamodels.container.ModelContainer object at 0x7fec5a463ad0>,).
# 2025-06-16 19:58:12,733 - stpipe.Spec3Pipeline.spectral_leak - WARNING - No spectral leak correction for extended source data
# 2025-06-16 19:58:12,782 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in stage3/Level3_ch1-long_x1d.fits
# 2025-06-16 19:58:12,828 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in stage3/Level3_ch2-long_x1d.fits
# 2025-06-16 19:58:12,875 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in stage3/Level3_ch3-long_x1d.fits
# 2025-06-16 19:58:12,921 - stpipe.Spec3Pipeline.spectral_leak - INFO - Saved model in stage3/Level3_ch4-long_x1d.fits
# 2025-06-16 19:58:12,921 - stpipe.Spec3Pipeline.spectral_leak - INFO - Step spectral_leak done
# 2025-06-16 19:58:12,927 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2025-06-16 19:58:12,931 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done
# 2025-06-16 19:58:12,932 - stpipe - INFO - Results used jwst version: 1.18.1

# %% [markdown]
# ## Post-pipeline Cube Stripe Removal

# %% [markdown]
# Ordinarily the Spec3 pipeline above would be the end of the road for most "well-behaved" data processing; the `s3d.fits` files in `stage3/` would be science-ready. In fact if you are working with data that don't show strong cosmic ray shower artifacts, you will not need to run this next part.
#
# Unfortunately for us, our data are strongly affected by the CR showers. You can see these as the large amorphous 'blobs' in the `_cal.fits` files produced in Stage 2 - most of those pixels are still unflagged even though the Stage 1 pipeline now has a preliminary way to identify and flag these lower-level jumps. Also unfortunately for us, the PAH emission is faint, the target galaxy SPT0418-47 has even fainter continuum, and the galaxy is extended over ~3" into an Einstein ring. We need every bit of sensitivity we can get, and the CR showers are the dominant remaining instrumental systematic.
#
# Because the showers take up blobby regions on the detector that are a few dozen pixels wide, they typically are contained entirely within 1 or 2 of the MRS slices but hit every pixel within a slice. The diagram below (taken directly from the [MRS documentation](https://jwst-docs.stsci.edu/jwst-mid-infrared-instrument/miri-observing-modes/miri-medium-resolution-spectroscopy); Law et al. 2023 in prep.) can help illustrate why the CR showers get mapped into stripes when built with the `ifualign` option in the Spec3 `cube_build` step.

# %%
Image('MRSDiagram.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1090, in Image._repr_mimebundle_(self, include, exclude)
#    1088 if self.embed:
#    1089     mimetype = self._mimetype
# -> 1090     data, metadata = self._data_and_metadata(always_both=True)
#    1091     if metadata:
#    1092         metadata = {mimetype: metadata}
#
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1102, in Image._data_and_metadata(self, always_both)
#    1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
# -> 1102     raise FileNotFoundError(
#    1103         "No such file or directory: '%s'" % (self.data)) from e
#    1104 md = {}
#    1105 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'MRSDiagram.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1122, in Image._repr_png_(self)
#    1120 def _repr_png_(self):
#    1121     if self.embed and self.format == self._FMT_PNG:
# -> 1122         return self._data_and_metadata()
#
# File ~/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/IPython/core/display.py:1102, in Image._data_and_metadata(self, always_both)
#    1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
# -> 1102     raise FileNotFoundError(
#    1103         "No such file or directory: '%s'" % (self.data)) from e
#    1104 md = {}
#    1105 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'MRSDiagram.png'

# %% [markdown]
# Let's look at the Channel 3 detector layout in yellow in the middle image. There are 16 vertical slices on the right half of the long-wavelength detector; these correspond to the y-dimension when mapped into the data cube. The cube's x-dimension corresponds to the along-slice direction - within each slice from right to left. Wavelength increases from top to bottom of the detector.
#
# Now imagine you have a blobby CR shower a few dozen pixels in size sitting somewhere in that region. The shower is big enough to cover basically all pixels within 1 or 2 slices - so it will affect all of the cube's x pixels within the rows that correspond to that slice. But it's not big enough to cover all slices at once, so it only influences maybe 2 or 3 rows of the y-dimension in the cube. It also spans a few dozen pixels up/down on the detector, corresponding to the cube's wavelength dimension. The net effect is that CR showers produce horizontal stripes in the output cube that are a couple rows tall but coherent over tens of wavelength channels. The stripes aren't perfectly horizontal (even with `ifualign` in the cube building) because the slices are curved on the detector and the CR showers are blobby instead of rectangular.
#
# Incidentally the shower removal techniques in the current (Feb. 2023) pipeline and our more aggressive jump flagging in Detector1 do greatly improve the data quality. Without them, horizontal stripes are visible even in individual channels of the data cube. With them, you have to average over >10 channels in order to beat down the noise and see the stripes come through.
#
# In the following I lay out one way to address these stripes, demonstrated only on the Channel 3 cube that contains the PAH emission. The key is that (1) the position of the galaxy in the cube is well known from existing data (from ALMA), so we aren't blindly searching through the cube for signal, and (2) we have at least a few pixels on all sides of the source that can be used to estimate the stripe amplitude (i.e. the source doesn't run up against the edge of the cube). This method will not work if either of those is not true.
#
# The basic steps are:
# 1. Use the known source position and shape to mask the Level 3 cube
# 2. Use the background tools in `photutils` to create a 'stripe template'
# 3. Subtract this stripe template from the cube
#
# If you want to try this on different data, you will definitely need to change the definition of the cube mask to match your target. You will also probably want to play around with some of the choices I made in the following to see what impact they have on your results, but hopefully this is enough to get you started...

# %%
from astropy.io import fits
from astropy.wcs import WCS
from regions import Regions
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import simple_norm

# --- File paths ---
cube_path = stage3 + 'Level3_ch3-long_s3d.fits'  # update if different
region_file = '/home/fatih/G165_main/G165_miri_bg_subtraction/data/just_sci_ds9_world_all_in copy'  # path to your DS9 region file

# --- Load JWST cube ---
cube = fits.open(cube_path)
sci = cube['SCI'].data
dq = cube['DQ'].data
wcs2d = WCS(cube['SCI'].header, naxis=2)

# --- Load and convert DS9 elliptical regions to pixel regions ---
regions = Regions.read(region_file, format='ds9')
pixel_regions = [reg.to_pixel(wcs2d) for reg in regions]

# --- Create a 2D boolean mask (for one slice) from the elliptical regions ---
mask2d = np.zeros(sci.shape[1:], dtype=bool)
for preg in pixel_regions:
    thismask = preg.to_mask(mode='center').to_image(mask2d.shape)
    if thismask is not None:
        mask2d |= thismask.astype(bool)

# --- Expand to 3D source mask ---
sourcemask = np.zeros(sci.shape, dtype=bool)
sourcemask[:] = mask2d

# --- Apply DQ mask and source mask ---
scimasked = np.ma.masked_array(sci, mask=(dq > 0))
scisourcemask = scimasked.copy()
scisourcemask.mask += sourcemask

# --- Display 47th slice with regions ---
slice_idx = 47
sci_slice = sci[slice_idx]
norm = simple_norm(sci_slice, 'linear', percent=99)

fig, ax = plt.subplots(figsize=(8, 6), subplot_kw={'projection': wcs2d})
im = ax.imshow(sci_slice, origin='lower', cmap='inferno', norm=norm)
# Plot each region correctly using as_artist
for sky_region in regions:
    pix_region = sky_region.to_pixel(wcs2d)
    artist = pix_region.as_artist(facecolor='none', edgecolor='cyan', lw=2)
    ax.add_patch(artist)

ax.set_title(f'Slice {slice_idx} with Region Overlays')
ax.set_xlabel('RA')
ax.set_ylabel('Dec')
plt.colorbar(im, ax=ax, label='Surface Brightness')
plt.tight_layout()
plt.show()
# Out:
# 2025-06-18 01:03:11,656 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/wcs/wcs.py:805: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -99.435174 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.985828 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1626787592.719 from OBSGEO-[XYZ]'.
#   warnings.warn(

# %%
if dopost:
    from regions import Regions
    from astropy.wcs import WCS
    from astropy.coordinates import SkyCoord
    import astropy.units as u
    import numpy as np

    # Read in the pipe-produced Level 3 data cube for channel 3
    cube = fits.open(stage3+'Level3_ch3-long_s3d.fits')
    sci  = cube['SCI'].data
    err  = cube['ERR'].data
    dq   = cube['DQ'].data
    scihead = cube['SCI'].header
    wcs = WCS(scihead)

    # Read your DS9 region file
    regions = Regions.read("/home/fatih/G165_main/G165_miri_bg_subtraction/data/just_sci_ds9_world_all_in copy", format="ds9")

    # Create a mask from all the regions (applied to the full cube spatially)
    mask = np.zeros(sci.shape[1:], dtype=bool)  # 2D spatial mask

for sky_region in regions:
    pix_region = sky_region.to_pixel(wcs.celestial)
    pix_mask = pix_region.to_mask(mode='center')
    if pix_mask is not None:
        mask_img = pix_mask.to_image(sci.shape[1:])
        if mask_img is not None:
            mask |= (mask_img > 0)


    wts  = err**-2   # w = 1/sigma^2, useful for weighted averages etc.
    scimasked = np.ma.masked_array(sci, mask = (dq>0)) # use DQ array to mask the science data

    # Apply the DS9 region mask across all slices of the cube (3D mask)
    sourcemask = np.zeros_like(sci, dtype=bool)
    for i in range(sci.shape[0]):
        sourcemask[i] = mask

    # Combine with existing mask
    scisourcemask = scimasked.copy()
    scisourcemask.mask += sourcemask

    # (rest of your original code below remains the same, but replace scimasked with scisourcemask where needed)
    
    # Example replacement in loop for background estimation:
    cubeavg     = np.zeros(scisourcemask.shape)
    cubeavg_wtd = np.zeros(scisourcemask.shape)
    cubebkg     = np.zeros(scisourcemask.shape)
    cubebkg_wtd = np.zeros(scisourcemask.shape)
    
    chstep   = 25
    halfstep = int((chstep-1)/2)
    bkg_estimator = MedianBackground() # From photutils
    
    for chstart in np.arange(halfstep, sci.shape[0]):
        cutout = np.ma.average(scisourcemask[chstart-halfstep:chstart+chstep+halfstep],axis=0)
        cutout2= np.ma.average(scisourcemask[chstart-halfstep:chstart+chstep+halfstep],axis=0,weights=wts[chstart-halfstep:chstart+chstep+halfstep])

        bkg = Background2D(cutout,  box_size=(1,int(np.ceil(cutout.shape[1]/2))), mask=(cutout.mask | sourcemask[0]), 
                filter_size=1, bkg_estimator=bkg_estimator, exclude_percentile=75.0)
        bkg2= Background2D(cutout2, box_size=(1,int(np.ceil(cutout.shape[1]/2))), mask=(cutout2.mask | sourcemask[0]), 
                filter_size=1, bkg_estimator=bkg_estimator, exclude_percentile=75.0)    

        cubeavg[chstart]     = cutout
        cubeavg_wtd[chstart] = cutout2
        cubebkg[chstart]     = bkg.background
        cubebkg_wtd[chstart] = bkg2.background
    
    # (rest of your code: padding, saving files, background subtraction - unchanged)
    # ...

if True:
    from matplotlib.patches import Ellipse
    from regions import Regions
    from astropy.wcs import WCS

    xpeak, ypeak, rout = 19.5, 18.0, 8.5 # copied from above

    chstart, chstop = 500, 600

    pipe = fits.open(stage3+'Level3_ch3-long_s3d.fits')['SCI'].data
    back = fits.open(poststage3+'Level3_ch3-long_s3d_background.fits')['SCI'].data
    bsub = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].data

    back[:,:1,:]  = 0.
    back[:,-1:,:] = 0.
    back[:,:,:1]  = 0.
    back[:,:,-1:] = 0.
    bsub[:,:1,:]  = 0.
    bsub[:,-1:,:] = 0.
    bsub[:,:,:2]  = 0.
    bsub[:,:,-2:] = 0.

    pipedata = np.ma.average(pipe[chstart:chstop], axis=0)
    backdata = np.ma.average(back[chstart:chstop], axis=0)
    bsubdata = np.ma.average(bsub[chstart:chstop], axis=0)

    f,axarr = plt.subplots(figsize=(7.5,3),nrows=1,ncols=3)
    f.subplots_adjust(left=0.01,right=0.99,bottom=0.01,top=0.9,hspace=0,wspace=0)

    axarr[0].imshow(pipedata, origin='lower', cmap='inferno')#, vmin=20, vmax=80)
    axarr[1].imshow(backdata, origin='lower', cmap='inferno')#, vmin=20, vmax=80)
    axarr[2].imshow(bsubdata, origin='lower', cmap='inferno')#, vmin=20, vmax=80)

    axarr[0].set_title('Original Pipeline',fontsize='large')
    axarr[1].set_title('Estimated Striping',fontsize='large')
    axarr[2].set_title('Stripes Removed',fontsize='large')

    # Read regions again for plotting
    regions = Regions.read("/home/fatih/G165_main/G165_miri_bg_subtraction/data/just_sci_ds9_world_all_in copy", format="ds9")
    wcs = WCS(cube['SCI'].header).celestial

    for ax in axarr:
        # Plot circular mask as before
        # mask = Ellipse(xy=(xpeak+0.5,ypeak+0.5),width=2*rout,height=2*rout,angle=0.,ec='grey',fc='None')
        # ax.add_artist(mask)
        # Plot your DS9 ellipses converted to pixel coords
        for sky_region in regions:
            pix_region = sky_region.to_pixel(wcs)
            artist = pix_region.as_artist(facecolor='none', edgecolor='cyan', lw=2)
            ax.add_patch(artist)

        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()
    plt.close(f)

    plt.imshow(mask, origin='lower', cmap='gray')
    plt.title("Final Combined 2D Mask")
    plt.show()

    plt.imshow(pipe[550], origin='lower', cmap='inferno')#, vmin=20, vmax=80)
    plt.title("Raw Pipeline Slice 550")
    plt.colorbar()
    plt.show()
# Out:
# 2025-06-18 01:06:07,946 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/wcs/wcs.py:805: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-05-14T19:26:37.229' from MJD-BEG.
# Set DATE-AVG to '2024-05-14T20:33:42.768' from MJD-AVG.
# Set DATE-END to '2024-05-14T21:40:48.275' from MJD-END'.
#   warnings.warn(
#
# 2025-06-18 01:06:07,946 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/wcs/wcs.py:805: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -99.435174 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.985828 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1626787592.719 from OBSGEO-[XYZ]'.
#   warnings.warn(
#
# 2025-06-18 01:06:14,227 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/wcs/wcs.py:805: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2024-05-14T19:26:37.229' from MJD-BEG.
# Set DATE-AVG to '2024-05-14T20:33:42.768' from MJD-AVG.
# Set DATE-END to '2024-05-14T21:40:48.275' from MJD-END'.
#   warnings.warn(
#
# 2025-06-18 01:06:14,228 - stpipe - WARNING - /home/fatih/G165_main/G165_miri_bg_subtraction/.venv/lib/python3.12/site-packages/astropy/wcs/wcs.py:805: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -99.435174 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -26.985828 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1626787592.719 from OBSGEO-[XYZ]'.
#   warnings.warn(

# %%
# from regions import Regions
# from astropy.wcs import WCS
# 
# def make_mask_from_regions(regions_file, shape_2d, wcs_2d):
#     """
#     Create a 2D boolean mask from a DS9 region file and 2D WCS.
#     True = masked pixel
#     """
#     regions = Regions.read(regions_file, format='ds9')
#     mask_total = np.zeros(shape_2d, dtype=bool)
# 
#     for sky_region in regions:
#         pixel_region = sky_region.to_pixel(wcs_2d)
#         region_mask = pixel_region.to_mask(mode='center')
#         mask_data = region_mask.to_image(shape_2d)
#         mask_total |= (mask_data != 0)  # Combine with OR
# 
#     return mask_total
# 
# # This function can be used to create a mask from the regions file

# %%
if dopost:
    # Read in the pipe-produced Level 3 data cube for channel 3
    cube = fits.open(stage3+'Level3_ch3-long_s3d.fits')
    sci  = cube['SCI'].data
    err  = cube['ERR'].data
    dq   = cube['DQ'].data
    scihead = cube['SCI'].header

    # These will be useful
    wts  = err**-2   # w = 1/sigma^2, useful for weighted averages etc.
    scimasked = np.ma.masked_array(sci, mask = (dq>0)) # use DQ array to mask the science data
    
    # These define the pixel coordinates for the x and y center of the foreground lens,
    # plus a radius based on the Einstein ring size. I (JS) get consistent results whether
    # I get these using the cube's WCS information and ancillary ALMA data, or by collapsing
    # the whole cube over wavelength and visibly seeing the lens+ring.
    xpeak, ypeak, rout = 19.5, 18.0, 8.5
    
    # Now we create a boolean mask, circular in shape, using the above params.
    # This atrocious command masks a circle with radius=rout pix around the lens center
    circmask = (np.linalg.norm(np.argwhere(sci[0]) - np.array([ypeak,xpeak]), axis=1) < rout).reshape(sci[0].shape)
    
    # Now use that (2D) circular mask to mask the source in all (3D) cube channels.
    # Optionally I (JS) explored also masking some of the edge pixels which seem to
    # be junk, but they also have high ERR / low weight so in weighted stats they matter little
    sourcemask    = np.zeros(sci.shape, dtype=bool)
    sourcemask[:] = circmask
    # sourcemask[:, :, :2] = True # mask edges
    # sourcemask[:, :, 32] = True
    
    # Create a copy of the original (DQ masked) data but now include our
    # additional mask from above
    scisourcemask = scimasked.copy()
    scisourcemask.mask += sourcemask
    
    # We will calculate the stripe template using a running average over the
    # cube. There's an option to use either a straight average or a weighted average,
    # so we'll just make both.
    # These will be the smoothed cubes before stripe removal
    cubeavg     = np.zeros(scisourcemask.shape)
    cubeavg_wtd = np.zeros(scisourcemask.shape)
    # These will contain the estimated stripe templates
    cubebkg     = np.zeros(scisourcemask.shape)
    cubebkg_wtd = np.zeros(scisourcemask.shape)
    
    # Setup for our background/stripe estimation. Stripes are coherent over tens
    # of wavelength channels (remember cube has been "3d drizzled" so oversamples
    # the detectors spectral resolution). After some experimentation I settled on
    # a 25-channel running average.
    chstep   = 25
    halfstep = int((chstep-1)/2)
    bkg_estimator = MedianBackground() # From photutils
    
    for chstart in np.arange(halfstep, sci.shape[0]):
        cutout = np.ma.average(scimasked[chstart-halfstep:chstart+chstep+halfstep],axis=0)
        cutout2= np.ma.average(scimasked[chstart-halfstep:chstart+chstep+halfstep],axis=0,weights=wts[chstart-halfstep:chstart+chstep+halfstep])

        # Use photutils to estimate the 2D "background" (striping). The box_size
        # parameter sets the shape of the stripe estimation. Here using (1,shape[1]/2)
        # corresponds to fitting the "background" in a shape that is 1 row tall and
        # half the x-pixels of the cube, which allows enough flexibility to account
        # for the fact that the slices aren't perfectly x-aligned due to the slice
        # curvature on the detector. Also exclude_percentile is very high here because
        # in some rows most of the cube pixels are masked, where our circular source
        # mask is at its widest point.
        bkg = Background2D(cutout,  box_size=(1,int(np.ceil(cutout.shape[1]/2))), mask=(cutout.mask | sourcemask[0]), 
                filter_size=1, bkg_estimator=bkg_estimator, exclude_percentile=75.0)
        bkg2= Background2D(cutout2, box_size=(1,int(np.ceil(cutout.shape[1]/2))), mask=(cutout2.mask | sourcemask[0]), 
                filter_size=1, bkg_estimator=bkg_estimator, exclude_percentile=75.0)    

        # Overwrite our blank cubes with data
        cubeavg[chstart]     = cutout
        cubeavg_wtd[chstart] = cutout2
        cubebkg[chstart]     = bkg.background
        cubebkg_wtd[chstart] = bkg2.background
        
    # The above fails near the edge channels at the start/end of the cube,
    # pad those slices with the same background for convenience (and remember
    # to ignore edge channels in later analysis)
    cubeavg[0:halfstep]     = cubeavg[halfstep]
    cubeavg_wtd[0:halfstep] = cubeavg_wtd[halfstep]
    cubebkg[0:halfstep]     = cubebkg[halfstep]
    cubebkg_wtd[0:halfstep] = cubebkg[halfstep]
    cubeavg[-halfstep:]     = cubeavg[-halfstep]
    cubeavg_wtd[-halfstep:] = cubeavg_wtd[-halfstep]
    cubebkg[-halfstep:]     = cubebkg[-halfstep]
    cubebkg_wtd[-halfstep:] = cubebkg[-halfstep]
    
    # Now write the wavelength-smoothed cubes and backgrounds to disk.
    cubehdu = fits.PrimaryHDU(cubeavg,header=cube['SCI'].header)
    cubehdu.writeto(poststage3+'Level3_ch3-long_s3d_runningavg.fits',overwrite=True)
    cubehdu = fits.PrimaryHDU(cubeavg_wtd,header=cube['SCI'].header)
    cubehdu.writeto(poststage3+'Level3_ch3-long_s3d_runningweightedavg.fits',overwrite=True)
    bkghdu = fits.PrimaryHDU(cubebkg,header=cube['SCI'].header)
    bkghdu.writeto(poststage3+'Level3_ch3-long_s3d_background.fits',overwrite=True)
    bkghdu = fits.PrimaryHDU(cubebkg_wtd, header=cube['SCI'].header)
    bkghdu.writeto(poststage3+'Level3_ch3-long_s3d_weightedbackground.fits',overwrite=True)
    
    # Finally, also write out the background-subtracted cubes to disk
    bkgsub     = scimasked.data - cubebkg
    bkgsub_wtd = scimasked.data - cubebkg_wtd
    cubehdu = fits.PrimaryHDU(bkgsub,header=cube['SCI'].header)
    cubehdu.writeto(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits',overwrite=True)
    cubehdu = fits.PrimaryHDU(bkgsub_wtd,header=cube['SCI'].header)
    cubehdu.writeto(poststage3+'Level3_ch3-long_s3d_bkgwtdsubtracted.fits',overwrite=True)

# %% [markdown]
# And that's it, we're finally done! As a quick check to see how well we did, let's try plotting up some random interval of the cube both with and without stripe removal.

# %%
# if dopost:
if True:
    xpeak, ypeak, rout = 19.5, 18.0, 8.5 # copied from above
    from matplotlib.patches import Ellipse

    # The starting and stopping channels of the cubes we should plot
    # You can play with these to see how the stripe properties vary
    # as a function of cube width etc.
    chstart, chstop = 500, 600

    pipe = fits.open(stage3+'Level3_ch3-long_s3d.fits')['SCI'].data
    back = fits.open(poststage3+'Level3_ch3-long_s3d_background.fits')['SCI'].data
    bsub = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].data
    
    # Edge pixels are flagged in original cube, but not in mine (we ignored the
    # DQ arrays when writing back to disk), flag them here for consistency
    back[:,:1,:]  = 0.
    back[:,-1:,:] = 0.
    back[:,:,:1]  = 0.
    back[:,:,-1:] = 0.
    bsub[:,:1,:]  = 0.
    bsub[:,-1:,:] = 0.
    bsub[:,:,:2]  = 0.
    bsub[:,:,-2:] = 0.
    
    # Average the cube over the specified channel range
    pipedata = np.ma.average(pipe[chstart:chstop], axis=0)
    backdata = np.ma.average(back[chstart:chstop], axis=0)
    bsubdata = np.ma.average(bsub[chstart:chstop], axis=0)
    
    f,axarr = plt.subplots(figsize=(7.5,3),nrows=1,ncols=3)
    f.subplots_adjust(left=0.01,right=0.99,bottom=0.01,top=0.9,hspace=0,wspace=0)
    
    axarr[0].imshow(pipedata, origin='lower', cmap='jet', vmin=-3., vmax=3.0)
    axarr[1].imshow(backdata, origin='lower', cmap='jet', vmin=-3., vmax=3.0)
    axarr[2].imshow(bsubdata, origin='lower', cmap='jet', vmin=-3., vmax=3.0)
    
    axarr[0].set_title('Original Pipeline',fontsize='large')
    axarr[1].set_title('Estimated Striping',fontsize='large')
    axarr[2].set_title('Stripes Removed',fontsize='large')
    
    for ax in axarr:
        # note we actually shift the drawing of the masked regions bc matplotlib
        # defines pixels differently than numpy (it's a half-pixel thing as always)
        mask = Ellipse(xy=(xpeak+0.5,ypeak+0.5),width=2*rout,height=2*rout,angle=0.,ec='grey',fc='None')
        ax.add_artist(mask)
        ax.set_xticks([])
        ax.set_yticks([])
    
    plt.show()
    plt.close(f)

# %% [markdown]
# Not too bad! We see that the very strong stripey artifacts are mostly gone now. There's still some mess around the edge pixels that weren't covered by all 4 dither positions, but the data are now in usable shape.

# %% [markdown]
# ## Cube Analysis and Spectral Extraction

# %% [markdown]
# Here's a quick demonstration of how to work with these cubes to produce an estimate of the continuum and a PAH-only map (moment-0 for the radio astronomers). We'll assume just a constant continuum level, made from the wavelength ranges with no PAH emission (judged by JS' eyes from the spectrum).

# %%
if doanalyze:
    # Read back in our cube in case above steps were skipped
    bkgsub = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].data
    header = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].header
    wave = np.arange(header['NAXIS3'])*header['CDELT3'] + header['CRVAL3'] # array of cube wavelengths
    
    
    # These channels correspond to the PAH feature, we don't expect any
    # other bright lines in the cube except this. PAH channel range
    # corresponds to approx. the FWHM of the line. All other channels
    # are counted as continuum, but we exclude 60 more channels on either
    # side of the above since the PAH image is the FWHM, not the FWZI.
    mom0start, mom0stop = 540, 650
    
    # which indices count as continuum?
    contix = np.ones(bkgsub.shape[0],dtype=bool)
    contix[mom0start-60:mom0stop+60] = False
    
    # Make estimates of the cont, PAH-only, and PAH wavelengths incl. continuum
    cont  = np.ma.average(bkgsub[contix], axis=0)
    total = np.ma.sum(bkgsub[mom0start:mom0stop], axis=0)
    mom0  = np.ma.sum(bkgsub[mom0start:mom0stop] - cont, axis=0)
    
    # Write these out to disk.
    momhdu = fits.PrimaryHDU(mom0.data,header=header)
    momhdu.header['CRVAL3'] = wave[int(np.mean([mom0start,mom0stop]))]
    momhdu.header['CDELT3'] = wave[mom0stop] - wave[mom0start]
    #momhdu.writeto(poststage3+'SPT0418-47_PAH3.3_mom0_contsubtract.fits',overwrite=True)

    momhdu = fits.PrimaryHDU(total.data,header=header)
    momhdu.header['CRVAL3'] = wave[int(np.mean([mom0start,mom0stop]))]
    momhdu.header['CDELT3'] = wave[mom0stop] - wave[mom0start]
    #momhdu.writeto(poststage3+'SPT0418-47_PAH3.3_mom0_nocontsubtract.fits',overwrite=True)

    conthdu = fits.PrimaryHDU(cont.data,header=header)
    conthdu.header['CRVAL3'] = np.mean(wave)
    #conthdu.writeto(poststage3+'SPT0418-47_ch3long_continuum.fits',overwrite=True)
    


# Just make a quick figure showing the 3 images we just made.
# In the above we ignored the DQ arrays, so the edge pixels that
# should be flagged will not be in the below. You can either blank
# them or just leave them, here I just choose not to plot them.
if doanalyze:
    f,axarr = plt.subplots(figsize=(7.5,3),nrows=1,ncols=3)
    f.subplots_adjust(left=0.01,right=0.99,bottom=0.01,top=0.9,hspace=0,wspace=0)
    
    axarr[0].imshow(total.data[1:-1,2:-2], origin='lower', cmap='jet', 
            vmin=np.nanpercentile(total.data[1:-1,2:-2],1.), vmax=np.nanpercentile(total.data[1:-1,2:-2],99.))
    axarr[1].imshow(cont.data[1:-1,2:-2],  origin='lower', cmap='jet', 
            vmin=np.nanpercentile(cont.data[1:-1,2:-2],1.), vmax=np.nanpercentile(cont.data[1:-1,2:-2],99.))
    axarr[2].imshow(mom0.data[1:-1,2:-2],  origin='lower', cmap='jet', 
            vmin=np.nanpercentile(mom0.data[1:-1,2:-2],1.), vmax=np.nanpercentile(mom0.data[1:-1,2:-2],99.))
    
    axarr[0].set_title('Total PAH+cont',fontsize='large')
    axarr[1].set_title('Continuum Only',fontsize='large')
    axarr[2].set_title('3.3um PAH Only',fontsize='large')
    
    for ax in axarr:
        ax.set_xticks([])
        ax.set_yticks([])
    
    plt.show()
    plt.close(f)

# %% [markdown]
# In the Total image, we are seeing continuum plus PAH emission, so the S/N is relatively high. In the cont-only image, you'll notice theres' a dot at the center of the ring - that's the foreground lens galaxy, which is a big bright elliptical galaxy at z=0.26 that still shows some faint emission out here at 17um. Because the PAH-only image has been continuum subtracted (which includes the lens), it's not present there.
#
# And there you have it! Depending on how you ran the pipeline (plus any calibration file differences), the images above should be very similar to those published in Spilker et al. (2023).
#
# As a last exercise, let's pull out a spectrum of the lensed galaxy from the cube. We'll use a simple annular aperture. For kicks we will also demonstrate how to do this in sky coordinates (rather than pixel coordinates).

# %%
if doanalyze:
    import astropy.coordinates as coord
    import astropy.units as au
    from astropy.wcs import WCS
    from scipy.ndimage import gaussian_filter1d # smooth the spectrum if desired
    
    # These are from the ALMA imaging, or you can eyeball using the
    # images we made above
    pos = coord.SkyCoord('04h18m39.696s','-47d51m52.82s')
    rin, rout = 0.6*au.arcsec, 1.8*au.arcsec
    annulus = SkyCircularAnnulus(pos, r_in=rin, r_out=rout)
    
    # Read back in our cube in case above steps were skipped, plus the DQ array
    bkgsub = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].data
    dqarr  = fits.open(stage3+'Level3_ch3-long_s3d.fits')['DQ'].data
    header = fits.open(poststage3+'Level3_ch3-long_s3d_bkgsubtracted.fits')['SCI'].header
    wave = np.arange(header['NAXIS3'])*header['CDELT3'] + header['CRVAL3'] # array of cube wavelengths
    pixareamjy = header['PIXAR_SR'] * 1e9 # From MJy/sr --> mJy/pix
    
    # photutils' aperture_photometry will fail if you try to
    # give it a 3D wcs from the cube because it only works on 2D
    # images. Let's recreate a 2D version of the cube's spatial wcs.
    inwcs_cube = WCS(naxis=2)
    inwcs_cube.wcs.ctype = header['CTYPE1'], header['CTYPE2']
    inwcs_cube.wcs.crval = header['CRVAL1'], header['CRVAL2']
    inwcs_cube.wcs.crpix = header['CRPIX1'], header['CRPIX2']
    inwcs_cube.wcs.cdelt = header['CDELT1'], header['CDELT2']
    inwcs_cube.wcs.pc  = [[header['PC1_1'],  header['PC1_2']],
                          [header['PC2_1'],  header['PC2_2']]]
    
    # Loop over channels and get source flux (in mJy) at each channel
    srcspec = np.zeros(bkgsub.shape[0])
    for i in range(srcspec.size):
        thisdq = (dqarr[i,:,:] > 0) # Convert the DQ channel into a True/False array
        photann = aperture_photometry(bkgsub[i,:,:], apertures=annulus, method='subpixel', mask=thisdq, wcs=inwcs_cube)
        srcspec[i] = photann['aperture_sum'][0] * pixareamjy
    
    # Smooth the spectrum if desired
    smoothspec = gaussian_filter1d(srcspec, sigma=10)
    
    f,ax = plt.subplots(figsize=(4,4),nrows=1,ncols=1)
    
    ax.plot(wave,srcspec,marker='None',ls='-',color='grey',lw=1)
    ax.plot(wave,smoothspec,marker='None',ls='-',color='navy',lw=2)
    
    # Draw lines for 0 flux and a very rough continuum
    ax.axhline(0,color='k',ls='-',zorder=0)
    ax.axhline(np.nanmean(srcspec[:400]),ls=':',color='k',lw=1,zorder=1)
    
    ax.set_xlabel('Observed Wavelength (um)')
    ax.set_ylabel('Flux Density (mJy)')
    
    plt.show()
    plt.close(f)

# %% [markdown]
# ## Lessons Learned and Future Improvements

# %% [markdown]
# That's all I've got to show you right now. I thought it would be nice to conclude with some lessons we've learned that might help others design better observing programs in the future.
#
# ### Lessons Learned
# - Our CR shower de-striping technique relies on having enough background pixels around the source position to estimate the stripe amplitudes. Our data used "primary channel" = "ALL", which roughly centers the source in all 4 MRS channels. In this particular case, if we were willing to sacrifice the other channels to some extent, SPT0418-47 could have been centered better in Channel 3, the one of primary interest.
# - Dedicated background exposures. Our data used 4 background exposures, reaching the same integration time as the on-source data. I (JS) have tried to reduce these data ignoring the backgrounds completely and it was a total disaster. It seems some dedicated backgrounds really are needed - but whether it's okay to get away with less background exposure time is still TBD.
#
# ### Future Improvements
# - CR Shower treatment. I really hope one day the pipeline is mature enough to identify and flag the CR showers, which would make a whole lot of the pain above unnecessary anymore.
# - Incorporate the simultaneous MIRI imaging. I (JS) have seen notebooks floating around that use the imager data to confirm/improve the astrometry for the MRS data. That wasn't necessary here because (at least at 0.6" resolution) there was no evidence for an astrometric offset between MRS and ALMA.
# - Ongoing calibration updates. At this early stage, many of the reference files are still in flux and will presumably improve with time. The bad pixel mask, for example, would save a lot of effort.
